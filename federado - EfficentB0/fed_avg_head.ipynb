# %% [markdown]
# <h1> <b> Configuraciones y rutas

# %%
# Librerías
import sys
import torch
import numpy as np
import random
import copy
import matplotlib.pyplot as plt
import seaborn as sns
import torch.nn as nn
import math
import importlib
import torchvision.transforms.functional as TF

# Importes
from pathlib import Path
sys.path.append(str(Path(".").resolve()))
from modelo_head import crear_encoder, crear_cabeza
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.metrics import (roc_auc_score, confusion_matrix, f1_score, recall_score, precision_score)

# Recargar agregacion para asegurar versión actualizada
import agregacion
importlib.reload(agregacion)
from agregacion import agregar_pesos

# Semilla
SEED = 42
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(SEED)

# Dispositivo
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Dispositivo: {DEVICE}")
# Out:
# Dispositivo: cuda

# %%
# Rutas por centro
BASE_DIR = Path("..")

CENTROS = {
    "center_1": {
        "train": BASE_DIR / "preprocesamiento/output/center_1/preprocesamiento_train",
        "test" : BASE_DIR / "preprocesamiento/output/center_1/preprocesamiento_test",
    },
    "center_2": {
        "train": BASE_DIR / "preprocesamiento/output/center_2/preprocesamiento_train",
        "test" : BASE_DIR / "preprocesamiento/output/center_2/preprocesamiento_test",
    },
    "center_3": {
        "train": BASE_DIR / "preprocesamiento/output/center_3/preprocesamiento_train",
        "test" : BASE_DIR / "preprocesamiento/output/center_3/preprocesamiento_test",
    },
    "center_4": {
        "train": BASE_DIR / "preprocesamiento/output/center_4/preprocesamiento_train",
        "test" : BASE_DIR / "preprocesamiento/output/center_4/preprocesamiento_test",
    },
}

# Hiperparámetros
BATCH_SIZE       = 16
EPOCHS_LOCAL     = 20     # épocas que entrena cada centro por ronda
RONDAS           = 30    # rondas de comunicación federada
LR               = 1e-4
PACIENCIA        = 10     # early stopping

# Directorio de pesos
PESOS_DIR = Path("pesos_sin_head")
PESOS_DIR.mkdir(exist_ok=True)
(PESOS_DIR / "cabezas").mkdir(exist_ok=True) 

# Verificar que los centros existen
for nombre, rutas in CENTROS.items():
    train_ok = rutas["train"].exists()
    test_ok  = rutas["test"].exists()
    print(f"  {nombre} — train: {'Ok' if train_ok else 'Bad'} | test: {'Ok' if test_ok else 'Bad'}")
# Out:
#   center_1 — train: Ok | test: Ok
#   center_2 — train: Ok | test: Ok
#   center_3 — train: Ok | test: Ok
#   center_4 — train: Ok | test: Ok

# %% [markdown]
# <h1><b> Dataset y dataloader

# %%
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# Definir esto una vez fuera de cargar_centro
g = torch.Generator()
g.manual_seed(SEED)

# %%
# Dataset y DataLoader personalizados para nuestros archivos .npy
class StrokeDataset(Dataset):

    def __init__(self, archivos, augment=False):
        # Guardamos las rutas de los archivos .npy
        self.archivos = archivos
        self.augment  = augment

    def __len__(self):
        # El número de muestras es el número de archivos .npy
        return len(self.archivos)

    def __getitem__(self, idx):
        # Cargar imagen
        ruta   = self.archivos[idx]
        imagen = np.load(ruta).astype(np.float32)
        imagen = torch.from_numpy(imagen)

        if self.augment:
            if random.random() > 0.5:
                imagen = TF.hflip(imagen)
            if random.random() > 0.5:
                imagen = TF.vflip(imagen)
            if random.random() > 0.5:
                angle  = random.uniform(-15, 15)
                imagen = TF.rotate(imagen, angle)

        nombre = ruta.stem
        # contiene "STROKE" para positivos y no lo contiene para negativos
        label  = 1 if "STROKE" in nombre else 0

        # Retorno como tensor de PyTorch del label (0 o 1) y la imagen
        return imagen, torch.tensor(label, dtype=torch.float32)


def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

g = torch.Generator()
g.manual_seed(SEED)


# Función para cargar los datos de un centro
def cargar_centro(rutas_centro):

    # Listar y ordenar los archivos .npy en train y test
    archivos_train = sorted(rutas_centro["train"].glob("*.npy"))
    archivos_test  = sorted(rutas_centro["test"].glob("*.npy"))

    # Split 80/20 sobre archivos — antes de crear datasets
    val_size   = int(len(archivos_train) * 0.2)
    train_size = len(archivos_train) - val_size

    indices = list(range(len(archivos_train)))
    rng     = random.Random(SEED)
    rng.shuffle(indices)

    idx_train = indices[:train_size]
    idx_val   = indices[train_size:]

    arch_train = [archivos_train[i] for i in idx_train]
    arch_val   = [archivos_train[i] for i in idx_val]

    # Calcular pos_weight por centro
    n_control  = sum(1 for f in arch_train if "CONTROL" in f.stem)
    n_stroke   = sum(1 for f in arch_train if "STROKE"  in f.stem)
    pos_weight = torch.tensor([n_stroke / n_control], dtype=torch.float32).to(DEVICE)

    dataset_train = StrokeDataset(arch_train, augment=True)   # ← augment en train
    dataset_val   = StrokeDataset(arch_val,   augment=False)  # ← val limpio
    dataset_test  = StrokeDataset(archivos_test, augment=False)

    # Crear dataloaders
    loader_train = DataLoader(dataset_train, batch_size=BATCH_SIZE, shuffle=True,
                              worker_init_fn=seed_worker, generator=g)
    loader_val   = DataLoader(dataset_val,  batch_size=BATCH_SIZE, shuffle=False)
    loader_test  = DataLoader(dataset_test, batch_size=BATCH_SIZE, shuffle=False)

    # Retornar los datasets y dataloaders
    return {
        "loader_train" : loader_train,
        "loader_val"   : loader_val,
        "loader_test"  : loader_test,
        "n_train"      : train_size,
        "n_val"        : val_size,
        "n_test"       : len(archivos_test),
        "pos_weight"   : pos_weight,
    }


# Cargar datos de todos los centros
datos_centros = {}

for nombre, rutas in CENTROS.items():
    datos_centros[nombre] = cargar_centro(rutas)


# Verificación
print(f"{'Centro':<12} {'Train':>8} {'Val':>8} {'Test':>8} {'pos_weight':>12}")
print("-" * 46)
for nombre, datos in datos_centros.items():
    print(f"{nombre:<12} {datos['n_train']:>8} {datos['n_val']:>8} {datos['n_test']:>8} {datos['pos_weight'].item():>12.4f}")
# Out:
# Centro          Train      Val     Test   pos_weight
# ----------------------------------------------
# center_1         2432      608      760       0.9853
# center_2          768      192      240       1.4000
# center_3          544      135      171       1.7200
# center_4         1024      256      320       1.1787

# %% [markdown]
# <h1><b> Modelo global

# %%
# Modelo global
set_seed(SEED)
encoder_global = crear_encoder().to(DEVICE)

# Cabezas locales por centro 
cabezas_centros = {nombre: crear_cabeza().to(DEVICE) for nombre in CENTROS}

# Ruta donde guardar el mejor modelo global
MEJOR_ENCODER_PATH = PESOS_DIR / "encoder_global_mejor_fedavg.pth"
CABEZAS_DIR        = PESOS_DIR / "cabezas" 

params_encoder = sum(p.numel() for p in encoder_global.parameters())
params_cabeza  = sum(p.numel() for p in list(cabezas_centros.values())[0].parameters())

print(f"Parámetros encoder : {params_encoder:,}")
print(f"Parámetros cabeza  : {params_cabeza:,}")
print(f"Dispositivo        : {DEVICE}")
# Out:
# Parámetros encoder : 4,007,260
# Parámetros cabeza  : 1,281
# Dispositivo        : cuda

# %% [markdown]
# <h1><b> Entrenamiento local por centro para federado

# %%
LOSS_POR_CENTRO = {
    "center_1": nn.BCEWithLogitsLoss(),
    "center_2": nn.BCEWithLogitsLoss(),
    "center_3": nn.BCEWithLogitsLoss(pos_weight=datos_centros["center_3"]["pos_weight"]),
    "center_4": nn.BCEWithLogitsLoss(pos_weight=datos_centros["center_4"]["pos_weight"]),
}

# Verificación
for nombre, criterio in LOSS_POR_CENTRO.items():
    pw = datos_centros[nombre]["pos_weight"].item()
    print(f"{nombre:<12} pos_weight: {pw:.4f}")
# Out:
# center_1     pos_weight: 0.9853
# center_2     pos_weight: 1.4000
# center_3     pos_weight: 1.7200
# center_4     pos_weight: 1.1787

# %%
def entrenar_centro(nombre, encoder_global, cabeza_centro, loader_train, loader_val, epochs):
    """
    Entrena localmente y retorna los mejores pesos
    y el val_loss correspondiente.
    """
    # Copia local del modelo global — no modificamos el global
    encoder_local = copy.deepcopy(encoder_global)
    cabeza_local  = copy.deepcopy(cabeza_centro)
    criterio      = LOSS_POR_CENTRO[nombre] # es mejor para clasificación binaria con logits

    # Optimizador para el modelo local
    optimizer = torch.optim.AdamW(
        list(encoder_local.parameters()) + list(cabeza_local.parameters()),
        lr=LR, weight_decay=1e-4
    )
    # Scheduler para reducir LR gradualmente
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)

    # Variables para guardar la mejor época local
    mejor_val_loss        = float("inf")
    mejor_val_auc         = 0.0
    mejor_val_acc         = 0.0
    mejores_pesos_encoder = None
    mejores_pesos_cabeza  = None

    for epoca in range(epochs):
        # Train
        encoder_local.train()
        cabeza_local.train()

        train_loss, train_correctos = 0.0, 0

        for imagenes, labels in loader_train:

            imagenes = imagenes.to(DEVICE)
            labels   = labels.to(DEVICE).unsqueeze(1)

            # zero_grad es importante para no acumular gradientes entre lotes
            optimizer.zero_grad()

            # forward + backward
            embedding = encoder_local(imagenes)   # [batch, 1280]
            salida    = cabeza_local(embedding)    # [batch, 1]

            loss   = criterio(salida, labels)
            loss.backward()
            # Gradient clipping para estabilidad
            torch.nn.utils.clip_grad_norm_(
                list(encoder_local.parameters()) + list(cabeza_local.parameters()),
                max_norm=1.0
            )
            # actualizar pesos locales
            optimizer.step()

            # Acumular métricas para esta época
            train_loss      += loss.item()
            preds            = (torch.sigmoid(salida) >= 0.5).float()
            train_correctos += (preds == labels).sum().item()

        # Val
        encoder_local.eval()
        cabeza_local.eval()

        val_loss, val_correctos = 0.0, 0
        todas_probs  = []
        todos_labels = []

        # No necesitamos gradientes para la validación
        with torch.no_grad():
            for imagenes, labels in loader_val:
                imagenes  = imagenes.to(DEVICE)
                labels    = labels.to(DEVICE).unsqueeze(1)
                embedding = encoder_local(imagenes)
                salida    = cabeza_local(embedding)
                loss      = criterio(salida, labels)
                probs     = torch.sigmoid(salida).squeeze(1).cpu().numpy()

                val_loss      += loss.item()
                preds          = (torch.sigmoid(salida) >= 0.5).float()
                val_correctos += (preds == labels).sum().item()
                todas_probs.extend(probs)
                todos_labels.extend(labels.squeeze(1).cpu().numpy())

        # Promedio de métricas por época
        train_loss /= len(loader_train)
        val_loss   /= len(loader_val)
        train_acc   = train_correctos / len(loader_train.dataset)
        val_acc     = val_correctos   / len(loader_val.dataset)
        val_auc     = roc_auc_score(todos_labels, todas_probs)

        # Actualizar LR con el scheduler
        scheduler.step()

        print(f"      [{nombre}] época {epoca+1:02d}/{epochs} — "
              f"train_loss: {train_loss:.4f} acc: {train_acc:.4f} | "
              f"val_loss: {val_loss:.4f} acc: {val_acc:.4f} | auc: {val_auc:.4f}")

        # Guardar mejor época local por AUC
        if val_auc > mejor_val_auc:
            mejor_val_loss        = val_loss
            mejor_val_acc         = val_acc
            mejor_val_auc         = val_auc
            mejores_pesos_encoder = copy.deepcopy(encoder_local.state_dict())
            mejores_pesos_cabeza  = copy.deepcopy(cabeza_local.state_dict())
            print(f"        → mejor época local: {epoca+1} | auc: {mejor_val_auc:.4f}")

    return mejores_pesos_encoder, mejores_pesos_cabeza, mejor_val_loss, mejor_val_acc, mejor_val_auc

# %% [markdown]
# # **Entrenamiento Federado (FedAvg) - Sin Cabezas**

# %%
# Rondas federadas

# Variables para seguimiento de la mejor ronda global
mejor_val_global  = 0.0
rondas_sin_mejora = 0
total_muestras    = sum(d["n_train"] for d in datos_centros.values())

historial = {"ronda": [], "val_auc": []}

# Entrenamiento federado
for ronda in range(1, RONDAS + 1):

    print(f"\n{'='*60}")
    print(f"  RONDA {ronda}/{RONDAS}")
    print(f"{'='*60}")

    set_seed(SEED + ronda)

    # Reiniciar generator al inicio de cada ronda
    g = torch.Generator()
    g.manual_seed(SEED + ronda)  # seed distinta pero fija por ronda

    # Recrear loader_train con el nuevo generator
    for nombre, datos in datos_centros.items():
        datos["loader_train"] = DataLoader(
            datos["loader_train"].dataset,
            batch_size=BATCH_SIZE,
            shuffle=True,
            worker_init_fn=seed_worker,
            generator=g
        )

    pesos_encoder_centros = []   # solo encoders van a FedAvg
    val_losses            = []
    val_aucs              = []
    muestras_centros      = []


    # Entrenamiento local por centro
    for nombre, datos in datos_centros.items():
        print(f"\n  Centro: {nombre}")
        set_seed(SEED + ronda)

        pesos_encoder, pesos_cabeza, val_loss, val_acc, val_auc = entrenar_centro(
            nombre,
            encoder_global,
            cabezas_centros[nombre],   # cabeza persistente por centro
            datos["loader_train"],
            datos["loader_val"],
            EPOCHS_LOCAL
        )

        pesos_encoder_centros.append(pesos_encoder)  # para FedAvg
        cabezas_centros[nombre].load_state_dict(pesos_cabeza)  # actualiza cabeza local
        val_losses.append(val_loss)
        val_aucs.append(val_auc)
        muestras_centros.append(datos["n_train"])

    # FedAvg
    pesos_globales = agregar_pesos(pesos_encoder_centros, muestras_centros)
    encoder_global.load_state_dict(pesos_globales)

    # Val global ponderada
    val_global = sum(
        va * (n / total_muestras)
        for va, n in zip(val_aucs, muestras_centros)
    )

    historial["ronda"].append(ronda)
    historial["val_auc"].append(val_global)

    print(f"\n  {'─'*55}")
    print(f"  Ronda {ronda} — val_auc global: {val_global:.4f}")


    # Guardar mejor modelo global
    if val_global > mejor_val_global:
        mejor_val_global  = val_global
        rondas_sin_mejora = 0
        torch.save(encoder_global.state_dict(), MEJOR_ENCODER_PATH)
        print(f"  Mejor encoder global guardado (val_auc: {mejor_val_global:.4f})")
    else:
        rondas_sin_mejora += 1
        print(f"  Sin mejora {rondas_sin_mejora}/{PACIENCIA}")

    # Early stopping
    if rondas_sin_mejora >= PACIENCIA:
        print(f"\n  Early stopping en ronda {ronda}")
        break


print(f"\n{'='*60}")
print(f"Entrenamiento federado finalizado")
print(f"Mejor val_auc global : {mejor_val_global:.4f}")
print(f"Encoder guardado en  : {MEJOR_ENCODER_PATH}")
# Out:
# ============================================================
#   RONDA 1/30
# ============================================================
#
#   Centro: center_1
#       [center_1] época 01/20 — train_loss: 0.3158 acc: 0.8725 | val_loss: 0.1142 acc: 0.9589 | auc: 0.9959
#         → mejor época local: 1 | auc: 0.9959
#       [center_1] época 02/20 — train_loss: 0.1382 acc: 0.9548 | val_loss: 0.0556 acc: 0.9819 | auc: 0.9989
#         → mejor época local: 2 | auc: 0.9989
#       [center_1] época 03/20 — train_loss: 0.0912 acc: 0.9667 | val_loss: 0.0419 acc: 0.9885 | auc: 0.9989
#         → mejor época local: 3 | auc: 0.9989
#       [center_1] época 04/20 — train_loss: 0.0924 acc: 0.9716 | val_loss: 0.0403 acc: 0.9901 | auc: 0.9994
#         → mejor época local: 4 | auc: 0.9994
#       [center_1] época 05/20 — train_loss: 0.0556 acc: 0.9811 | val_loss: 0.0500 acc: 0.9836 | auc: 0.9992
#       [center_1] época 06/20 — train_loss: 0.0436 acc: 0.9868 | val_loss: 0.0269 acc: 0.9934 | auc: 0.9995
#         → mejor época local: 6 | auc: 0.9995
#       [center_1] época 07/20 — train_loss: 0.0477 acc: 0.9873 | val_loss: 0.0369 acc: 0.9885 | auc: 0.9995
#       [center_1] época 08/20 — train_loss: 0.0339 acc: 0.9897 | val_loss: 0.0150 acc: 0.9984 | auc: 0.9997
#         → mejor época local: 8 | auc: 0.9997
#       [center_1] época 09/20 — train_loss: 0.0244 acc: 0.9942 | val_loss: 0.0150 acc: 0.9951 | auc: 0.9998
#         → mejor época local: 9 | auc: 0.9998
#       [center_1] época 10/20 — train_loss: 0.0279 acc: 0.9926 | val_loss: 0.0168 acc: 0.9984 | auc: 0.9991
#       [center_1] época 11/20 — train_loss: 0.0404 acc: 0.9918 | val_loss: 0.0124 acc: 0.9984 | auc: 0.9999
#         → mejor época local: 11 | auc: 0.9999
#       [center_1] época 12/20 — train_loss: 0.0186 acc: 0.9934 | val_loss: 0.0234 acc: 0.9901 | auc: 0.9999
#       [center_1] época 13/20 — train_loss: 0.0141 acc: 0.9951 | val_loss: 0.0079 acc: 0.9984 | auc: 1.0000
#         → mejor época local: 13 | auc: 1.0000
#       [center_1] época 14/20 — train_loss: 0.0133 acc: 0.9959 | val_loss: 0.0115 acc: 0.9967 | auc: 0.9999
#       [center_1] época 15/20 — train_loss: 0.0113 acc: 0.9971 | val_loss: 0.0074 acc: 0.9984 | auc: 1.0000
#       [center_1] época 16/20 — train_loss: 0.0141 acc: 0.9963 | val_loss: 0.0047 acc: 0.9984 | auc: 1.0000
#         → mejor época local: 16 | auc: 1.0000
#       [center_1] época 17/20 — train_loss: 0.0126 acc: 0.9975 | val_loss: 0.0089 acc: 0.9984 | auc: 1.0000
#       [center_1] época 18/20 — train_loss: 0.0081 acc: 0.9963 | val_loss: 0.0067 acc: 0.9984 | auc: 1.0000
#       [center_1] época 19/20 — train_loss: 0.0106 acc: 0.9963 | val_loss: 0.0064 acc: 0.9984 | auc: 1.0000
#       [center_1] época 20/20 — train_loss: 0.0155 acc: 0.9959 | val_loss: 0.0064 acc: 0.9984 | auc: 1.0000
#
#   Centro: center_2
#       [center_2] época 01/20 — train_loss: 0.4802 acc: 0.8190 | val_loss: 0.2771 acc: 0.8906 | auc: 0.9689
#         → mejor época local: 1 | auc: 0.9689
#       [center_2] época 02/20 — train_loss: 0.2924 acc: 0.8841 | val_loss: 0.2116 acc: 0.9010 | auc: 0.9852
#         → mejor época local: 2 | auc: 0.9852
#       [center_2] época 03/20 — train_loss: 0.2101 acc: 0.9219 | val_loss: 0.1173 acc: 0.9583 | auc: 0.9939
#         → mejor época local: 3 | auc: 0.9939
#       [center_2] época 04/20 — train_loss: 0.1904 acc: 0.9375 | val_loss: 0.0995 acc: 0.9583 | auc: 0.9945
#         → mejor época local: 4 | auc: 0.9945
#       [center_2] época 05/20 — train_loss: 0.1521 acc: 0.9453 | val_loss: 0.0856 acc: 0.9688 | auc: 0.9952
#         → mejor época local: 5 | auc: 0.9952
#       [center_2] época 06/20 — train_loss: 0.1280 acc: 0.9518 | val_loss: 0.0700 acc: 0.9688 | auc: 0.9987
#         → mejor época local: 6 | auc: 0.9987
#       [center_2] época 07/20 — train_loss: 0.0892 acc: 0.9648 | val_loss: 0.0761 acc: 0.9688 | auc: 0.9975
#       [center_2] época 08/20 — train_loss: 0.1332 acc: 0.9596 | val_loss: 0.0782 acc: 0.9635 | auc: 0.9959
#       [center_2] época 09/20 — train_loss: 0.0846 acc: 0.9661 | val_loss: 0.0583 acc: 0.9792 | auc: 0.9985
#       [center_2] época 10/20 — train_loss: 0.0642 acc: 0.9740 | val_loss: 0.0558 acc: 0.9792 | auc: 0.9981
#       [center_2] época 11/20 — train_loss: 0.0644 acc: 0.9779 | val_loss: 0.0754 acc: 0.9635 | auc: 0.9968
#       [center_2] época 12/20 — train_loss: 0.0586 acc: 0.9831 | val_loss: 0.0770 acc: 0.9635 | auc: 0.9959
#       [center_2] época 13/20 — train_loss: 0.0490 acc: 0.9805 | val_loss: 0.0761 acc: 0.9688 | auc: 0.9977
#       [center_2] época 14/20 — train_loss: 0.0485 acc: 0.9857 | val_loss: 0.0921 acc: 0.9583 | auc: 0.9916
#       [center_2] época 15/20 — train_loss: 0.0904 acc: 0.9727 | val_loss: 0.0994 acc: 0.9635 | auc: 0.9954
#       [center_2] época 16/20 — train_loss: 0.0617 acc: 0.9753 | val_loss: 0.1069 acc: 0.9688 | auc: 0.9931
#       [center_2] época 17/20 — train_loss: 0.0279 acc: 0.9922 | val_loss: 0.1142 acc: 0.9635 | auc: 0.9892
#       [center_2] época 18/20 — train_loss: 0.0404 acc: 0.9857 | val_loss: 0.0938 acc: 0.9688 | auc: 0.9949
#       [center_2] época 19/20 — train_loss: 0.0304 acc: 0.9909 | val_loss: 0.1038 acc: 0.9635 | auc: 0.9942
#       [center_2] época 20/20 — train_loss: 0.0243 acc: 0.9909 | val_loss: 0.1055 acc: 0.9688 | auc: 0.9923
#
#   Centro: center_3
#       [center_3] época 01/20 — train_loss: 0.8718 acc: 0.6562 | val_loss: 0.6513 acc: 0.7333 | auc: 0.8652
#         → mejor época local: 1 | auc: 0.8652
#       [center_3] época 02/20 — train_loss: 0.6387 acc: 0.7647 | val_loss: 0.5521 acc: 0.8148 | auc: 0.8953
#         → mejor época local: 2 | auc: 0.8953
#       [center_3] época 03/20 — train_loss: 0.5455 acc: 0.8107 | val_loss: 0.5437 acc: 0.8222 | auc: 0.9027
#         → mejor época local: 3 | auc: 0.9027
#       [center_3] época 04/20 — train_loss: 0.4460 acc: 0.8309 | val_loss: 0.4884 acc: 0.8074 | auc: 0.9113
#         → mejor época local: 4 | auc: 0.9113
#       [center_3] época 05/20 — train_loss: 0.3971 acc: 0.8621 | val_loss: 0.4744 acc: 0.8296 | auc: 0.9175
#         → mejor época local: 5 | auc: 0.9175
#       [center_3] época 06/20 — train_loss: 0.3608 acc: 0.8897 | val_loss: 0.4366 acc: 0.8370 | auc: 0.9261
#         → mejor época local: 6 | auc: 0.9261
#       [center_3] época 07/20 — train_loss: 0.3830 acc: 0.8548 | val_loss: 0.4768 acc: 0.8889 | auc: 0.9377
#         → mejor época local: 7 | auc: 0.9377
#       [center_3] época 08/20 — train_loss: 0.3260 acc: 0.9026 | val_loss: 0.4248 acc: 0.8741 | auc: 0.9453
#         → mejor época local: 8 | auc: 0.9453
#       [center_3] época 09/20 — train_loss: 0.2699 acc: 0.9246 | val_loss: 0.5162 acc: 0.8963 | auc: 0.9407
#       [center_3] época 10/20 — train_loss: 0.2334 acc: 0.9283 | val_loss: 0.3586 acc: 0.9037 | auc: 0.9525
#         → mejor época local: 10 | auc: 0.9525
#       [center_3] época 11/20 — train_loss: 0.2388 acc: 0.9191 | val_loss: 0.4698 acc: 0.8815 | auc: 0.9534
#         → mejor época local: 11 | auc: 0.9534
#       [center_3] época 12/20 — train_loss: 0.2326 acc: 0.9301 | val_loss: 0.4983 acc: 0.8889 | auc: 0.9527
#       [center_3] época 13/20 — train_loss: 0.2080 acc: 0.9412 | val_loss: 0.4717 acc: 0.8963 | auc: 0.9583
#         → mejor época local: 13 | auc: 0.9583
#       [center_3] época 14/20 — train_loss: 0.2193 acc: 0.9375 | val_loss: 0.3705 acc: 0.9037 | auc: 0.9664
#         → mejor época local: 14 | auc: 0.9664
#       [center_3] época 15/20 — train_loss: 0.1819 acc: 0.9449 | val_loss: 0.3526 acc: 0.9185 | auc: 0.9690
#         → mejor época local: 15 | auc: 0.9690
#       [center_3] época 16/20 — train_loss: 0.2198 acc: 0.9338 | val_loss: 0.4039 acc: 0.9037 | auc: 0.9701
#         → mejor época local: 16 | auc: 0.9701
#       [center_3] época 17/20 — train_loss: 0.2265 acc: 0.9338 | val_loss: 0.4026 acc: 0.9111 | auc: 0.9687
#       [center_3] época 18/20 — train_loss: 0.2229 acc: 0.9449 | val_loss: 0.3374 acc: 0.9111 | auc: 0.9703
#         → mejor época local: 18 | auc: 0.9703
#       [center_3] época 19/20 — train_loss: 0.1964 acc: 0.9504 | val_loss: 0.3861 acc: 0.9111 | auc: 0.9694
#       [center_3] época 20/20 — train_loss: 0.1508 acc: 0.9632 | val_loss: 0.3468 acc: 0.9111 | auc: 0.9690
#
#   Centro: center_4
#       [center_4] época 01/20 — train_loss: 0.6089 acc: 0.7080 | val_loss: 0.4312 acc: 0.8320 | auc: 0.9133
#         → mejor época local: 1 | auc: 0.9133
#       [center_4] época 02/20 — train_loss: 0.4241 acc: 0.8223 | val_loss: 0.2993 acc: 0.8906 | auc: 0.9565
#         → mejor época local: 2 | auc: 0.9565
#       [center_4] época 03/20 — train_loss: 0.3182 acc: 0.8809 | val_loss: 0.2559 acc: 0.9102 | auc: 0.9592
#         → mejor época local: 3 | auc: 0.9592
#       [center_4] época 04/20 — train_loss: 0.2729 acc: 0.9053 | val_loss: 0.2194 acc: 0.9258 | auc: 0.9703
#         → mejor época local: 4 | auc: 0.9703
#       [center_4] época 05/20 — train_loss: 0.2613 acc: 0.9092 | val_loss: 0.2351 acc: 0.9297 | auc: 0.9653
#       [center_4] época 06/20 — train_loss: 0.2392 acc: 0.9131 | val_loss: 0.2014 acc: 0.9375 | auc: 0.9758
#         → mejor época local: 6 | auc: 0.9758
#       [center_4] época 07/20 — train_loss: 0.1979 acc: 0.9277 | val_loss: 0.1922 acc: 0.9453 | auc: 0.9731
#       [center_4] época 08/20 — train_loss: 0.2298 acc: 0.9238 | val_loss: 0.1881 acc: 0.9336 | auc: 0.9763
#         → mejor época local: 8 | auc: 0.9763
#       [center_4] época 09/20 — train_loss: 0.1893 acc: 0.9336 | val_loss: 0.1852 acc: 0.9375 | auc: 0.9780
#         → mejor época local: 9 | auc: 0.9780
#       [center_4] época 10/20 — train_loss: 0.1674 acc: 0.9541 | val_loss: 0.1567 acc: 0.9453 | auc: 0.9852
#         → mejor época local: 10 | auc: 0.9852
#       [center_4] época 11/20 — train_loss: 0.1883 acc: 0.9336 | val_loss: 0.1805 acc: 0.9414 | auc: 0.9802
#       [center_4] época 12/20 — train_loss: 0.1593 acc: 0.9434 | val_loss: 0.1828 acc: 0.9375 | auc: 0.9796
#       [center_4] época 13/20 — train_loss: 0.1846 acc: 0.9443 | val_loss: 0.2196 acc: 0.9336 | auc: 0.9749
#       [center_4] época 14/20 — train_loss: 0.1430 acc: 0.9482 | val_loss: 0.1701 acc: 0.9492 | auc: 0.9841
#       [center_4] época 15/20 — train_loss: 0.1424 acc: 0.9531 | val_loss: 0.1756 acc: 0.9375 | auc: 0.9846
#       [center_4] época 16/20 — train_loss: 0.1250 acc: 0.9600 | val_loss: 0.1765 acc: 0.9453 | auc: 0.9848
#       [center_4] época 17/20 — train_loss: 0.1340 acc: 0.9590 | val_loss: 0.1788 acc: 0.9492 | auc: 0.9825
#       [center_4] época 18/20 — train_loss: 0.1203 acc: 0.9600 | val_loss: 0.1760 acc: 0.9414 | auc: 0.9839
#       [center_4] época 19/20 — train_loss: 0.1240 acc: 0.9551 | val_loss: 0.1701 acc: 0.9375 | auc: 0.9843
#       [center_4] época 20/20 — train_loss: 0.1109 acc: 0.9600 | val_loss: 0.1697 acc: 0.9453 | auc: 0.9843
#
#   ───────────────────────────────────────────────────────
#   Ronda 1 — val_auc global: 0.9932
#   Mejor encoder global guardado (val_auc: 0.9932)
#
# ============================================================
#   RONDA 2/30
# ============================================================
#
#   Centro: center_1
#       [center_1] época 01/20 — train_loss: 0.0550 acc: 0.9844 | val_loss: 0.0349 acc: 0.9885 | auc: 0.9994
#         → mejor época local: 1 | auc: 0.9994
#       [center_1] época 02/20 — train_loss: 0.0370 acc: 0.9881 | val_loss: 0.0110 acc: 0.9967 | auc: 1.0000
#         → mejor época local: 2 | auc: 1.0000
#       [center_1] época 03/20 — train_loss: 0.0542 acc: 0.9856 | val_loss: 0.0170 acc: 0.9967 | auc: 0.9999
#       [center_1] época 04/20 — train_loss: 0.0398 acc: 0.9901 | val_loss: 0.0184 acc: 0.9934 | auc: 0.9999
#       [center_1] época 05/20 — train_loss: 0.0302 acc: 0.9910 | val_loss: 0.0172 acc: 0.9967 | auc: 0.9994
#       [center_1] época 06/20 — train_loss: 0.0167 acc: 0.9947 | val_loss: 0.0141 acc: 0.9967 | auc: 0.9999
#       [center_1] época 07/20 — train_loss: 0.0179 acc: 0.9955 | val_loss: 0.0109 acc: 0.9951 | auc: 1.0000
#       [center_1] época 08/20 — train_loss: 0.0073 acc: 0.9984 | val_loss: 0.0214 acc: 0.9951 | auc: 1.0000
#         → mejor época local: 8 | auc: 1.0000
#       [center_1] época 09/20 — train_loss: 0.0169 acc: 0.9967 | val_loss: 0.0048 acc: 0.9984 | auc: 1.0000
#         → mejor época local: 9 | auc: 1.0000
#       [center_1] época 10/20 — train_loss: 0.0104 acc: 0.9967 | val_loss: 0.0042 acc: 0.9984 | auc: 1.0000
#       [center_1] época 11/20 — train_loss: 0.0104 acc: 0.9975 | val_loss: 0.0055 acc: 0.9984 | auc: 1.0000
#         → mejor época local: 11 | auc: 1.0000
#       [center_1] época 12/20 — train_loss: 0.0350 acc: 0.9951 | val_loss: 0.0005 acc: 1.0000 | auc: 1.0000
#       [center_1] época 13/20 — train_loss: 0.0081 acc: 0.9967 | val_loss: 0.0150 acc: 0.9967 | auc: 1.0000
#       [center_1] época 14/20 — train_loss: 0.0047 acc: 0.9979 | val_loss: 0.0016 acc: 1.0000 | auc: 1.0000
#       [center_1] época 15/20 — train_loss: 0.0045 acc: 0.9992 | val_loss: 0.0006 acc: 1.0000 | auc: 1.0000
#       [center_1] época 16/20 — train_loss: 0.0024 acc: 0.9996 | val_loss: 0.0023 acc: 0.9984 | auc: 1.0000
#       [center_1] época 17/20 — train_loss: 0.0068 acc: 0.9971 | val_loss: 0.0011 acc: 1.0000 | auc: 1.0000
#       [center_1] época 18/20 — train_loss: 0.0044 acc: 0.9979 | val_loss: 0.0019 acc: 1.0000 | auc: 1.0000
#       [center_1] época 19/20 — train_loss: 0.0007 acc: 1.0000 | val_loss: 0.0015 acc: 1.0000 | auc: 1.0000
#       [center_1] época 20/20 — train_loss: 0.0026 acc: 0.9984 | val_loss: 0.0012 acc: 1.0000 | auc: 1.0000
#
#   Centro: center_2
#       [center_2] época 01/20 — train_loss: 0.2225 acc: 0.9245 | val_loss: 0.0955 acc: 0.9635 | auc: 0.9951
#         → mejor época local: 1 | auc: 0.9951
#       [center_2] época 02/20 — train_loss: 0.1566 acc: 0.9479 | val_loss: 0.0910 acc: 0.9635 | auc: 0.9959
#         → mejor época local: 2 | auc: 0.9959
#       [center_2] época 03/20 — train_loss: 0.1081 acc: 0.9648 | val_loss: 0.0732 acc: 0.9740 | auc: 0.9975
#         → mejor época local: 3 | auc: 0.9975
#       [center_2] época 04/20 — train_loss: 0.0927 acc: 0.9688 | val_loss: 0.0874 acc: 0.9740 | auc: 0.9948
#       [center_2] época 05/20 — train_loss: 0.0895 acc: 0.9674 | val_loss: 0.0777 acc: 0.9740 | auc: 0.9979
#         → mejor época local: 5 | auc: 0.9979
#       [center_2] época 06/20 — train_loss: 0.0466 acc: 0.9857 | val_loss: 0.0761 acc: 0.9792 | auc: 0.9970
#       [center_2] época 07/20 — train_loss: 0.0809 acc: 0.9805 | val_loss: 0.0830 acc: 0.9688 | auc: 0.9979
#       [center_2] época 08/20 — train_loss: 0.0451 acc: 0.9883 | val_loss: 0.1025 acc: 0.9688 | auc: 0.9971
#       [center_2] época 09/20 — train_loss: 0.0543 acc: 0.9753 | val_loss: 0.1179 acc: 0.9740 | auc: 0.9961
#       [center_2] época 10/20 — train_loss: 0.0284 acc: 0.9883 | val_loss: 0.0782 acc: 0.9844 | auc: 0.9985
#         → mejor época local: 10 | auc: 0.9985
#       [center_2] época 11/20 — train_loss: 0.0301 acc: 0.9922 | val_loss: 0.1066 acc: 0.9740 | auc: 0.9972
#       [center_2] época 12/20 — train_loss: 0.0270 acc: 0.9935 | val_loss: 0.1200 acc: 0.9740 | auc: 0.9967
#       [center_2] época 13/20 — train_loss: 0.0231 acc: 0.9935 | val_loss: 0.1072 acc: 0.9740 | auc: 0.9968
#       [center_2] época 14/20 — train_loss: 0.0221 acc: 0.9935 | val_loss: 0.1135 acc: 0.9740 | auc: 0.9967
#       [center_2] época 15/20 — train_loss: 0.0320 acc: 0.9896 | val_loss: 0.0692 acc: 0.9792 | auc: 0.9985
#       [center_2] época 16/20 — train_loss: 0.0318 acc: 0.9948 | val_loss: 0.0717 acc: 0.9740 | auc: 0.9985
#       [center_2] época 17/20 — train_loss: 0.0363 acc: 0.9883 | val_loss: 0.0711 acc: 0.9792 | auc: 0.9987
#         → mejor época local: 17 | auc: 0.9987
#       [center_2] época 18/20 — train_loss: 0.0100 acc: 0.9961 | val_loss: 0.0807 acc: 0.9740 | auc: 0.9980
#       [center_2] época 19/20 — train_loss: 0.0218 acc: 0.9922 | val_loss: 0.0925 acc: 0.9688 | auc: 0.9978
#       [center_2] época 20/20 — train_loss: 0.0224 acc: 0.9935 | val_loss: 0.0794 acc: 0.9740 | auc: 0.9983
#
#   Centro: center_3
#       [center_3] época 01/20 — train_loss: 0.4191 acc: 0.8346 | val_loss: 0.3897 acc: 0.8815 | auc: 0.9520
#         → mejor época local: 1 | auc: 0.9520
#       [center_3] época 02/20 — train_loss: 0.3098 acc: 0.9118 | val_loss: 0.4532 acc: 0.8889 | auc: 0.9444
#       [center_3] época 03/20 — train_loss: 0.3022 acc: 0.9136 | val_loss: 0.3993 acc: 0.8963 | auc: 0.9504
#       [center_3] época 04/20 — train_loss: 0.2601 acc: 0.9173 | val_loss: 0.4156 acc: 0.8815 | auc: 0.9439
#       [center_3] época 05/20 — train_loss: 0.2808 acc: 0.9338 | val_loss: 0.3068 acc: 0.9037 | auc: 0.9639
#         → mejor época local: 5 | auc: 0.9639
#       [center_3] época 06/20 — train_loss: 0.1768 acc: 0.9504 | val_loss: 0.4362 acc: 0.8815 | auc: 0.9511
#       [center_3] época 07/20 — train_loss: 0.1759 acc: 0.9430 | val_loss: 0.4017 acc: 0.9037 | auc: 0.9532
#       [center_3] época 08/20 — train_loss: 0.2094 acc: 0.9467 | val_loss: 0.3674 acc: 0.9111 | auc: 0.9583
#       [center_3] época 09/20 — train_loss: 0.1930 acc: 0.9412 | val_loss: 0.3567 acc: 0.9037 | auc: 0.9620
#       [center_3] época 10/20 — train_loss: 0.1544 acc: 0.9669 | val_loss: 0.3901 acc: 0.9111 | auc: 0.9601
#       [center_3] época 11/20 — train_loss: 0.2146 acc: 0.9485 | val_loss: 0.3794 acc: 0.9185 | auc: 0.9627
#       [center_3] época 12/20 — train_loss: 0.1734 acc: 0.9504 | val_loss: 0.3579 acc: 0.9111 | auc: 0.9676
#         → mejor época local: 12 | auc: 0.9676
#       [center_3] época 13/20 — train_loss: 0.1737 acc: 0.9596 | val_loss: 0.3307 acc: 0.9333 | auc: 0.9696
#         → mejor época local: 13 | auc: 0.9696
#       [center_3] época 14/20 — train_loss: 0.1220 acc: 0.9724 | val_loss: 0.3880 acc: 0.9259 | auc: 0.9650
#       [center_3] época 15/20 — train_loss: 0.1235 acc: 0.9688 | val_loss: 0.3944 acc: 0.9185 | auc: 0.9657
#       [center_3] época 16/20 — train_loss: 0.1547 acc: 0.9577 | val_loss: 0.3970 acc: 0.9185 | auc: 0.9678
#       [center_3] época 17/20 — train_loss: 0.1484 acc: 0.9614 | val_loss: 0.3562 acc: 0.9185 | auc: 0.9673
#       [center_3] época 18/20 — train_loss: 0.1725 acc: 0.9577 | val_loss: 0.3664 acc: 0.9185 | auc: 0.9650
#       [center_3] época 19/20 — train_loss: 0.1269 acc: 0.9614 | val_loss: 0.3766 acc: 0.9185 | auc: 0.9673
#       [center_3] época 20/20 — train_loss: 0.0846 acc: 0.9779 | val_loss: 0.3922 acc: 0.9259 | auc: 0.9652
#
#   Centro: center_4
#       [center_4] época 01/20 — train_loss: 0.3486 acc: 0.8721 | val_loss: 0.1782 acc: 0.9414 | auc: 0.9893
#         → mejor época local: 1 | auc: 0.9893
#       [center_4] época 02/20 — train_loss: 0.2484 acc: 0.9150 | val_loss: 0.1439 acc: 0.9609 | auc: 0.9893
#       [center_4] época 03/20 — train_loss: 0.2177 acc: 0.9189 | val_loss: 0.1477 acc: 0.9570 | auc: 0.9871
#       [center_4] época 04/20 — train_loss: 0.2090 acc: 0.9355 | val_loss: 0.1476 acc: 0.9570 | auc: 0.9876
#       [center_4] época 05/20 — train_loss: 0.2164 acc: 0.9297 | val_loss: 0.1326 acc: 0.9570 | auc: 0.9896
#         → mejor época local: 5 | auc: 0.9896
#       [center_4] época 06/20 — train_loss: 0.1664 acc: 0.9463 | val_loss: 0.1506 acc: 0.9531 | auc: 0.9841
#       [center_4] época 07/20 — train_loss: 0.1666 acc: 0.9502 | val_loss: 0.1429 acc: 0.9609 | auc: 0.9872
#       [center_4] época 08/20 — train_loss: 0.1642 acc: 0.9473 | val_loss: 0.1256 acc: 0.9531 | auc: 0.9908
#         → mejor época local: 8 | auc: 0.9908
#       [center_4] época 09/20 — train_loss: 0.1253 acc: 0.9580 | val_loss: 0.1284 acc: 0.9688 | auc: 0.9921
#         → mejor época local: 9 | auc: 0.9921
#       [center_4] época 10/20 — train_loss: 0.1701 acc: 0.9521 | val_loss: 0.1246 acc: 0.9727 | auc: 0.9897
#       [center_4] época 11/20 — train_loss: 0.1493 acc: 0.9473 | val_loss: 0.1149 acc: 0.9727 | auc: 0.9905
#       [center_4] época 12/20 — train_loss: 0.0907 acc: 0.9688 | val_loss: 0.1144 acc: 0.9688 | auc: 0.9901
#       [center_4] época 13/20 — train_loss: 0.0796 acc: 0.9717 | val_loss: 0.1348 acc: 0.9727 | auc: 0.9902
#       [center_4] época 14/20 — train_loss: 0.1048 acc: 0.9658 | val_loss: 0.1336 acc: 0.9727 | auc: 0.9879
#       [center_4] época 15/20 — train_loss: 0.0935 acc: 0.9688 | val_loss: 0.1176 acc: 0.9766 | auc: 0.9893
#       [center_4] época 16/20 — train_loss: 0.0965 acc: 0.9678 | val_loss: 0.1263 acc: 0.9766 | auc: 0.9907
#       [center_4] época 17/20 — train_loss: 0.0822 acc: 0.9688 | val_loss: 0.1092 acc: 0.9766 | auc: 0.9911
#       [center_4] época 18/20 — train_loss: 0.0771 acc: 0.9736 | val_loss: 0.1253 acc: 0.9766 | auc: 0.9912
#       [center_4] época 19/20 — train_loss: 0.0902 acc: 0.9736 | val_loss: 0.1128 acc: 0.9727 | auc: 0.9904
#       [center_4] época 20/20 — train_loss: 0.0569 acc: 0.9844 | val_loss: 0.1240 acc: 0.9688 | auc: 0.9904
#
#   ───────────────────────────────────────────────────────
#   Ronda 2 — val_auc global: 0.9946
#   Mejor encoder global guardado (val_auc: 0.9946)
#
# ============================================================
#   RONDA 3/30
# ============================================================
#
#   Centro: center_1
#       [center_1] época 01/20 — train_loss: 0.0342 acc: 0.9901 | val_loss: 0.0136 acc: 0.9967 | auc: 1.0000
#         → mejor época local: 1 | auc: 1.0000
#       [center_1] época 02/20 — train_loss: 0.0263 acc: 0.9922 | val_loss: 0.0137 acc: 0.9934 | auc: 0.9999
#       [center_1] época 03/20 — train_loss: 0.0292 acc: 0.9918 | val_loss: 0.0291 acc: 0.9918 | auc: 0.9998
#       [center_1] época 04/20 — train_loss: 0.0159 acc: 0.9963 | val_loss: 0.0096 acc: 0.9967 | auc: 1.0000
#       [center_1] época 05/20 — train_loss: 0.0249 acc: 0.9963 | val_loss: 0.0108 acc: 0.9967 | auc: 1.0000
#         → mejor época local: 5 | auc: 1.0000
#       [center_1] época 06/20 — train_loss: 0.0168 acc: 0.9963 | val_loss: 0.0377 acc: 0.9901 | auc: 0.9997
#       [center_1] época 07/20 — train_loss: 0.0263 acc: 0.9951 | val_loss: 0.0035 acc: 0.9984 | auc: 1.0000
#       [center_1] época 08/20 — train_loss: 0.0038 acc: 0.9988 | val_loss: 0.0140 acc: 0.9967 | auc: 1.0000
#       [center_1] época 09/20 — train_loss: 0.0114 acc: 0.9967 | val_loss: 0.0044 acc: 0.9967 | auc: 1.0000
#       [center_1] época 10/20 — train_loss: 0.0128 acc: 0.9975 | val_loss: 0.0065 acc: 0.9984 | auc: 1.0000
#         → mejor época local: 10 | auc: 1.0000
#       [center_1] época 11/20 — train_loss: 0.0072 acc: 0.9984 | val_loss: 0.0024 acc: 0.9984 | auc: 1.0000
#       [center_1] época 12/20 — train_loss: 0.0152 acc: 0.9951 | val_loss: 0.0022 acc: 0.9984 | auc: 1.0000
#       [center_1] época 13/20 — train_loss: 0.0019 acc: 0.9996 | val_loss: 0.0064 acc: 0.9967 | auc: 1.0000
#       [center_1] época 14/20 — train_loss: 0.0010 acc: 0.9996 | val_loss: 0.0013 acc: 1.0000 | auc: 1.0000
#       [center_1] época 15/20 — train_loss: 0.0001 acc: 1.0000 | val_loss: 0.0037 acc: 0.9984 | auc: 1.0000
#       [center_1] época 16/20 — train_loss: 0.0064 acc: 0.9988 | val_loss: 0.0010 acc: 1.0000 | auc: 1.0000
#       [center_1] época 17/20 — train_loss: 0.0025 acc: 0.9992 | val_loss: 0.0036 acc: 0.9967 | auc: 1.0000
#       [center_1] época 18/20 — train_loss: 0.0027 acc: 0.9996 | val_loss: 0.0044 acc: 0.9967 | auc: 1.0000
#       [center_1] época 19/20 — train_loss: 0.0015 acc: 0.9992 | val_loss: 0.0058 acc: 0.9967 | auc: 1.0000
#       [center_1] época 20/20 — train_loss: 0.0029 acc: 0.9988 | val_loss: 0.0051 acc: 0.9967 | auc: 1.0000
#
#   Centro: center_2
#       [center_2] época 01/20 — train_loss: 0.1510 acc: 0.9375 | val_loss: 0.0834 acc: 0.9740 | auc: 0.9959
#         → mejor época local: 1 | auc: 0.9959
#       [center_2] época 02/20 — train_loss: 0.1021 acc: 0.9596 | val_loss: 0.0835 acc: 0.9740 | auc: 0.9958
#       [center_2] época 03/20 — train_loss: 0.0847 acc: 0.9701 | val_loss: 0.0978 acc: 0.9740 | auc: 0.9955
#       [center_2] época 04/20 — train_loss: 0.0418 acc: 0.9883 | val_loss: 0.1372 acc: 0.9688 | auc: 0.9897
#       [center_2] época 05/20 — train_loss: 0.0698 acc: 0.9779 | val_loss: 0.1209 acc: 0.9688 | auc: 0.9925
#       [center_2] época 06/20 — train_loss: 0.0432 acc: 0.9844 | val_loss: 0.0527 acc: 0.9896 | auc: 0.9983
#         → mejor época local: 6 | auc: 0.9983
#       [center_2] época 07/20 — train_loss: 0.0400 acc: 0.9831 | val_loss: 0.0834 acc: 0.9740 | auc: 0.9984
#         → mejor época local: 7 | auc: 0.9984
#       [center_2] época 08/20 — train_loss: 0.0161 acc: 0.9935 | val_loss: 0.0811 acc: 0.9740 | auc: 0.9972
#       [center_2] época 09/20 — train_loss: 0.0183 acc: 0.9935 | val_loss: 0.1005 acc: 0.9740 | auc: 0.9952
#       [center_2] época 10/20 — train_loss: 0.0297 acc: 0.9922 | val_loss: 0.1082 acc: 0.9740 | auc: 0.9988
#         → mejor época local: 10 | auc: 0.9988
#       [center_2] época 11/20 — train_loss: 0.0452 acc: 0.9896 | val_loss: 0.0714 acc: 0.9844 | auc: 0.9990
#         → mejor época local: 11 | auc: 0.9990
#       [center_2] época 12/20 — train_loss: 0.0167 acc: 0.9922 | val_loss: 0.0711 acc: 0.9844 | auc: 0.9989
#       [center_2] época 13/20 — train_loss: 0.0190 acc: 0.9948 | val_loss: 0.0886 acc: 0.9740 | auc: 0.9958
#       [center_2] época 14/20 — train_loss: 0.0137 acc: 0.9948 | val_loss: 0.0957 acc: 0.9740 | auc: 0.9968
#       [center_2] época 15/20 — train_loss: 0.0157 acc: 0.9948 | val_loss: 0.0879 acc: 0.9792 | auc: 0.9970
#       [center_2] época 16/20 — train_loss: 0.0116 acc: 0.9974 | val_loss: 0.0784 acc: 0.9844 | auc: 0.9982
#       [center_2] época 17/20 — train_loss: 0.0086 acc: 0.9961 | val_loss: 0.0839 acc: 0.9844 | auc: 0.9968
#       [center_2] época 18/20 — train_loss: 0.0145 acc: 0.9922 | val_loss: 0.0776 acc: 0.9844 | auc: 0.9969
#       [center_2] época 19/20 — train_loss: 0.0030 acc: 0.9987 | val_loss: 0.0809 acc: 0.9792 | auc: 0.9964
#       [center_2] época 20/20 — train_loss: 0.0031 acc: 1.0000 | val_loss: 0.0873 acc: 0.9740 | auc: 0.9963
#
#   Centro: center_3
#       [center_3] época 01/20 — train_loss: 0.3393 acc: 0.8805 | val_loss: 0.2985 acc: 0.9259 | auc: 0.9671
#         → mejor época local: 1 | auc: 0.9671
#       [center_3] época 02/20 — train_loss: 0.2739 acc: 0.9246 | val_loss: 0.4577 acc: 0.8889 | auc: 0.9525
#       [center_3] época 03/20 — train_loss: 0.2739 acc: 0.9246 | val_loss: 0.3559 acc: 0.8963 | auc: 0.9506
#       [center_3] época 04/20 — train_loss: 0.2418 acc: 0.9173 | val_loss: 0.4250 acc: 0.8963 | auc: 0.9592
#       [center_3] época 05/20 — train_loss: 0.2409 acc: 0.9338 | val_loss: 0.4110 acc: 0.9111 | auc: 0.9590
#       [center_3] época 06/20 — train_loss: 0.1925 acc: 0.9338 | val_loss: 0.3880 acc: 0.8963 | auc: 0.9560
#       [center_3] época 07/20 — train_loss: 0.1726 acc: 0.9651 | val_loss: 0.3872 acc: 0.9259 | auc: 0.9608
#       [center_3] época 08/20 — train_loss: 0.1318 acc: 0.9669 | val_loss: 0.4277 acc: 0.9111 | auc: 0.9578
#       [center_3] época 09/20 — train_loss: 0.1456 acc: 0.9540 | val_loss: 0.4316 acc: 0.9185 | auc: 0.9597
#       [center_3] época 10/20 — train_loss: 0.1645 acc: 0.9559 | val_loss: 0.4754 acc: 0.9185 | auc: 0.9608
#       [center_3] época 11/20 — train_loss: 0.1340 acc: 0.9706 | val_loss: 0.5649 acc: 0.8963 | auc: 0.9574
#       [center_3] época 12/20 — train_loss: 0.1925 acc: 0.9596 | val_loss: 0.4793 acc: 0.9037 | auc: 0.9659
#       [center_3] época 13/20 — train_loss: 0.1011 acc: 0.9761 | val_loss: 0.4630 acc: 0.9259 | auc: 0.9657
#       [center_3] época 14/20 — train_loss: 0.1001 acc: 0.9743 | val_loss: 0.5053 acc: 0.9259 | auc: 0.9669
#       [center_3] época 15/20 — train_loss: 0.0771 acc: 0.9779 | val_loss: 0.4749 acc: 0.9259 | auc: 0.9650
#       [center_3] época 16/20 — train_loss: 0.0545 acc: 0.9871 | val_loss: 0.4831 acc: 0.9111 | auc: 0.9650
#       [center_3] época 17/20 — train_loss: 0.1026 acc: 0.9798 | val_loss: 0.4945 acc: 0.9037 | auc: 0.9636
#       [center_3] época 18/20 — train_loss: 0.0494 acc: 0.9908 | val_loss: 0.4948 acc: 0.9111 | auc: 0.9650
#       [center_3] época 19/20 — train_loss: 0.0859 acc: 0.9779 | val_loss: 0.5280 acc: 0.9037 | auc: 0.9641
#       [center_3] época 20/20 — train_loss: 0.1227 acc: 0.9706 | val_loss: 0.5046 acc: 0.9111 | auc: 0.9636
#
#   Centro: center_4
#       [center_4] época 01/20 — train_loss: 0.2854 acc: 0.8984 | val_loss: 0.1731 acc: 0.9297 | auc: 0.9814
#         → mejor época local: 1 | auc: 0.9814
#       [center_4] época 02/20 — train_loss: 0.2200 acc: 0.9297 | val_loss: 0.1569 acc: 0.9609 | auc: 0.9842
#         → mejor época local: 2 | auc: 0.9842
#       [center_4] época 03/20 — train_loss: 0.1938 acc: 0.9326 | val_loss: 0.1140 acc: 0.9688 | auc: 0.9908
#         → mejor época local: 3 | auc: 0.9908
#       [center_4] época 04/20 — train_loss: 0.1658 acc: 0.9473 | val_loss: 0.1459 acc: 0.9531 | auc: 0.9934
#         → mejor época local: 4 | auc: 0.9934
#       [center_4] época 05/20 — train_loss: 0.1643 acc: 0.9463 | val_loss: 0.1041 acc: 0.9531 | auc: 0.9958
#         → mejor época local: 5 | auc: 0.9958
#       [center_4] época 06/20 — train_loss: 0.1277 acc: 0.9590 | val_loss: 0.1260 acc: 0.9609 | auc: 0.9929
#       [center_4] época 07/20 — train_loss: 0.1362 acc: 0.9600 | val_loss: 0.1556 acc: 0.9570 | auc: 0.9902
#       [center_4] época 08/20 — train_loss: 0.1253 acc: 0.9658 | val_loss: 0.1370 acc: 0.9609 | auc: 0.9872
#       [center_4] época 09/20 — train_loss: 0.1186 acc: 0.9600 | val_loss: 0.1337 acc: 0.9609 | auc: 0.9915
#       [center_4] época 10/20 — train_loss: 0.1100 acc: 0.9648 | val_loss: 0.1303 acc: 0.9648 | auc: 0.9913
#       [center_4] época 11/20 — train_loss: 0.1267 acc: 0.9688 | val_loss: 0.1430 acc: 0.9688 | auc: 0.9915
#       [center_4] época 12/20 — train_loss: 0.0870 acc: 0.9756 | val_loss: 0.1183 acc: 0.9766 | auc: 0.9953
#       [center_4] época 13/20 — train_loss: 0.0823 acc: 0.9805 | val_loss: 0.1317 acc: 0.9688 | auc: 0.9944
#       [center_4] época 14/20 — train_loss: 0.0563 acc: 0.9795 | val_loss: 0.1115 acc: 0.9727 | auc: 0.9951
#       [center_4] época 15/20 — train_loss: 0.0868 acc: 0.9766 | val_loss: 0.1150 acc: 0.9727 | auc: 0.9945
#       [center_4] época 16/20 — train_loss: 0.0604 acc: 0.9854 | val_loss: 0.1234 acc: 0.9727 | auc: 0.9948
#       [center_4] época 17/20 — train_loss: 0.0610 acc: 0.9814 | val_loss: 0.1416 acc: 0.9688 | auc: 0.9950
#       [center_4] época 18/20 — train_loss: 0.0842 acc: 0.9756 | val_loss: 0.1451 acc: 0.9648 | auc: 0.9937
#       [center_4] época 19/20 — train_loss: 0.0707 acc: 0.9795 | val_loss: 0.1398 acc: 0.9648 | auc: 0.9944
#       [center_4] época 20/20 — train_loss: 0.0705 acc: 0.9766 | val_loss: 0.1447 acc: 0.9688 | auc: 0.9939
#
#   ───────────────────────────────────────────────────────
#   Ronda 3 — val_auc global: 0.9952
#   Mejor encoder global guardado (val_auc: 0.9952)
#
# ============================================================
#   RONDA 4/30
# ============================================================
#
#   Centro: center_1
#       [center_1] época 01/20 — train_loss: 0.0286 acc: 0.9955 | val_loss: 0.0308 acc: 0.9918 | auc: 1.0000
#         → mejor época local: 1 | auc: 1.0000
#       [center_1] época 02/20 — train_loss: 0.0325 acc: 0.9922 | val_loss: 0.0032 acc: 0.9984 | auc: 1.0000
#       [center_1] época 03/20 — train_loss: 0.0153 acc: 0.9971 | val_loss: 0.0139 acc: 0.9901 | auc: 0.9999
#       [center_1] época 04/20 — train_loss: 0.0272 acc: 0.9934 | val_loss: 0.0175 acc: 0.9951 | auc: 1.0000
#       [center_1] época 05/20 — train_loss: 0.0108 acc: 0.9967 | val_loss: 0.0288 acc: 0.9934 | auc: 0.9999
#       [center_1] época 06/20 — train_loss: 0.0079 acc: 0.9984 | val_loss: 0.0197 acc: 0.9951 | auc: 1.0000
#       [center_1] época 07/20 — train_loss: 0.0109 acc: 0.9971 | val_loss: 0.0145 acc: 0.9967 | auc: 1.0000
#       [center_1] época 08/20 — train_loss: 0.0080 acc: 0.9979 | val_loss: 0.0179 acc: 0.9967 | auc: 0.9999
#       [center_1] época 09/20 — train_loss: 0.0063 acc: 0.9984 | val_loss: 0.0174 acc: 0.9951 | auc: 0.9999
#       [center_1] época 10/20 — train_loss: 0.0153 acc: 0.9959 | val_loss: 0.0066 acc: 0.9984 | auc: 1.0000
#       [center_1] época 11/20 — train_loss: 0.0079 acc: 0.9971 | val_loss: 0.0062 acc: 0.9951 | auc: 1.0000
#       [center_1] época 12/20 — train_loss: 0.0097 acc: 0.9984 | val_loss: 0.0052 acc: 0.9984 | auc: 1.0000
#       [center_1] época 13/20 — train_loss: 0.0009 acc: 0.9996 | val_loss: 0.0030 acc: 0.9984 | auc: 1.0000
#       [center_1] época 14/20 — train_loss: 0.0043 acc: 0.9996 | val_loss: 0.0026 acc: 0.9984 | auc: 1.0000
#       [center_1] época 15/20 — train_loss: 0.0040 acc: 0.9992 | val_loss: 0.0043 acc: 0.9984 | auc: 1.0000
#       [center_1] época 16/20 — train_loss: 0.0038 acc: 0.9992 | val_loss: 0.0032 acc: 0.9984 | auc: 1.0000
#       [center_1] época 17/20 — train_loss: 0.0073 acc: 0.9992 | val_loss: 0.0039 acc: 0.9984 | auc: 1.0000
#       [center_1] época 18/20 — train_loss: 0.0016 acc: 0.9996 | val_loss: 0.0036 acc: 0.9984 | auc: 1.0000
#       [center_1] época 19/20 — train_loss: 0.0034 acc: 0.9988 | val_loss: 0.0029 acc: 0.9984 | auc: 1.0000
#       [center_1] época 20/20 — train_loss: 0.0050 acc: 0.9988 | val_loss: 0.0039 acc: 0.9984 | auc: 1.0000
#
#   Centro: center_2
#       [center_2] época 01/20 — train_loss: 0.1187 acc: 0.9609 | val_loss: 0.0753 acc: 0.9688 | auc: 0.9975
#         → mejor época local: 1 | auc: 0.9975
#       [center_2] época 02/20 — train_loss: 0.0615 acc: 0.9753 | val_loss: 0.1394 acc: 0.9635 | auc: 0.9959
#       [center_2] época 03/20 — train_loss: 0.0573 acc: 0.9779 | val_loss: 0.0375 acc: 0.9844 | auc: 0.9994
#         → mejor época local: 3 | auc: 0.9994
#       [center_2] época 04/20 — train_loss: 0.0197 acc: 0.9961 | val_loss: 0.0665 acc: 0.9792 | auc: 0.9989
#       [center_2] época 05/20 — train_loss: 0.0281 acc: 0.9909 | val_loss: 0.0692 acc: 0.9740 | auc: 0.9984
#       [center_2] época 06/20 — train_loss: 0.0375 acc: 0.9844 | val_loss: 0.0730 acc: 0.9844 | auc: 0.9987
#       [center_2] época 07/20 — train_loss: 0.0443 acc: 0.9844 | val_loss: 0.0707 acc: 0.9844 | auc: 0.9987
#       [center_2] época 08/20 — train_loss: 0.0122 acc: 0.9961 | val_loss: 0.0793 acc: 0.9792 | auc: 0.9990
#       [center_2] época 09/20 — train_loss: 0.0289 acc: 0.9922 | val_loss: 0.1583 acc: 0.9688 | auc: 0.9925
#       [center_2] época 10/20 — train_loss: 0.0238 acc: 0.9935 | val_loss: 0.0894 acc: 0.9792 | auc: 0.9987
#       [center_2] época 11/20 — train_loss: 0.0475 acc: 0.9896 | val_loss: 0.0864 acc: 0.9844 | auc: 0.9990
#       [center_2] época 12/20 — train_loss: 0.0051 acc: 0.9987 | val_loss: 0.0787 acc: 0.9844 | auc: 0.9985
#       [center_2] época 13/20 — train_loss: 0.0281 acc: 0.9935 | val_loss: 0.0801 acc: 0.9844 | auc: 0.9982
#       [center_2] época 14/20 — train_loss: 0.0059 acc: 0.9987 | val_loss: 0.0971 acc: 0.9844 | auc: 0.9973
#       [center_2] época 15/20 — train_loss: 0.0085 acc: 0.9974 | val_loss: 0.0835 acc: 0.9792 | auc: 0.9990
#       [center_2] época 16/20 — train_loss: 0.0082 acc: 0.9948 | val_loss: 0.0858 acc: 0.9844 | auc: 0.9989
#       [center_2] época 17/20 — train_loss: 0.0159 acc: 0.9961 | val_loss: 0.0754 acc: 0.9844 | auc: 0.9990
#       [center_2] época 18/20 — train_loss: 0.0091 acc: 0.9974 | val_loss: 0.0918 acc: 0.9844 | auc: 0.9981
#       [center_2] época 19/20 — train_loss: 0.0107 acc: 0.9961 | val_loss: 0.1074 acc: 0.9844 | auc: 0.9971
#       [center_2] época 20/20 — train_loss: 0.0063 acc: 0.9961 | val_loss: 0.0909 acc: 0.9844 | auc: 0.9974
#
#   Centro: center_3
#       [center_3] época 01/20 — train_loss: 0.3581 acc: 0.8768 | val_loss: 0.2751 acc: 0.9259 | auc: 0.9606
#         → mejor época local: 1 | auc: 0.9606
#       [center_3] época 02/20 — train_loss: 0.2357 acc: 0.9283 | val_loss: 0.3439 acc: 0.9037 | auc: 0.9604
#       [center_3] época 03/20 — train_loss: 0.2562 acc: 0.9412 | val_loss: 0.3603 acc: 0.9037 | auc: 0.9608
#         → mejor época local: 3 | auc: 0.9608
#       [center_3] época 04/20 — train_loss: 0.2261 acc: 0.9375 | val_loss: 0.3029 acc: 0.9185 | auc: 0.9648
#         → mejor época local: 4 | auc: 0.9648
#       [center_3] época 05/20 — train_loss: 0.1846 acc: 0.9430 | val_loss: 0.3772 acc: 0.9333 | auc: 0.9641
#       [center_3] época 06/20 — train_loss: 0.1810 acc: 0.9449 | val_loss: 0.4323 acc: 0.9185 | auc: 0.9636
#       [center_3] época 07/20 — train_loss: 0.1450 acc: 0.9596 | val_loss: 0.4415 acc: 0.9259 | auc: 0.9634
#       [center_3] época 08/20 — train_loss: 0.1119 acc: 0.9706 | val_loss: 0.5226 acc: 0.9185 | auc: 0.9592
#       [center_3] época 09/20 — train_loss: 0.1442 acc: 0.9669 | val_loss: 0.4458 acc: 0.9185 | auc: 0.9646
#       [center_3] época 10/20 — train_loss: 0.1501 acc: 0.9632 | val_loss: 0.4720 acc: 0.9185 | auc: 0.9639
#       [center_3] época 11/20 — train_loss: 0.1211 acc: 0.9651 | val_loss: 0.4495 acc: 0.9185 | auc: 0.9662
#         → mejor época local: 11 | auc: 0.9662
#       [center_3] época 12/20 — train_loss: 0.1278 acc: 0.9798 | val_loss: 0.4745 acc: 0.9111 | auc: 0.9676
#         → mejor época local: 12 | auc: 0.9676
#       [center_3] época 13/20 — train_loss: 0.0980 acc: 0.9761 | val_loss: 0.4285 acc: 0.9259 | auc: 0.9669
#       [center_3] época 14/20 — train_loss: 0.0712 acc: 0.9853 | val_loss: 0.4468 acc: 0.9185 | auc: 0.9680
#         → mejor época local: 14 | auc: 0.9680
#       [center_3] época 15/20 — train_loss: 0.0826 acc: 0.9743 | val_loss: 0.4507 acc: 0.9259 | auc: 0.9671
#       [center_3] época 16/20 — train_loss: 0.1422 acc: 0.9706 | val_loss: 0.4557 acc: 0.9259 | auc: 0.9652
#       [center_3] época 17/20 — train_loss: 0.0954 acc: 0.9798 | val_loss: 0.4549 acc: 0.9259 | auc: 0.9657
#       [center_3] época 18/20 — train_loss: 0.0721 acc: 0.9779 | val_loss: 0.4812 acc: 0.9185 | auc: 0.9646
#       [center_3] época 19/20 — train_loss: 0.0880 acc: 0.9798 | val_loss: 0.4621 acc: 0.9259 | auc: 0.9659
#       [center_3] época 20/20 — train_loss: 0.0973 acc: 0.9835 | val_loss: 0.4799 acc: 0.9259 | auc: 0.9662
#
#   Centro: center_4
#       [center_4] época 01/20 — train_loss: 0.2461 acc: 0.9229 | val_loss: 0.1661 acc: 0.9414 | auc: 0.9816
#         → mejor época local: 1 | auc: 0.9816
#       [center_4] época 02/20 — train_loss: 0.2207 acc: 0.9268 | val_loss: 0.1342 acc: 0.9648 | auc: 0.9867
#         → mejor época local: 2 | auc: 0.9867
#       [center_4] época 03/20 — train_loss: 0.1609 acc: 0.9492 | val_loss: 0.1246 acc: 0.9609 | auc: 0.9902
#         → mejor época local: 3 | auc: 0.9902
#       [center_4] época 04/20 — train_loss: 0.1639 acc: 0.9512 | val_loss: 0.1311 acc: 0.9414 | auc: 0.9933
#         → mejor época local: 4 | auc: 0.9933
#       [center_4] época 05/20 — train_loss: 0.1417 acc: 0.9580 | val_loss: 0.1296 acc: 0.9453 | auc: 0.9921
#       [center_4] época 06/20 — train_loss: 0.1653 acc: 0.9531 | val_loss: 0.1540 acc: 0.9531 | auc: 0.9878
#       [center_4] época 07/20 — train_loss: 0.0954 acc: 0.9707 | val_loss: 0.1443 acc: 0.9570 | auc: 0.9904
#       [center_4] época 08/20 — train_loss: 0.1023 acc: 0.9697 | val_loss: 0.1316 acc: 0.9570 | auc: 0.9929
#       [center_4] época 09/20 — train_loss: 0.0754 acc: 0.9736 | val_loss: 0.1206 acc: 0.9688 | auc: 0.9931
#       [center_4] época 10/20 — train_loss: 0.0815 acc: 0.9756 | val_loss: 0.1511 acc: 0.9648 | auc: 0.9893
#       [center_4] época 11/20 — train_loss: 0.0952 acc: 0.9756 | val_loss: 0.1220 acc: 0.9609 | auc: 0.9923
#       [center_4] época 12/20 — train_loss: 0.0878 acc: 0.9785 | val_loss: 0.1276 acc: 0.9648 | auc: 0.9912
#       [center_4] época 13/20 — train_loss: 0.0578 acc: 0.9785 | val_loss: 0.1385 acc: 0.9648 | auc: 0.9928
#       [center_4] época 14/20 — train_loss: 0.0942 acc: 0.9775 | val_loss: 0.1568 acc: 0.9648 | auc: 0.9920
#       [center_4] época 15/20 — train_loss: 0.0370 acc: 0.9863 | val_loss: 0.1779 acc: 0.9609 | auc: 0.9915
#       [center_4] época 16/20 — train_loss: 0.0428 acc: 0.9834 | val_loss: 0.1555 acc: 0.9570 | auc: 0.9926
#       [center_4] época 17/20 — train_loss: 0.0595 acc: 0.9814 | val_loss: 0.1748 acc: 0.9570 | auc: 0.9904
#       [center_4] época 18/20 — train_loss: 0.0616 acc: 0.9863 | val_loss: 0.1757 acc: 0.9570 | auc: 0.9910
#       [center_4] época 19/20 — train_loss: 0.0751 acc: 0.9775 | val_loss: 0.1676 acc: 0.9570 | auc: 0.9910
#       [center_4] época 20/20 — train_loss: 0.0687 acc: 0.9746 | val_loss: 0.1836 acc: 0.9570 | auc: 0.9919
#
#   ───────────────────────────────────────────────────────
#   Ronda 4 — val_auc global: 0.9948
#   Sin mejora 1/10
#
# ============================================================
#   RONDA 5/30
# ============================================================
#
#   Centro: center_1
#       [center_1] época 01/20 — train_loss: 0.0226 acc: 0.9938 | val_loss: 0.0197 acc: 0.9967 | auc: 1.0000
#         → mejor época local: 1 | auc: 1.0000
#       [center_1] época 02/20 — train_loss: 0.0215 acc: 0.9942 | val_loss: 0.0129 acc: 0.9967 | auc: 1.0000
#       [center_1] época 03/20 — train_loss: 0.0168 acc: 0.9967 | val_loss: 0.0033 acc: 0.9984 | auc: 1.0000
#         → mejor época local: 3 | auc: 1.0000
#       [center_1] época 04/20 — train_loss: 0.0119 acc: 0.9967 | val_loss: 0.0039 acc: 0.9967 | auc: 1.0000
#         → mejor época local: 4 | auc: 1.0000
#       [center_1] época 05/20 — train_loss: 0.0189 acc: 0.9963 | val_loss: 0.0127 acc: 0.9934 | auc: 1.0000
#       [center_1] época 06/20 — train_loss: 0.0080 acc: 0.9988 | val_loss: 0.0125 acc: 0.9951 | auc: 1.0000
#       [center_1] época 07/20 — train_loss: 0.0110 acc: 0.9971 | val_loss: 0.0070 acc: 0.9967 | auc: 1.0000
#       [center_1] época 08/20 — train_loss: 0.0018 acc: 0.9992 | val_loss: 0.0059 acc: 0.9967 | auc: 1.0000
#       [center_1] época 09/20 — train_loss: 0.0133 acc: 0.9975 | val_loss: 0.0072 acc: 0.9984 | auc: 1.0000
#       [center_1] época 10/20 — train_loss: 0.0087 acc: 0.9984 | val_loss: 0.0105 acc: 0.9984 | auc: 1.0000
#       [center_1] época 11/20 — train_loss: 0.0074 acc: 0.9984 | val_loss: 0.0099 acc: 0.9984 | auc: 1.0000
#       [center_1] época 12/20 — train_loss: 0.0069 acc: 0.9992 | val_loss: 0.0096 acc: 0.9984 | auc: 1.0000
#       [center_1] época 13/20 — train_loss: 0.0066 acc: 0.9984 | val_loss: 0.0136 acc: 0.9984 | auc: 1.0000
#       [center_1] época 14/20 — train_loss: 0.0005 acc: 1.0000 | val_loss: 0.0131 acc: 0.9984 | auc: 0.9999
#       [center_1] época 15/20 — train_loss: 0.0012 acc: 0.9996 | val_loss: 0.0185 acc: 0.9984 | auc: 0.9997
#       [center_1] época 16/20 — train_loss: 0.0066 acc: 0.9992 | val_loss: 0.0127 acc: 0.9984 | auc: 1.0000
#       [center_1] época 17/20 — train_loss: 0.0001 acc: 1.0000 | val_loss: 0.0099 acc: 0.9984 | auc: 1.0000
#       [center_1] época 18/20 — train_loss: 0.0029 acc: 0.9992 | val_loss: 0.0127 acc: 0.9984 | auc: 1.0000
#       [center_1] época 19/20 — train_loss: 0.0007 acc: 0.9996 | val_loss: 0.0099 acc: 0.9984 | auc: 1.0000
#       [center_1] época 20/20 — train_loss: 0.0019 acc: 0.9996 | val_loss: 0.0135 acc: 0.9984 | auc: 1.0000
#
#   Centro: center_2
#       [center_2] época 01/20 — train_loss: 0.0750 acc: 0.9766 | val_loss: 0.1173 acc: 0.9479 | auc: 0.9952
#         → mejor época local: 1 | auc: 0.9952
#       [center_2] época 02/20 — train_loss: 0.0785 acc: 0.9779 | val_loss: 0.0891 acc: 0.9688 | auc: 0.9987
#         → mejor época local: 2 | auc: 0.9987
#       [center_2] época 03/20 — train_loss: 0.0658 acc: 0.9857 | val_loss: 0.0796 acc: 0.9688 | auc: 0.9977
#       [center_2] época 04/20 — train_loss: 0.0439 acc: 0.9857 | val_loss: 0.1663 acc: 0.9635 | auc: 0.9900
#       [center_2] época 05/20 — train_loss: 0.0219 acc: 0.9922 | val_loss: 0.0757 acc: 0.9792 | auc: 0.9987
#       [center_2] época 06/20 — train_loss: 0.0227 acc: 0.9909 | val_loss: 0.0648 acc: 0.9896 | auc: 0.9981
#       [center_2] época 07/20 — train_loss: 0.0123 acc: 0.9948 | val_loss: 0.1023 acc: 0.9844 | auc: 0.9927
#       [center_2] época 08/20 — train_loss: 0.0103 acc: 0.9935 | val_loss: 0.1322 acc: 0.9792 | auc: 0.9891
#       [center_2] época 09/20 — train_loss: 0.0215 acc: 0.9961 | val_loss: 0.0909 acc: 0.9844 | auc: 0.9950
#       [center_2] época 10/20 — train_loss: 0.0415 acc: 0.9909 | val_loss: 0.1992 acc: 0.9740 | auc: 0.9856
#       [center_2] época 11/20 — train_loss: 0.0125 acc: 0.9948 | val_loss: 0.0849 acc: 0.9844 | auc: 0.9981
#       [center_2] época 12/20 — train_loss: 0.0170 acc: 0.9948 | val_loss: 0.1515 acc: 0.9792 | auc: 0.9890
#       [center_2] época 13/20 — train_loss: 0.0292 acc: 0.9922 | val_loss: 0.1160 acc: 0.9792 | auc: 0.9943
#       [center_2] época 14/20 — train_loss: 0.0254 acc: 0.9961 | val_loss: 0.1531 acc: 0.9844 | auc: 0.9887
#       [center_2] época 15/20 — train_loss: 0.0147 acc: 0.9961 | val_loss: 0.1371 acc: 0.9844 | auc: 0.9891
#       [center_2] época 16/20 — train_loss: 0.0090 acc: 0.9961 | val_loss: 0.1304 acc: 0.9844 | auc: 0.9905
#       [center_2] época 17/20 — train_loss: 0.0123 acc: 0.9948 | val_loss: 0.1590 acc: 0.9844 | auc: 0.9893
#       [center_2] época 18/20 — train_loss: 0.0054 acc: 0.9974 | val_loss: 0.1319 acc: 0.9844 | auc: 0.9886
#       [center_2] época 19/20 — train_loss: 0.0195 acc: 0.9922 | val_loss: 0.1396 acc: 0.9844 | auc: 0.9901
#       [center_2] época 20/20 — train_loss: 0.0139 acc: 0.9948 | val_loss: 0.1443 acc: 0.9844 | auc: 0.9893
#
#   Centro: center_3
#       [center_3] época 01/20 — train_loss: 0.2936 acc: 0.9246 | val_loss: 0.3870 acc: 0.9037 | auc: 0.9636
#         → mejor época local: 1 | auc: 0.9636
#       [center_3] época 02/20 — train_loss: 0.2239 acc: 0.9485 | val_loss: 0.4158 acc: 0.8963 | auc: 0.9599
#       [center_3] época 03/20 — train_loss: 0.2002 acc: 0.9412 | val_loss: 0.3392 acc: 0.9185 | auc: 0.9646
#         → mejor época local: 3 | auc: 0.9646
#       [center_3] época 04/20 — train_loss: 0.2085 acc: 0.9485 | val_loss: 0.3928 acc: 0.9259 | auc: 0.9659
#         → mejor época local: 4 | auc: 0.9659
#       [center_3] época 05/20 — train_loss: 0.1775 acc: 0.9559 | val_loss: 0.3843 acc: 0.9259 | auc: 0.9627
#       [center_3] época 06/20 — train_loss: 0.1743 acc: 0.9596 | val_loss: 0.3970 acc: 0.9185 | auc: 0.9611
#       [center_3] época 07/20 — train_loss: 0.1725 acc: 0.9614 | val_loss: 0.4534 acc: 0.9111 | auc: 0.9652
#       [center_3] época 08/20 — train_loss: 0.1319 acc: 0.9706 | val_loss: 0.4574 acc: 0.9185 | auc: 0.9676
#         → mejor época local: 8 | auc: 0.9676
#       [center_3] época 09/20 — train_loss: 0.1604 acc: 0.9577 | val_loss: 0.5020 acc: 0.9111 | auc: 0.9659
#       [center_3] época 10/20 — train_loss: 0.1068 acc: 0.9706 | val_loss: 0.4792 acc: 0.9185 | auc: 0.9664
#       [center_3] época 11/20 — train_loss: 0.1263 acc: 0.9669 | val_loss: 0.5341 acc: 0.9185 | auc: 0.9671
#       [center_3] época 12/20 — train_loss: 0.1238 acc: 0.9743 | val_loss: 0.5439 acc: 0.9111 | auc: 0.9632
#       [center_3] época 13/20 — train_loss: 0.1110 acc: 0.9743 | val_loss: 0.5595 acc: 0.9185 | auc: 0.9555
#       [center_3] época 14/20 — train_loss: 0.1165 acc: 0.9669 | val_loss: 0.5821 acc: 0.9037 | auc: 0.9557
#       [center_3] época 15/20 — train_loss: 0.0735 acc: 0.9743 | val_loss: 0.5369 acc: 0.9111 | auc: 0.9625
#       [center_3] época 16/20 — train_loss: 0.0551 acc: 0.9835 | val_loss: 0.5262 acc: 0.9111 | auc: 0.9632
#       [center_3] época 17/20 — train_loss: 0.1002 acc: 0.9743 | val_loss: 0.5871 acc: 0.9185 | auc: 0.9650
#       [center_3] época 18/20 — train_loss: 0.0940 acc: 0.9798 | val_loss: 0.5898 acc: 0.9185 | auc: 0.9615
#       [center_3] época 19/20 — train_loss: 0.0620 acc: 0.9871 | val_loss: 0.5660 acc: 0.9111 | auc: 0.9620
#       [center_3] época 20/20 — train_loss: 0.1086 acc: 0.9761 | val_loss: 0.5632 acc: 0.9185 | auc: 0.9597
#
#   Centro: center_4
#       [center_4] época 01/20 — train_loss: 0.2190 acc: 0.9316 | val_loss: 0.1090 acc: 0.9648 | auc: 0.9915
#         → mejor época local: 1 | auc: 0.9915
#       [center_4] época 02/20 — train_loss: 0.1741 acc: 0.9385 | val_loss: 0.1735 acc: 0.9375 | auc: 0.9850
#       [center_4] época 03/20 — train_loss: 0.1747 acc: 0.9385 | val_loss: 0.1188 acc: 0.9609 | auc: 0.9917
#         → mejor época local: 3 | auc: 0.9917
#       [center_4] época 04/20 — train_loss: 0.1624 acc: 0.9492 | val_loss: 0.1299 acc: 0.9648 | auc: 0.9897
#       [center_4] época 05/20 — train_loss: 0.1191 acc: 0.9658 | val_loss: 0.1336 acc: 0.9648 | auc: 0.9922
#         → mejor época local: 5 | auc: 0.9922
#       [center_4] época 06/20 — train_loss: 0.1180 acc: 0.9639 | val_loss: 0.1529 acc: 0.9609 | auc: 0.9872
#       [center_4] época 07/20 — train_loss: 0.0977 acc: 0.9736 | val_loss: 0.1789 acc: 0.9648 | auc: 0.9895
#       [center_4] época 08/20 — train_loss: 0.1108 acc: 0.9736 | val_loss: 0.1121 acc: 0.9688 | auc: 0.9936
#         → mejor época local: 8 | auc: 0.9936
#       [center_4] época 09/20 — train_loss: 0.0737 acc: 0.9775 | val_loss: 0.1595 acc: 0.9609 | auc: 0.9905
#       [center_4] época 10/20 — train_loss: 0.0846 acc: 0.9795 | val_loss: 0.1661 acc: 0.9648 | auc: 0.9907
#       [center_4] época 11/20 — train_loss: 0.0815 acc: 0.9756 | val_loss: 0.1704 acc: 0.9648 | auc: 0.9915
#       [center_4] época 12/20 — train_loss: 0.0564 acc: 0.9844 | val_loss: 0.1798 acc: 0.9648 | auc: 0.9915
# ...
#       [center_2] época 06/20 — train_loss: 0.0149 acc: 0.9961 | val_loss: 0.0825 acc: 0.9792 | auc: 0.9997
#         → mejor época local: 6 | auc: 0.9997
#       [center_2] época 07/20 — train_loss: 0.0240 acc: 0.9961 | val_loss: 0.0823 acc: 0.9844 | auc: 0.9991
#       [center_2] época 08/20 — train_loss: 0.0004 acc: 1.0000 | val_loss: 0.0927 acc: 0.9896 | auc: 0.9977
#       [center_2] época 09/20 — train_loss: 0.0007 acc: 1.0000 | val_loss: 0.1107 acc: 0.9896 | auc: 0.9922
#       [center_2] época 10/20 — train_loss: 0.0000 acc: 1.0000 | val_loss: 0.1192 acc: 0.9896 | auc: 0.9922
#       [center_2] época 11/20 — train_loss: 0.0002 acc: 1.0000 | val_loss: 0.1576 acc: 0.9844 | auc: 0.9927
#       [center_2] época 12/20 — train_loss: 0.0009 acc: 1.0000 | val_loss: 0.0978 acc: 0.9896 | auc: 0.9990
#       [center_2] época 13/20 — train_loss: 0.0058 acc: 0.9987 | val_loss: 0.0900 acc: 0.9896 | auc: 0.9987
#       [center_2] época 14/20 — train_loss: 0.0022 acc: 0.9987 | val_loss: 0.0879 acc: 0.9896 | auc: 0.9985
#       [center_2] época 15/20 — train_loss: 0.0266 acc: 0.9948 | val_loss: 0.0860 acc: 0.9896 | auc: 0.9994
#       [center_2] época 16/20 — train_loss: 0.0263 acc: 0.9948 | val_loss: 0.1141 acc: 0.9844 | auc: 0.9924
#       [center_2] época 17/20 — train_loss: 0.0106 acc: 0.9987 | val_loss: 0.1075 acc: 0.9844 | auc: 0.9980
#       [center_2] época 18/20 — train_loss: 0.0009 acc: 1.0000 | val_loss: 0.1074 acc: 0.9844 | auc: 0.9980
#       [center_2] época 19/20 — train_loss: 0.0186 acc: 0.9961 | val_loss: 0.1152 acc: 0.9844 | auc: 0.9924
#       [center_2] época 20/20 — train_loss: 0.0016 acc: 1.0000 | val_loss: 0.1088 acc: 0.9844 | auc: 0.9978
#
#   Centro: center_3
#       [center_3] época 01/20 — train_loss: 0.0514 acc: 0.9871 | val_loss: 0.7472 acc: 0.9185 | auc: 0.9754
#         → mejor época local: 1 | auc: 0.9754
#       [center_3] época 02/20 — train_loss: 0.0304 acc: 0.9963 | val_loss: 0.8954 acc: 0.9185 | auc: 0.9641
#       [center_3] época 03/20 — train_loss: 0.0292 acc: 0.9926 | val_loss: 0.9155 acc: 0.9259 | auc: 0.9599
#       [center_3] época 04/20 — train_loss: 0.0859 acc: 0.9908 | val_loss: 0.8147 acc: 0.9185 | auc: 0.9801
#         → mejor época local: 4 | auc: 0.9801
#       [center_3] época 05/20 — train_loss: 0.0587 acc: 0.9908 | val_loss: 0.7067 acc: 0.9333 | auc: 0.9866
#         → mejor época local: 5 | auc: 0.9866
#       [center_3] época 06/20 — train_loss: 0.0194 acc: 0.9945 | val_loss: 0.7361 acc: 0.9333 | auc: 0.9840
#       [center_3] época 07/20 — train_loss: 0.0352 acc: 0.9908 | val_loss: 0.8042 acc: 0.9259 | auc: 0.9723
#       [center_3] época 08/20 — train_loss: 0.0068 acc: 0.9982 | val_loss: 0.8553 acc: 0.9259 | auc: 0.9688
#       [center_3] época 09/20 — train_loss: 0.0117 acc: 0.9963 | val_loss: 0.7306 acc: 0.9111 | auc: 0.9678
#       [center_3] época 10/20 — train_loss: 0.0677 acc: 0.9908 | val_loss: 0.8101 acc: 0.9111 | auc: 0.9714
#       [center_3] época 11/20 — train_loss: 0.0393 acc: 0.9908 | val_loss: 0.7456 acc: 0.9333 | auc: 0.9787
#       [center_3] época 12/20 — train_loss: 0.0278 acc: 0.9926 | val_loss: 0.7272 acc: 0.9333 | auc: 0.9880
#         → mejor época local: 12 | auc: 0.9880
#       [center_3] época 13/20 — train_loss: 0.0231 acc: 0.9963 | val_loss: 0.7407 acc: 0.9185 | auc: 0.9845
#       [center_3] época 14/20 — train_loss: 0.0448 acc: 0.9908 | val_loss: 0.7407 acc: 0.9185 | auc: 0.9840
#       [center_3] época 15/20 — train_loss: 0.0197 acc: 0.9963 | val_loss: 0.7332 acc: 0.9185 | auc: 0.9845
#       [center_3] época 16/20 — train_loss: 0.0041 acc: 0.9982 | val_loss: 0.7350 acc: 0.9185 | auc: 0.9829
#       [center_3] época 17/20 — train_loss: 0.0300 acc: 0.9963 | val_loss: 0.7366 acc: 0.9185 | auc: 0.9849
#       [center_3] época 18/20 — train_loss: 0.0133 acc: 0.9982 | val_loss: 0.7613 acc: 0.9185 | auc: 0.9859
#       [center_3] época 19/20 — train_loss: 0.0296 acc: 0.9945 | val_loss: 0.7213 acc: 0.9259 | auc: 0.9824
#       [center_3] época 20/20 — train_loss: 0.0072 acc: 0.9963 | val_loss: 0.7282 acc: 0.9185 | auc: 0.9832
#
#   Centro: center_4
#       [center_4] época 01/20 — train_loss: 0.0454 acc: 0.9873 | val_loss: 0.2186 acc: 0.9688 | auc: 0.9948
#         → mejor época local: 1 | auc: 0.9948
#       [center_4] época 02/20 — train_loss: 0.0035 acc: 0.9990 | val_loss: 0.2917 acc: 0.9648 | auc: 0.9917
#       [center_4] época 03/20 — train_loss: 0.0178 acc: 0.9932 | val_loss: 0.1828 acc: 0.9727 | auc: 0.9964
#         → mejor época local: 3 | auc: 0.9964
#       [center_4] época 04/20 — train_loss: 0.0553 acc: 0.9902 | val_loss: 0.1745 acc: 0.9727 | auc: 0.9948
#       [center_4] época 05/20 — train_loss: 0.0302 acc: 0.9951 | val_loss: 0.2496 acc: 0.9648 | auc: 0.9909
#       [center_4] época 06/20 — train_loss: 0.0155 acc: 0.9971 | val_loss: 0.2203 acc: 0.9688 | auc: 0.9967
#         → mejor época local: 6 | auc: 0.9967
#       [center_4] época 07/20 — train_loss: 0.0256 acc: 0.9961 | val_loss: 0.3311 acc: 0.9727 | auc: 0.9917
#       [center_4] época 08/20 — train_loss: 0.0170 acc: 0.9961 | val_loss: 0.2318 acc: 0.9688 | auc: 0.9953
#       [center_4] época 09/20 — train_loss: 0.0118 acc: 0.9961 | val_loss: 0.3079 acc: 0.9648 | auc: 0.9907
#       [center_4] época 10/20 — train_loss: 0.0176 acc: 0.9961 | val_loss: 0.3279 acc: 0.9648 | auc: 0.9937
#       [center_4] época 11/20 — train_loss: 0.0191 acc: 0.9951 | val_loss: 0.2413 acc: 0.9648 | auc: 0.9968
#         → mejor época local: 11 | auc: 0.9968
#       [center_4] época 12/20 — train_loss: 0.0134 acc: 0.9932 | val_loss: 0.2988 acc: 0.9648 | auc: 0.9903
#       [center_4] época 13/20 — train_loss: 0.0187 acc: 0.9951 | val_loss: 0.2619 acc: 0.9609 | auc: 0.9916
#       [center_4] época 14/20 — train_loss: 0.0237 acc: 0.9941 | val_loss: 0.2445 acc: 0.9688 | auc: 0.9951
#       [center_4] época 15/20 — train_loss: 0.0097 acc: 0.9980 | val_loss: 0.2419 acc: 0.9609 | auc: 0.9958
#       [center_4] época 16/20 — train_loss: 0.0185 acc: 0.9932 | val_loss: 0.2397 acc: 0.9688 | auc: 0.9959
#       [center_4] época 17/20 — train_loss: 0.0148 acc: 0.9971 | val_loss: 0.2605 acc: 0.9648 | auc: 0.9912
#       [center_4] época 18/20 — train_loss: 0.0084 acc: 0.9971 | val_loss: 0.2681 acc: 0.9648 | auc: 0.9917
#       [center_4] época 19/20 — train_loss: 0.0039 acc: 0.9990 | val_loss: 0.2720 acc: 0.9648 | auc: 0.9916
#       [center_4] época 20/20 — train_loss: 0.0207 acc: 0.9941 | val_loss: 0.2790 acc: 0.9688 | auc: 0.9912
#
#   ───────────────────────────────────────────────────────
#   Ronda 29 — val_auc global: 0.9979
#   Sin mejora 3/10
#
# ============================================================
#   RONDA 30/30
# ============================================================
#
#   Centro: center_1
#       [center_1] época 01/20 — train_loss: 0.0025 acc: 0.9988 | val_loss: 0.0000 acc: 1.0000 | auc: 1.0000
#         → mejor época local: 1 | auc: 1.0000
#       [center_1] época 02/20 — train_loss: 0.0192 acc: 0.9963 | val_loss: 0.0030 acc: 0.9984 | auc: 1.0000
#       [center_1] época 03/20 — train_loss: 0.0033 acc: 0.9988 | val_loss: 0.0000 acc: 1.0000 | auc: 1.0000
#       [center_1] época 04/20 — train_loss: 0.0019 acc: 0.9992 | val_loss: 0.0048 acc: 0.9984 | auc: 1.0000
#       [center_1] época 05/20 — train_loss: 0.0110 acc: 0.9984 | val_loss: 0.0011 acc: 1.0000 | auc: 1.0000
#       [center_1] época 06/20 — train_loss: 0.0035 acc: 0.9992 | val_loss: 0.0005 acc: 1.0000 | auc: 1.0000
#       [center_1] época 07/20 — train_loss: 0.0097 acc: 0.9992 | val_loss: 0.0001 acc: 1.0000 | auc: 1.0000
#       [center_1] época 08/20 — train_loss: 0.0001 acc: 1.0000 | val_loss: 0.0055 acc: 0.9967 | auc: 1.0000
#       [center_1] época 09/20 — train_loss: 0.0146 acc: 0.9979 | val_loss: 0.0022 acc: 1.0000 | auc: 1.0000
#       [center_1] época 10/20 — train_loss: 0.0012 acc: 0.9996 | val_loss: 0.0000 acc: 1.0000 | auc: 1.0000
#       [center_1] época 11/20 — train_loss: 0.0018 acc: 0.9996 | val_loss: 0.0002 acc: 1.0000 | auc: 1.0000
#       [center_1] época 12/20 — train_loss: 0.0069 acc: 0.9988 | val_loss: 0.0010 acc: 1.0000 | auc: 1.0000
#       [center_1] época 13/20 — train_loss: 0.0076 acc: 0.9992 | val_loss: 0.0001 acc: 1.0000 | auc: 1.0000
#       [center_1] época 14/20 — train_loss: 0.0005 acc: 0.9996 | val_loss: 0.0000 acc: 1.0000 | auc: 1.0000
#       [center_1] época 15/20 — train_loss: 0.0000 acc: 1.0000 | val_loss: 0.0000 acc: 1.0000 | auc: 1.0000
#       [center_1] época 16/20 — train_loss: 0.0208 acc: 0.9992 | val_loss: 0.0000 acc: 1.0000 | auc: 1.0000
#       [center_1] época 17/20 — train_loss: 0.0003 acc: 1.0000 | val_loss: 0.0000 acc: 1.0000 | auc: 1.0000
#       [center_1] época 18/20 — train_loss: 0.0002 acc: 1.0000 | val_loss: 0.0000 acc: 1.0000 | auc: 1.0000
#       [center_1] época 19/20 — train_loss: 0.0005 acc: 0.9996 | val_loss: 0.0000 acc: 1.0000 | auc: 1.0000
#       [center_1] época 20/20 — train_loss: 0.0034 acc: 0.9996 | val_loss: 0.0000 acc: 1.0000 | auc: 1.0000
#
#   Centro: center_2
#       [center_2] época 01/20 — train_loss: 0.0114 acc: 0.9974 | val_loss: 0.0922 acc: 0.9844 | auc: 0.9988
#         → mejor época local: 1 | auc: 0.9988
#       [center_2] época 02/20 — train_loss: 0.0133 acc: 0.9961 | val_loss: 0.1451 acc: 0.9844 | auc: 0.9927
#       [center_2] época 03/20 — train_loss: 0.0008 acc: 1.0000 | val_loss: 0.1105 acc: 0.9896 | auc: 0.9983
#       [center_2] época 04/20 — train_loss: 0.0014 acc: 1.0000 | val_loss: 0.0783 acc: 0.9948 | auc: 0.9992
#         → mejor época local: 4 | auc: 0.9992
#       [center_2] época 05/20 — train_loss: 0.0113 acc: 0.9974 | val_loss: 0.1307 acc: 0.9844 | auc: 0.9985
#       [center_2] época 06/20 — train_loss: 0.0021 acc: 0.9987 | val_loss: 0.1391 acc: 0.9792 | auc: 0.9979
#       [center_2] época 07/20 — train_loss: 0.0377 acc: 0.9948 | val_loss: 0.1107 acc: 0.9792 | auc: 0.9990
#       [center_2] época 08/20 — train_loss: 0.0366 acc: 0.9948 | val_loss: 0.0792 acc: 0.9844 | auc: 0.9993
#         → mejor época local: 8 | auc: 0.9993
#       [center_2] época 09/20 — train_loss: 0.0110 acc: 0.9961 | val_loss: 0.1059 acc: 0.9792 | auc: 0.9990
#       [center_2] época 10/20 — train_loss: 0.0046 acc: 0.9987 | val_loss: 0.1193 acc: 0.9844 | auc: 0.9978
#       [center_2] época 11/20 — train_loss: 0.0164 acc: 0.9948 | val_loss: 0.1639 acc: 0.9844 | auc: 0.9915
#       [center_2] época 12/20 — train_loss: 0.0068 acc: 0.9974 | val_loss: 0.1265 acc: 0.9844 | auc: 0.9926
#       [center_2] época 13/20 — train_loss: 0.0011 acc: 1.0000 | val_loss: 0.1265 acc: 0.9844 | auc: 0.9966
#       [center_2] época 14/20 — train_loss: 0.0047 acc: 0.9961 | val_loss: 0.1214 acc: 0.9844 | auc: 0.9964
#       [center_2] época 15/20 — train_loss: 0.0003 acc: 1.0000 | val_loss: 0.1543 acc: 0.9844 | auc: 0.9922
#       [center_2] época 16/20 — train_loss: 0.0003 acc: 1.0000 | val_loss: 0.1203 acc: 0.9896 | auc: 0.9925
#       [center_2] época 17/20 — train_loss: 0.0001 acc: 1.0000 | val_loss: 0.1399 acc: 0.9844 | auc: 0.9921
#       [center_2] época 18/20 — train_loss: 0.0075 acc: 0.9974 | val_loss: 0.1311 acc: 0.9844 | auc: 0.9919
#       [center_2] época 19/20 — train_loss: 0.0001 acc: 1.0000 | val_loss: 0.1358 acc: 0.9844 | auc: 0.9919
#       [center_2] época 20/20 — train_loss: 0.0008 acc: 1.0000 | val_loss: 0.1432 acc: 0.9844 | auc: 0.9921
#
#   Centro: center_3
#       [center_3] época 01/20 — train_loss: 0.1005 acc: 0.9816 | val_loss: 0.7001 acc: 0.9333 | auc: 0.9791
#         → mejor época local: 1 | auc: 0.9791
#       [center_3] época 02/20 — train_loss: 0.0585 acc: 0.9908 | val_loss: 0.6307 acc: 0.9259 | auc: 0.9817
#         → mejor época local: 2 | auc: 0.9817
#       [center_3] época 03/20 — train_loss: 0.0308 acc: 0.9945 | val_loss: 0.6292 acc: 0.9407 | auc: 0.9785
#       [center_3] época 04/20 — train_loss: 0.0452 acc: 0.9890 | val_loss: 0.7184 acc: 0.9333 | auc: 0.9789
#       [center_3] época 05/20 — train_loss: 0.0306 acc: 0.9926 | val_loss: 0.7809 acc: 0.9259 | auc: 0.9745
#       [center_3] época 06/20 — train_loss: 0.0501 acc: 0.9890 | val_loss: 1.0518 acc: 0.9259 | auc: 0.9720
#       [center_3] época 07/20 — train_loss: 0.0317 acc: 0.9926 | val_loss: 0.9572 acc: 0.9259 | auc: 0.9731
#       [center_3] época 08/20 — train_loss: 0.0670 acc: 0.9890 | val_loss: 0.9776 acc: 0.9185 | auc: 0.9692
#       [center_3] época 09/20 — train_loss: 0.0399 acc: 0.9908 | val_loss: 0.8032 acc: 0.9259 | auc: 0.9764
#       [center_3] época 10/20 — train_loss: 0.0381 acc: 0.9926 | val_loss: 0.8011 acc: 0.9259 | auc: 0.9817
#       [center_3] época 11/20 — train_loss: 0.0314 acc: 0.9945 | val_loss: 0.8741 acc: 0.9259 | auc: 0.9787
#       [center_3] época 12/20 — train_loss: 0.0068 acc: 0.9982 | val_loss: 0.8277 acc: 0.9259 | auc: 0.9780
#       [center_3] época 13/20 — train_loss: 0.0270 acc: 0.9963 | val_loss: 0.8950 acc: 0.9407 | auc: 0.9805
#       [center_3] época 14/20 — train_loss: 0.0229 acc: 0.9963 | val_loss: 0.9105 acc: 0.9481 | auc: 0.9787
#       [center_3] época 15/20 — train_loss: 0.0200 acc: 0.9945 | val_loss: 0.8877 acc: 0.9333 | auc: 0.9768
#       [center_3] época 16/20 — train_loss: 0.0225 acc: 0.9926 | val_loss: 0.8750 acc: 0.9259 | auc: 0.9787
#       [center_3] época 17/20 — train_loss: 0.0554 acc: 0.9926 | val_loss: 0.8245 acc: 0.9259 | auc: 0.9796
#       [center_3] época 18/20 — train_loss: 0.0493 acc: 0.9926 | val_loss: 0.8369 acc: 0.9259 | auc: 0.9808
#       [center_3] época 19/20 — train_loss: 0.0127 acc: 0.9963 | val_loss: 0.8125 acc: 0.9259 | auc: 0.9801
#       [center_3] época 20/20 — train_loss: 0.0154 acc: 0.9963 | val_loss: 0.8030 acc: 0.9259 | auc: 0.9796
#
#   Centro: center_4
#       [center_4] época 01/20 — train_loss: 0.0420 acc: 0.9902 | val_loss: 0.2057 acc: 0.9688 | auc: 0.9959
#         → mejor época local: 1 | auc: 0.9959
#       [center_4] época 02/20 — train_loss: 0.0206 acc: 0.9932 | val_loss: 0.2807 acc: 0.9688 | auc: 0.9913
#       [center_4] época 03/20 — train_loss: 0.0090 acc: 0.9961 | val_loss: 0.3252 acc: 0.9648 | auc: 0.9900
#       [center_4] época 04/20 — train_loss: 0.0152 acc: 0.9961 | val_loss: 0.4378 acc: 0.9648 | auc: 0.9805
#       [center_4] época 05/20 — train_loss: 0.0243 acc: 0.9932 | val_loss: 0.2845 acc: 0.9648 | auc: 0.9906
#       [center_4] época 06/20 — train_loss: 0.0160 acc: 0.9961 | val_loss: 0.2164 acc: 0.9648 | auc: 0.9952
#       [center_4] época 07/20 — train_loss: 0.0352 acc: 0.9922 | val_loss: 0.3410 acc: 0.9648 | auc: 0.9904
#       [center_4] época 08/20 — train_loss: 0.0399 acc: 0.9912 | val_loss: 0.2132 acc: 0.9648 | auc: 0.9951
#       [center_4] época 09/20 — train_loss: 0.0377 acc: 0.9932 | val_loss: 0.2337 acc: 0.9688 | auc: 0.9947
#       [center_4] época 10/20 — train_loss: 0.0200 acc: 0.9961 | val_loss: 0.2317 acc: 0.9648 | auc: 0.9963
#         → mejor época local: 10 | auc: 0.9963
#       [center_4] época 11/20 — train_loss: 0.0188 acc: 0.9961 | val_loss: 0.2066 acc: 0.9648 | auc: 0.9965
#         → mejor época local: 11 | auc: 0.9965
#       [center_4] época 12/20 — train_loss: 0.0377 acc: 0.9912 | val_loss: 0.3104 acc: 0.9688 | auc: 0.9911
#       [center_4] época 13/20 — train_loss: 0.0127 acc: 0.9951 | val_loss: 0.2253 acc: 0.9688 | auc: 0.9976
#         → mejor época local: 13 | auc: 0.9976
#       [center_4] época 14/20 — train_loss: 0.0126 acc: 0.9990 | val_loss: 0.3708 acc: 0.9688 | auc: 0.9922
#       [center_4] época 15/20 — train_loss: 0.0169 acc: 0.9980 | val_loss: 0.4214 acc: 0.9648 | auc: 0.9917
#       [center_4] época 16/20 — train_loss: 0.0081 acc: 0.9971 | val_loss: 0.3515 acc: 0.9688 | auc: 0.9919
#       [center_4] época 17/20 — train_loss: 0.0097 acc: 0.9980 | val_loss: 0.3572 acc: 0.9688 | auc: 0.9920
#       [center_4] época 18/20 — train_loss: 0.0011 acc: 1.0000 | val_loss: 0.3720 acc: 0.9688 | auc: 0.9924
#       [center_4] época 19/20 — train_loss: 0.0063 acc: 0.9990 | val_loss: 0.4016 acc: 0.9688 | auc: 0.9924
#       [center_4] época 20/20 — train_loss: 0.0165 acc: 0.9971 | val_loss: 0.3647 acc: 0.9688 | auc: 0.9927
#
#   ───────────────────────────────────────────────────────
#   Ronda 30 — val_auc global: 0.9973
#   Sin mejora 4/10
#
# ============================================================
# Entrenamiento federado finalizado
# Mejor val_auc global : 0.9980
# Encoder guardado en  : pesos_sin_head\encoder_global_mejor_fedavg.pth

# %% [markdown]
# <h1><b> Entrenamiento local - Heads

# %%
# Entrenamiento local desde cero por centro
# Encoder + cabeza nuevos, nos quedamos solo con la cabeza

for nombre, datos in datos_centros.items():

    print(f"\n{'='*60}")
    print(f"  Centro: {nombre}")
    print(f"{'='*60}")

    set_seed(SEED)

    # Crear encoder y cabeza desde cero — sin cargar nada del federado
    encoder_local = crear_encoder().to(DEVICE)
    cabeza_local  = crear_cabeza().to(DEVICE)

    criterio  = LOSS_POR_CENTRO[nombre]
    optimizer = torch.optim.AdamW(
        list(encoder_local.parameters()) + list(cabeza_local.parameters()),
        lr=LR, weight_decay=1e-4
    )
    # Scheduler para reducir LR gradualmente
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=EPOCHS_LOCAL)

    mejor_val_auc        = 0.0
    mejores_pesos_cabeza = None

    for epoca in range(EPOCHS_LOCAL):

        # Train
        encoder_local.train()
        cabeza_local.train()

        train_loss, train_correctos = 0.0, 0

        for imagenes, labels in datos["loader_train"]:
            imagenes = imagenes.to(DEVICE)
            labels   = labels.to(DEVICE).unsqueeze(1)

            optimizer.zero_grad()
            embedding = encoder_local(imagenes)
            salida    = cabeza_local(embedding)
            loss      = criterio(salida, labels)
            loss.backward()
            # Gradient clipping para estabilidad
            torch.nn.utils.clip_grad_norm_(
                list(encoder_local.parameters()) + list(cabeza_local.parameters()),
                max_norm=1.0
            )
            optimizer.step()

            train_loss      += loss.item()
            preds            = (torch.sigmoid(salida) >= 0.5).float()
            train_correctos += (preds == labels).sum().item()

        # Val
        encoder_local.eval()
        cabeza_local.eval()

        val_loss, val_correctos = 0.0, 0
        todas_probs  = []
        todos_labels = []

        with torch.no_grad():
            for imagenes, labels in datos["loader_val"]:
                imagenes  = imagenes.to(DEVICE)
                labels    = labels.to(DEVICE).unsqueeze(1)
                embedding = encoder_local(imagenes)
                salida    = cabeza_local(embedding)
                loss      = criterio(salida, labels)
                probs     = torch.sigmoid(salida).squeeze(1).cpu().numpy()

                val_loss      += loss.item()
                preds          = (torch.sigmoid(salida) >= 0.5).float()
                val_correctos += (preds == labels).sum().item()
                todas_probs.extend(probs)
                todos_labels.extend(labels.squeeze(1).cpu().numpy())

        train_loss /= len(datos["loader_train"])
        val_loss   /= len(datos["loader_val"])
        train_acc   = train_correctos / len(datos["loader_train"].dataset)
        val_acc     = val_correctos   / len(datos["loader_val"].dataset)
        val_auc     = roc_auc_score(todos_labels, todas_probs)

        # Actualizar LR con el scheduler
        scheduler.step()

        print(f"  época {epoca+1:02d}/{EPOCHS_LOCAL} — "
              f"train_loss: {train_loss:.4f} acc: {train_acc:.4f} | "
              f"val_loss: {val_loss:.4f} acc: {val_acc:.4f} | auc: {val_auc:.4f}")

        # Guardar mejor cabeza por AUC
        if val_auc > mejor_val_auc:
            mejor_val_auc        = val_auc
            mejores_pesos_cabeza = copy.deepcopy(cabeza_local.state_dict())
            print(f"    → mejor época: {epoca+1} | auc: {mejor_val_auc:.4f}")

    # Guardar solo la cabeza — el encoder se descarta
    torch.save(mejores_pesos_cabeza, CABEZAS_DIR / f"{nombre}_head.pth")
    print(f"\n  Cabeza guardada: {nombre}_head.pth | mejor auc: {mejor_val_auc:.4f}")

print(f"\n{'='*60}")
print(f"Entrenamiento local finalizado")
print(f"Cabezas guardadas en: {CABEZAS_DIR}")
# Out:
# ============================================================
#   Centro: center_1
# ============================================================
#   época 01/20 — train_loss: 0.3068 acc: 0.8758 | val_loss: 0.1459 acc: 0.9523 | auc: 0.9960
#     → mejor época: 1 | auc: 0.9960
#   época 02/20 — train_loss: 0.1356 acc: 0.9585 | val_loss: 0.0921 acc: 0.9737 | auc: 0.9972
#     → mejor época: 2 | auc: 0.9972
#   época 03/20 — train_loss: 0.1138 acc: 0.9650 | val_loss: 0.0602 acc: 0.9836 | auc: 0.9968
#   época 04/20 — train_loss: 0.0897 acc: 0.9725 | val_loss: 0.0575 acc: 0.9852 | auc: 0.9979
#     → mejor época: 4 | auc: 0.9979
#   época 05/20 — train_loss: 0.0760 acc: 0.9766 | val_loss: 0.0342 acc: 0.9901 | auc: 0.9987
#     → mejor época: 5 | auc: 0.9987
#   época 06/20 — train_loss: 0.0761 acc: 0.9749 | val_loss: 0.0645 acc: 0.9836 | auc: 0.9989
#     → mejor época: 6 | auc: 0.9989
#   época 07/20 — train_loss: 0.0373 acc: 0.9881 | val_loss: 0.0229 acc: 0.9934 | auc: 0.9997
#     → mejor época: 7 | auc: 0.9997
#   época 08/20 — train_loss: 0.0467 acc: 0.9868 | val_loss: 0.0361 acc: 0.9918 | auc: 0.9987
#   época 09/20 — train_loss: 0.0294 acc: 0.9934 | val_loss: 0.0251 acc: 0.9951 | auc: 0.9992
#   época 10/20 — train_loss: 0.0212 acc: 0.9930 | val_loss: 0.0297 acc: 0.9934 | auc: 0.9983
#   época 11/20 — train_loss: 0.0300 acc: 0.9910 | val_loss: 0.0188 acc: 0.9984 | auc: 0.9995
#   época 12/20 — train_loss: 0.0194 acc: 0.9959 | val_loss: 0.0229 acc: 0.9951 | auc: 0.9993
#   época 13/20 — train_loss: 0.0114 acc: 0.9963 | val_loss: 0.0191 acc: 0.9967 | auc: 0.9990
#   época 14/20 — train_loss: 0.0204 acc: 0.9951 | val_loss: 0.0201 acc: 0.9967 | auc: 0.9994
#   época 15/20 — train_loss: 0.0376 acc: 0.9926 | val_loss: 0.0224 acc: 0.9951 | auc: 0.9998
#     → mejor época: 15 | auc: 0.9998
#   época 16/20 — train_loss: 0.0065 acc: 0.9979 | val_loss: 0.0158 acc: 0.9967 | auc: 0.9997
#   época 17/20 — train_loss: 0.0232 acc: 0.9947 | val_loss: 0.0187 acc: 0.9951 | auc: 0.9999
#     → mejor época: 17 | auc: 0.9999
#   época 18/20 — train_loss: 0.0099 acc: 0.9971 | val_loss: 0.0151 acc: 0.9967 | auc: 0.9999
#   época 19/20 — train_loss: 0.0067 acc: 0.9967 | val_loss: 0.0157 acc: 0.9967 | auc: 0.9999
#   época 20/20 — train_loss: 0.0213 acc: 0.9975 | val_loss: 0.0158 acc: 0.9951 | auc: 0.9999
#
#   Cabeza guardada: center_1_head.pth | mejor auc: 0.9999
#
# ============================================================
#   Centro: center_2
# ============================================================
#   época 01/20 — train_loss: 0.4781 acc: 0.7878 | val_loss: 0.2916 acc: 0.8854 | auc: 0.9662
#     → mejor época: 1 | auc: 0.9662
#   época 02/20 — train_loss: 0.3159 acc: 0.8789 | val_loss: 0.1967 acc: 0.9375 | auc: 0.9798
#     → mejor época: 2 | auc: 0.9798
#   época 03/20 — train_loss: 0.2179 acc: 0.9154 | val_loss: 0.1403 acc: 0.9531 | auc: 0.9917
#     → mejor época: 3 | auc: 0.9917
#   época 04/20 — train_loss: 0.1532 acc: 0.9401 | val_loss: 0.0801 acc: 0.9583 | auc: 0.9968
#     → mejor época: 4 | auc: 0.9968
#   época 05/20 — train_loss: 0.1390 acc: 0.9518 | val_loss: 0.0668 acc: 0.9740 | auc: 0.9972
#     → mejor época: 5 | auc: 0.9972
#   época 06/20 — train_loss: 0.1287 acc: 0.9479 | val_loss: 0.0752 acc: 0.9583 | auc: 0.9981
#     → mejor época: 6 | auc: 0.9981
#   época 07/20 — train_loss: 0.1324 acc: 0.9518 | val_loss: 0.0582 acc: 0.9688 | auc: 0.9989
#     → mejor época: 7 | auc: 0.9989
#   época 08/20 — train_loss: 0.1225 acc: 0.9622 | val_loss: 0.0491 acc: 0.9844 | auc: 0.9985
#   época 09/20 — train_loss: 0.0833 acc: 0.9701 | val_loss: 0.0389 acc: 0.9844 | auc: 0.9990
#     → mejor época: 9 | auc: 0.9990
#   época 10/20 — train_loss: 0.0591 acc: 0.9818 | val_loss: 0.0795 acc: 0.9688 | auc: 0.9985
#   época 11/20 — train_loss: 0.0838 acc: 0.9766 | val_loss: 0.0549 acc: 0.9844 | auc: 0.9988
#   época 12/20 — train_loss: 0.0505 acc: 0.9831 | val_loss: 0.0483 acc: 0.9844 | auc: 0.9989
#   época 13/20 — train_loss: 0.0828 acc: 0.9740 | val_loss: 0.0727 acc: 0.9740 | auc: 0.9989
#   época 14/20 — train_loss: 0.0698 acc: 0.9740 | val_loss: 0.0527 acc: 0.9792 | auc: 0.9987
#   época 15/20 — train_loss: 0.0536 acc: 0.9831 | val_loss: 0.0547 acc: 0.9792 | auc: 0.9990
#   época 16/20 — train_loss: 0.0491 acc: 0.9805 | val_loss: 0.0776 acc: 0.9688 | auc: 0.9989
#   época 17/20 — train_loss: 0.0589 acc: 0.9857 | val_loss: 0.0588 acc: 0.9792 | auc: 0.9983
#   época 18/20 — train_loss: 0.0413 acc: 0.9870 | val_loss: 0.0656 acc: 0.9740 | auc: 0.9984
#   época 19/20 — train_loss: 0.0560 acc: 0.9805 | val_loss: 0.0701 acc: 0.9740 | auc: 0.9988
#   época 20/20 — train_loss: 0.0423 acc: 0.9870 | val_loss: 0.0617 acc: 0.9792 | auc: 0.9979
#
#   Cabeza guardada: center_2_head.pth | mejor auc: 0.9990
#
# ============================================================
#   Centro: center_3
# ============================================================
#   época 01/20 — train_loss: 0.9068 acc: 0.5993 | val_loss: 0.7145 acc: 0.7481 | auc: 0.8028
#     → mejor época: 1 | auc: 0.8028
#   época 02/20 — train_loss: 0.6870 acc: 0.7371 | val_loss: 0.5990 acc: 0.7630 | auc: 0.8779
#     → mejor época: 2 | auc: 0.8779
#   época 03/20 — train_loss: 0.5811 acc: 0.7592 | val_loss: 0.4930 acc: 0.8296 | auc: 0.9256
#     → mejor época: 3 | auc: 0.9256
#   época 04/20 — train_loss: 0.4551 acc: 0.8456 | val_loss: 0.4664 acc: 0.8741 | auc: 0.9168
#   época 05/20 — train_loss: 0.4225 acc: 0.8511 | val_loss: 0.4758 acc: 0.8667 | auc: 0.9268
#     → mejor época: 5 | auc: 0.9268
#   época 06/20 — train_loss: 0.3069 acc: 0.9081 | val_loss: 0.5305 acc: 0.8519 | auc: 0.9391
#     → mejor época: 6 | auc: 0.9391
#   época 07/20 — train_loss: 0.3478 acc: 0.8842 | val_loss: 0.4545 acc: 0.8593 | auc: 0.9335
#   época 08/20 — train_loss: 0.3226 acc: 0.8915 | val_loss: 0.4679 acc: 0.8667 | auc: 0.9293
#   época 09/20 — train_loss: 0.2318 acc: 0.9320 | val_loss: 0.4900 acc: 0.8741 | auc: 0.9532
#     → mejor época: 9 | auc: 0.9532
#   época 10/20 — train_loss: 0.2629 acc: 0.9191 | val_loss: 0.3956 acc: 0.8815 | auc: 0.9585
#     → mejor época: 10 | auc: 0.9585
#   época 11/20 — train_loss: 0.3046 acc: 0.8989 | val_loss: 0.4658 acc: 0.8593 | auc: 0.9525
#   época 12/20 — train_loss: 0.2032 acc: 0.9393 | val_loss: 0.4064 acc: 0.8815 | auc: 0.9574
#   época 13/20 — train_loss: 0.2476 acc: 0.9265 | val_loss: 0.3857 acc: 0.8889 | auc: 0.9525
#   época 14/20 — train_loss: 0.1724 acc: 0.9375 | val_loss: 0.4815 acc: 0.8519 | auc: 0.9479
#   época 15/20 — train_loss: 0.1997 acc: 0.9449 | val_loss: 0.4462 acc: 0.8667 | auc: 0.9523
#   época 16/20 — train_loss: 0.2315 acc: 0.9228 | val_loss: 0.4425 acc: 0.8667 | auc: 0.9520
#   época 17/20 — train_loss: 0.1974 acc: 0.9485 | val_loss: 0.4615 acc: 0.8667 | auc: 0.9509
#   época 18/20 — train_loss: 0.2100 acc: 0.9430 | val_loss: 0.5245 acc: 0.8593 | auc: 0.9504
#   época 19/20 — train_loss: 0.1870 acc: 0.9338 | val_loss: 0.4756 acc: 0.8519 | auc: 0.9551
#   época 20/20 — train_loss: 0.2344 acc: 0.9265 | val_loss: 0.4177 acc: 0.8741 | auc: 0.9541
#
#   Cabeza guardada: center_3_head.pth | mejor auc: 0.9585
#
# ============================================================
#   Centro: center_4
# ============================================================
#   época 01/20 — train_loss: 0.6182 acc: 0.7109 | val_loss: 0.4385 acc: 0.7969 | auc: 0.9044
#     → mejor época: 1 | auc: 0.9044
#   época 02/20 — train_loss: 0.4192 acc: 0.8242 | val_loss: 0.2761 acc: 0.9062 | auc: 0.9643
#     → mejor época: 2 | auc: 0.9643
#   época 03/20 — train_loss: 0.3414 acc: 0.8623 | val_loss: 0.2515 acc: 0.9141 | auc: 0.9644
#     → mejor época: 3 | auc: 0.9644
#   época 04/20 — train_loss: 0.2980 acc: 0.8965 | val_loss: 0.1940 acc: 0.9336 | auc: 0.9829
#     → mejor época: 4 | auc: 0.9829
#   época 05/20 — train_loss: 0.2583 acc: 0.9072 | val_loss: 0.2000 acc: 0.9297 | auc: 0.9715
#   época 06/20 — train_loss: 0.2384 acc: 0.9297 | val_loss: 0.2311 acc: 0.9375 | auc: 0.9651
#   época 07/20 — train_loss: 0.2513 acc: 0.9121 | val_loss: 0.1837 acc: 0.9453 | auc: 0.9765
#   época 08/20 — train_loss: 0.2186 acc: 0.9111 | val_loss: 0.1838 acc: 0.9570 | auc: 0.9751
#   época 09/20 — train_loss: 0.1908 acc: 0.9316 | val_loss: 0.1293 acc: 0.9570 | auc: 0.9870
#     → mejor época: 9 | auc: 0.9870
#   época 10/20 — train_loss: 0.1678 acc: 0.9492 | val_loss: 0.1192 acc: 0.9609 | auc: 0.9888
#     → mejor época: 10 | auc: 0.9888
#   época 11/20 — train_loss: 0.1856 acc: 0.9307 | val_loss: 0.1410 acc: 0.9570 | auc: 0.9852
#   época 12/20 — train_loss: 0.1923 acc: 0.9395 | val_loss: 0.1327 acc: 0.9609 | auc: 0.9866
#   época 13/20 — train_loss: 0.1725 acc: 0.9395 | val_loss: 0.1259 acc: 0.9648 | auc: 0.9878
#   época 14/20 — train_loss: 0.1507 acc: 0.9521 | val_loss: 0.1563 acc: 0.9648 | auc: 0.9827
#   época 15/20 — train_loss: 0.1614 acc: 0.9473 | val_loss: 0.1440 acc: 0.9648 | auc: 0.9842
#   época 16/20 — train_loss: 0.1611 acc: 0.9473 | val_loss: 0.1446 acc: 0.9648 | auc: 0.9845
#   época 17/20 — train_loss: 0.1322 acc: 0.9551 | val_loss: 0.1425 acc: 0.9688 | auc: 0.9846
#   época 18/20 — train_loss: 0.1132 acc: 0.9619 | val_loss: 0.1411 acc: 0.9688 | auc: 0.9858
#   época 19/20 — train_loss: 0.1350 acc: 0.9561 | val_loss: 0.1498 acc: 0.9688 | auc: 0.9842
#   época 20/20 — train_loss: 0.1082 acc: 0.9639 | val_loss: 0.1559 acc: 0.9648 | auc: 0.9836
#
#   Cabeza guardada: center_4_head.pth | mejor auc: 0.9888
#
# ============================================================
# Entrenamiento local finalizado
# Cabezas guardadas en: pesos_sin_head\cabezas

# %% [markdown]
# <h1><b> Evaluación

# %%
# Cargar el mejor encoder global
encoder_global.load_state_dict(torch.load(MEJOR_ENCODER_PATH, map_location=DEVICE))
encoder_global.eval()

# Cargar las cabezas locales guardadas
for nombre in CENTROS:
    cabezas_centros[nombre].load_state_dict(
        torch.load(CABEZAS_DIR / f"{nombre}_head.pth", map_location=DEVICE)
    )
    cabezas_centros[nombre].eval()


def evaluar_centro(nombre, encoder, cabeza, loader_test):
    todos_labels = []
    todos_probs  = []
    todos_preds  = []

    with torch.no_grad():
        for imagenes, labels in loader_test:
            imagenes  = imagenes.to(DEVICE)
            embedding = encoder(imagenes)
            salida    = cabeza(embedding)
            probs     = torch.sigmoid(salida).squeeze(1).cpu().numpy()
            preds     = (probs >= 0.5).astype(int)

            todos_labels.extend(labels.numpy().astype(int))
            todos_probs.extend(probs)
            todos_preds.extend(preds)

    auc           = roc_auc_score(todos_labels, todos_probs)
    f1            = f1_score(todos_labels, todos_preds)
    sensibilidad  = recall_score(todos_labels, todos_preds)
    especificidad = recall_score(todos_labels, todos_preds, pos_label=0)
    precision     = precision_score(todos_labels, todos_preds)
    accuracy      = sum(p == l for p, l in zip(todos_preds, todos_labels)) / len(todos_labels)
    cm            = confusion_matrix(todos_labels, todos_preds)

    return {
        "auc"          : auc,
        "f1"           : f1,
        "sensibilidad" : sensibilidad,
        "especificidad": especificidad,
        "precision"    : precision,
        "accuracy"     : accuracy,
        "cm"           : cm,
        "labels"       : todos_labels,
        "preds"        : todos_preds,
    }


# Evaluar cada centro con encoder global + su cabeza local
resultados = {}

for nombre, datos in datos_centros.items():
    resultados[nombre] = evaluar_centro(
        nombre,
        encoder_global,
        cabezas_centros[nombre],
        datos["loader_test"]
    )

# Métricas por centro
print(f"\n{'='*65}")
print(f"  EVALUACIÓN FINAL — TEST SET POR CENTRO")
print(f"{'='*65}")
print(f"{'Métrica':<18} {'Center 1':>10} {'Center 2':>10} {'Center 3':>10} {'Center 4':>10}")
print(f"{'─'*65}")

metricas  = ["auc", "accuracy", "f1", "sensibilidad", "especificidad", "precision"]
nombres_m = ["AUC-ROC", "Accuracy", "F1-Score", "Sensibilidad", "Especificidad", "Precisión"]

for metrica, nombre_m in zip(metricas, nombres_m):
    vals = [resultados[c][metrica] for c in datos_centros]
    print(f"  {nombre_m:<16} {vals[0]:>10.4f} {vals[1]:>10.4f} {vals[2]:>10.4f} {vals[3]:>10.4f}")

print(f"{'='*65}")
# Out:
# =================================================================
#   EVALUACIÓN FINAL — TEST SET POR CENTRO
# =================================================================
# Métrica              Center 1   Center 2   Center 3   Center 4
# ─────────────────────────────────────────────────────────────────
#   AUC-ROC              0.9806     0.8401     0.2002     0.2559
#   Accuracy             0.9513     0.7875     0.2749     0.2812
#   F1-Score             0.9491     0.7935     0.2955     0.4363
#   Sensibilidad         0.9079     0.7000     0.2430     0.5145
#   Especificidad        0.9947     0.9100     0.3281     0.0068
#   Precisión            0.9942     0.9159     0.3768     0.3787
# =================================================================

# %% [markdown]
# <h1><b> Probabilidades centro 5

# %%
# Rutas center_5
CENTER_5_TEST = BASE_DIR / "preprocesamiento/output/center_5/preprocesamiento_test"

# Dataset y loader
archivos_test_c5 = sorted(CENTER_5_TEST.glob("*.npy"))
dataset_c5       = StrokeDataset(archivos_test_c5)
loader_c5        = DataLoader(dataset_c5, batch_size=BATCH_SIZE, shuffle=False)

# Subcarpeta de salida
CENTER_5_DIR = PESOS_DIR / "center_5"
CENTER_5_DIR.mkdir(exist_ok=True)

print(f"Center 5 — muestras test: {len(dataset_c5)}")
# Out:
# Center 5 — muestras test: 257

# %%
import pandas as pd

encoder_global.eval()

for nombre_centro, cabeza in cabezas_centros.items():
    cabeza.eval()

    nombres_archivos = []
    probabilidades   = []

    with torch.no_grad():
        for i, (imagenes, _) in enumerate(loader_c5):
            imagenes  = imagenes.to(DEVICE)
            embedding = encoder_global(imagenes)
            salida    = cabeza(embedding)
            probs     = torch.sigmoid(salida).squeeze(1).cpu().numpy()

            idx_inicio     = i * BATCH_SIZE
            batch_archivos = archivos_test_c5[idx_inicio: idx_inicio + len(imagenes)]
            nombres_archivos.extend([a.stem for a in batch_archivos])
            probabilidades.extend(probs.tolist())

    df = pd.DataFrame({
        "archivo"     : nombres_archivos,
        "probabilidad": probabilidades,
    })

    ruta_csv = CENTER_5_DIR / f"center_5_probs_{nombre_centro}_head.csv"
    df.to_csv(ruta_csv, index=False)
    print(f"  {nombre_centro} - {ruta_csv} ({len(df)} muestras)")

print(f"\nCSVs guardados en: {CENTER_5_DIR}")
# Out:
#   center_1 - pesos_sin_head\center_5\center_5_probs_center_1_head.csv (257 muestras)
#   center_2 - pesos_sin_head\center_5\center_5_probs_center_2_head.csv (257 muestras)
#   center_3 - pesos_sin_head\center_5\center_5_probs_center_3_head.csv (257 muestras)
#   center_4 - pesos_sin_head\center_5\center_5_probs_center_4_head.csv (257 muestras)
#
# CSVs guardados en: pesos_sin_head\center_5

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

BASE_DIR         = Path("..")
BATCH_SIZE       = 16
archivos_test_c5 = sorted(
    (BASE_DIR / "preprocesamiento/output/center_5/preprocesamiento_test").glob("*.npy")
)

print(f"Center 5 — muestras: {len(archivos_test_c5)}")

def get_pixeles_dwi(archivos, n_max=None):
    """Extrae todos los píxeles del canal DWI (canal 0) de los archivos .npy"""
    pixeles = []
    archivos = archivos[:n_max] if n_max else archivos
    for ruta in archivos:
        img = np.load(ruta)  # [2, 112, 112]
        dwi = img[0].flatten()
        pixeles.extend(dwi.tolist())
    return np.array(pixeles)


# Archivos de center_3 y center_5
archivos_c3 = sorted(
    (BASE_DIR / "preprocesamiento/output/center_3/preprocesamiento_test").glob("*.npy")
)

pixeles_c3 = get_pixeles_dwi(archivos_c3)
pixeles_c5 = get_pixeles_dwi(archivos_test_c5)

# Histograma
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].hist(pixeles_c3, bins=100, color="steelblue", density=True)
axes[0].set_title(f"Center 3 — DWI (n={len(archivos_c3)})")
axes[0].set_xlabel("Intensidad")
axes[0].set_ylabel("Densidad")

axes[1].hist(pixeles_c5, bins=100, color="tomato", density=True)
axes[1].set_title(f"Center 5 — DWI (n={len(archivos_test_c5)})")
axes[1].set_xlabel("Intensidad")
axes[1].set_ylabel("Densidad")

plt.suptitle("Distribución de intensidades DWI", fontsize=13)
plt.tight_layout()
plt.show()

print(f"Center 3 — mean: {pixeles_c3.mean():.4f} | std: {pixeles_c3.std():.4f} | min: {pixeles_c3.min():.4f} | max: {pixeles_c3.max():.4f}")
print(f"Center 5 — mean: {pixeles_c5.mean():.4f} | std: {pixeles_c5.std():.4f} | min: {pixeles_c5.min():.4f} | max: {pixeles_c5.max():.4f}")
# Out:
# Center 5 — muestras: 257
# Center 3 — mean: -2.2336 | std: 1.3898 | min: -4.5737 | max: 6.3794
# Center 5 — mean: -2.3580 | std: 1.3038 | min: -4.1431 | max: 6.2501

# %%
from scipy.stats import mannwhitneyu

BASE_DIR         = Path("..")
BATCH_SIZE       = 16
archivos_test_c5 = sorted(
    (BASE_DIR / "preprocesamiento/output/center_5/preprocesamiento_test").glob("*.npy")
)
archivos_c3 = sorted(
    (BASE_DIR / "preprocesamiento/output/center_3/preprocesamiento_test").glob("*.npy")
)

def get_pixeles_dwi(archivos, n_max=None):
    """Extrae todos los píxeles del canal DWI (canal 0) de los archivos .npy"""
    pixeles = []
    archivos = archivos[:n_max] if n_max else archivos
    for ruta in archivos:
        img = np.load(ruta)  # [2, 112, 112]
        dwi = img[0].flatten()
        pixeles.extend(dwi.tolist())
    return np.array(pixeles)

pixeles_c3 = get_pixeles_dwi(archivos_c3)
pixeles_c5 = get_pixeles_dwi(archivos_test_c5)

# Excluir fondo
UMBRAL_FONDO     = -2.5
pixeles_c3_brain = pixeles_c3[pixeles_c3 > UMBRAL_FONDO]
pixeles_c5_brain = pixeles_c5[pixeles_c5 > UMBRAL_FONDO]

print(f"Center 3 — píxeles cerebro: {len(pixeles_c3_brain):,}")
print(f"Center 5 — píxeles cerebro: {len(pixeles_c5_brain):,}")


print(f"\nCenter 3 — mean: {pixeles_c3_brain.mean():.4f} | std: {pixeles_c3_brain.std():.4f}")
print(f"Center 5 — mean: {pixeles_c5_brain.mean():.4f} | std: {pixeles_c5_brain.std():.4f}")

# Mann-Whitney U
stat, p_value = mannwhitneyu(pixeles_c3_brain, pixeles_c5_brain)

print(f"\nMann-Whitney U")
print(f"{'─'*35}")
print(f"  Estadístico U : {stat:,.0f}")
print(f"  p-value       : {p_value:.6f}")
print()
if p_value > 0.05:
    print(f"  → No hay diferencia significativa (p > 0.05)")
    print(f"     Las distribuciones son similares — center_5 es compatible con center_3")
else:
    print(f"  → Diferencia significativa (p < 0.05)")
    print(f"     Las distribuciones difieren entre centros")
# Out:
# Center 3 — píxeles cerebro: 544,902
# Center 5 — píxeles cerebro: 689,524
#
# Center 3 — mean: 0.0101 | std: 0.9231
# Center 5 — mean: -0.0077 | std: 0.9583
#
# Mann-Whitney U
# ───────────────────────────────────
#   Estadístico U : 194,800,332,252
#   p-value       : 0.000000
#
#   → Diferencia significativa (p < 0.05)
#      Las distribuciones difieren entre centros

# %%
from scipy.stats import wilcoxon

# Igualar tamaños muestreando aleatoriamente el más grande
np.random.seed(SEED)
n = min(len(pixeles_c3_brain), len(pixeles_c5_brain))
muestra_c3 = np.random.choice(pixeles_c3_brain, size=n, replace=False)
muestra_c5 = np.random.choice(pixeles_c5_brain, size=n, replace=False)

stat, p_value = wilcoxon(muestra_c3, muestra_c5)

print(f"Wilcoxon signed-rank test")
print(f"{'─'*35}")
print(f"  n muestras    : {n:,}")
print(f"  Estadístico W : {stat:,.0f}")
print(f"  p-value       : {p_value:.6f}")
print()
if p_value > 0.05:
    print(f"  → No hay diferencia significativa (p > 0.05)")
    print(f"     Las distribuciones son similares")
else:
    print(f"  → Diferencia significativa (p < 0.05)")
    print(f"     Las distribuciones difieren entre centros")
# Out:
# Wilcoxon signed-rank test
# ───────────────────────────────────
#   n muestras    : 544,902
#   Estadístico W : 71,992,105,382
#   p-value       : 0.000000
#
#   → Diferencia significativa (p < 0.05)
#      Las distribuciones difieren entre centros
