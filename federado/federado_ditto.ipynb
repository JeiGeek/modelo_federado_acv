# %% [markdown]
# <h1><b> Librerías y configuraciones

# %%
# Librerías
import sys
import copy
import math
import torch
import torch.nn as nn
import numpy as np
import random
import importlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from pathlib import Path
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.metrics import roc_auc_score, confusion_matrix, f1_score, recall_score, precision_score

# Modelos
sys.path.append(str(Path(".").resolve()))

import agregacion
importlib.reload(agregacion)
from agregacion import agregar_pesos

from modelo import crear_modelo

# Semilla para reproducibilidad
SEED = 42
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark     = False

set_seed(SEED)

# Configuración del dispositivo
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Dispositivo: {DEVICE}")
# Out:
# Dispositivo: cuda

# %%
BASE_DIR = Path("..")

CENTROS = {
    "center_1": {
        "train": BASE_DIR / "preprocesamiento/output/center_1/preprocesamiento_train",
        "test" : BASE_DIR / "preprocesamiento/output/center_1/preprocesamiento_test",
    },
    "center_2": {
        "train": BASE_DIR / "preprocesamiento/output/center_2/preprocesamiento_train",
        "test" : BASE_DIR / "preprocesamiento/output/center_2/preprocesamiento_test",
    },
    "center_3": {
        "train": BASE_DIR / "preprocesamiento/output/center_3/preprocesamiento_train",
        "test" : BASE_DIR / "preprocesamiento/output/center_3/preprocesamiento_test",
    },
    "center_4": {
        "train": BASE_DIR / "preprocesamiento/output/center_4/preprocesamiento_train",
        "test" : BASE_DIR / "preprocesamiento/output/center_4/preprocesamiento_test",
    },
}

# Directorio de pesos
PESOS_DIR = Path("ditto_pesos")
PESOS_DIR.mkdir(exist_ok=True)

# Hiperparámetros
BATCH_SIZE   = 16
EPOCHS_LOCAL = 20     # épocas entrenamiento global por ronda
EPOCHS_DITTO = 15     # épocas entrenamiento local Ditto por ronda
RONDAS       = 30
LR           = 1e-4
PACIENCIA    = 10
LAMBDA       = 0.5    # fuerza del ancla al modelo global

# workers para DataLoader
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# Verificar rutas
print("\nVerificación de rutas:")
for nombre, rutas in CENTROS.items():
    train_ok = rutas["train"].exists()
    test_ok  = rutas["test"].exists()
    print(f"  {nombre} — train: {'OK' if train_ok else 'BAD'} | test: {'OK' if test_ok else 'BAD'}")
# Out:
# Verificación de rutas:
#   center_1 — train: OK | test: OK
#   center_2 — train: OK | test: OK
#   center_3 — train: OK | test: OK
#   center_4 — train: OK | test: OK

# %% [markdown]
# <h1><b> Dataset

# %%
# Dataset
class StrokeDataset(Dataset):
    def __init__(self, archivos):
        self.archivos = archivos

    def __len__(self):
        return len(self.archivos)

    def __getitem__(self, idx):
        ruta   = self.archivos[idx]
        imagen = np.load(ruta).astype(np.float32)
        imagen = torch.from_numpy(imagen)
        label  = 1 if "STROKE" in ruta.stem else 0
        return imagen, torch.tensor(label, dtype=torch.float32)

# Carga y split por centro
def cargar_centro(rutas_centro, seed=SEED):
    archivos_train = sorted(rutas_centro["train"].glob("*.npy"))
    archivos_test  = sorted(rutas_centro["test"].glob("*.npy"))

    dataset_train = StrokeDataset(archivos_train)
    dataset_test  = StrokeDataset(archivos_test)

    # Split 80/20 train/val
    val_size   = int(len(dataset_train) * 0.2)
    train_size = len(dataset_train) - val_size
    train_split, val_split = random_split(
        dataset_train, [train_size, val_size],
        generator=torch.Generator().manual_seed(seed)
    )

    g = torch.Generator()
    g.manual_seed(seed)

    loader_train = DataLoader(train_split, batch_size=BATCH_SIZE, shuffle=True,
                              worker_init_fn=seed_worker, generator=g)
    loader_val   = DataLoader(val_split,   batch_size=BATCH_SIZE, shuffle=False)
    loader_test  = DataLoader(dataset_test, batch_size=BATCH_SIZE, shuffle=False)

    return {
        "dataset_train": dataset_train,
        "loader_train" : loader_train,
        "loader_val"   : loader_val,
        "loader_test"  : loader_test,
        "n_train"      : train_size,
        "n_val"        : val_size,
        "n_test"       : len(dataset_test),
    }


# Cargar todos los centros
datos_centros = {}
for nombre, rutas in CENTROS.items():
    datos_centros[nombre] = cargar_centro(rutas)

# Verificación
print(f"{'Centro':<12} {'Train':>8} {'Val':>8} {'Test':>8}")
print("─" * 40)
for nombre, datos in datos_centros.items():
    print(f"{nombre:<12} {datos['n_train']:>8} {datos['n_val']:>8} {datos['n_test']:>8}")
# Out:
# Centro          Train      Val     Test
# ────────────────────────────────────────
# center_1         2432      608      760
# center_2          768      192      240
# center_3          544      135      171
# center_4         1024      256      320

# %% [markdown]
# <h1><b>Modelos y loss por centro

# %%
# Punto de partida
set_seed(SEED)
modelo_global = crear_modelo().to(DEVICE)

# %%
# Modelos locales ditto
modelos_locales = {
    nombre: crear_modelo().to(DEVICE)
    for nombre in CENTROS.keys()
}

# Inicializamos los modelos locales con los pesos del global
for nombre, modelo_local in modelos_locales.items():
    modelo_local.load_state_dict(copy.deepcopy(modelo_global.state_dict()))

# Rutas de guardado
MODELO_GLOBAL_PATH = PESOS_DIR / "modelo_global_ditto.pth"
MODELOS_LOCALES_PATHS = {
    nombre: PESOS_DIR / f"{nombre}_local_ditto.pth"
    for nombre in CENTROS.keys()
}

# %%
# Loss por centro
class FocalLoss(nn.Module):
    def __init__(self, gamma=2.0):
        super().__init__()
        self.gamma = gamma

    def forward(self, logits, targets):
        bce   = nn.functional.binary_cross_entropy_with_logits(logits, targets, reduction="none")
        probs = torch.sigmoid(logits)
        pt    = torch.where(targets == 1, probs, 1 - probs)
        loss  = ((1 - pt) ** self.gamma) * bce
        return loss.mean()


LOSS_POR_CENTRO = {
    "center_1": nn.BCEWithLogitsLoss(),
    "center_2": nn.BCEWithLogitsLoss(),
    "center_3": FocalLoss(gamma=2.0),
    "center_4": nn.BCEWithLogitsLoss(pos_weight=torch.tensor([588/692]).to(DEVICE)),
}

# Verificación
total_params = sum(p.numel() for p in modelo_global.parameters())
print(f"Modelo global     : {total_params:,} parámetros")
print(f"Modelos locales   : {len(modelos_locales)} × {total_params:,} parámetros")
print(f"\nLoss por centro:")
for nombre, loss in LOSS_POR_CENTRO.items():
    print(f"  {nombre} - {loss.__class__.__name__}")
# Out:
# Modelo global     : 11,218,825 parámetros
# Modelos locales   : 4 × 11,218,825 parámetros
#
# Loss por centro:
#   center_1 - BCEWithLogitsLoss
#   center_2 - BCEWithLogitsLoss
#   center_3 - FocalLoss
#   center_4 - BCEWithLogitsLoss

# %% [markdown]
# <h1><b> Funciones de entrenamiento Ditto

# %%
# Entrenamiento local
def entrenar_global(nombre, modelo_global, loader_train, loader_val, epochs):

    modelo_local = copy.deepcopy(modelo_global)
    criterio     = LOSS_POR_CENTRO[nombre]
    optimizer    = torch.optim.AdamW(modelo_local.parameters(), lr=LR)

    mejor_val_auc  = 0.0
    mejores_pesos  = None
    mejor_val_loss = float("inf")
    mejor_val_acc  = 0.0

    for epoca in range(epochs):
        modelo_local.train()
        train_loss, train_correctos = 0.0, 0

        for imagenes, labels in loader_train:
            imagenes = imagenes.to(DEVICE)
            labels   = labels.to(DEVICE).unsqueeze(1)
            optimizer.zero_grad()
            salida = modelo_local(imagenes)
            loss   = criterio(salida, labels)
            loss.backward()
            optimizer.step()
            train_loss      += loss.item()
            preds            = (torch.sigmoid(salida) >= 0.5).float()
            train_correctos += (preds == labels).sum().item()

        modelo_local.eval()
        val_loss, val_correctos = 0.0, 0
        todas_probs  = []
        todos_labels = []

        with torch.no_grad():
            for imagenes, labels in loader_val:
                imagenes = imagenes.to(DEVICE)
                labels   = labels.to(DEVICE).unsqueeze(1)
                salida   = modelo_local(imagenes)
                loss     = criterio(salida, labels)
                probs    = torch.sigmoid(salida).squeeze(1).cpu().numpy()
                val_loss      += loss.item()
                preds          = (torch.sigmoid(salida) >= 0.5).float()
                val_correctos += (preds == labels).sum().item()
                todas_probs.extend(probs)
                todos_labels.extend(labels.squeeze(1).cpu().numpy())

        train_loss /= len(loader_train)
        val_loss   /= len(loader_val)
        train_acc   = train_correctos / len(loader_train.dataset)
        val_acc     = val_correctos   / len(loader_val.dataset)
        val_auc     = roc_auc_score(todos_labels, todas_probs)

        print(f"      [global/{nombre}] época {epoca+1:02d}/{epochs} — "
              f"loss: {train_loss:.4f} acc: {train_acc:.4f} | "
              f"val_loss: {val_loss:.4f} acc: {val_acc:.4f} | auc: {val_auc:.4f}")

        if val_auc > mejor_val_auc:
            mejor_val_auc  = val_auc
            mejor_val_loss = val_loss
            mejor_val_acc  = val_acc
            mejores_pesos  = copy.deepcopy(modelo_local.state_dict())
            print(f"        → mejor época global: {epoca+1} | auc: {mejor_val_auc:.4f}")

    return mejores_pesos, mejor_val_loss, mejor_val_acc, mejor_val_auc

# %%
# Entrenamiento local Ditto
def entrenar_ditto(nombre, modelo_local, modelo_global, loader_train, loader_val, epochs, lam=LAMBDA):
    """
    Personaliza el modelo local de cada centro.
    El ancla al global evita que se aleje demasiado.
    Retorna val_loss, val_acc, val_auc del mejor modelo local.
    """
    criterio  = LOSS_POR_CENTRO[nombre]
    optimizer = torch.optim.AdamW(modelo_local.parameters(), lr=LR)

    # Pesos del global como referencia fija
    pesos_global_ref = {k: v.clone().detach() for k, v in modelo_global.state_dict().items()}

    mejor_val_auc  = 0.0
    mejor_estado   = None
    mejor_val_loss = float("inf")
    mejor_val_acc  = 0.0

    for epoca in range(epochs):
        modelo_local.train()
        train_loss, train_correctos = 0.0, 0

        for imagenes, labels in loader_train:
            imagenes = imagenes.to(DEVICE)
            labels   = labels.to(DEVICE).unsqueeze(1)
            optimizer.zero_grad()
            salida      = modelo_local(imagenes)
            loss_normal = criterio(salida, labels)

            # Ancla al modelo global
            ancla = 0.0
            for k, param in modelo_local.named_parameters():
                if k in pesos_global_ref:
                    ancla += ((param - pesos_global_ref[k]) ** 2).sum()
            loss_total = loss_normal + (lam / 2) * ancla

            loss_total.backward()
            optimizer.step()
            train_loss      += loss_normal.item()
            preds            = (torch.sigmoid(salida) >= 0.5).float()
            train_correctos += (preds == labels).sum().item()

        modelo_local.eval()
        val_loss, val_correctos = 0.0, 0
        todas_probs  = []
        todos_labels = []

        with torch.no_grad():
            for imagenes, labels in loader_val:
                imagenes = imagenes.to(DEVICE)
                labels   = labels.to(DEVICE).unsqueeze(1)
                salida   = modelo_local(imagenes)
                loss     = criterio(salida, labels)
                probs    = torch.sigmoid(salida).squeeze(1).cpu().numpy()
                val_loss      += loss.item()
                preds          = (torch.sigmoid(salida) >= 0.5).float()
                val_correctos += (preds == labels).sum().item()
                todas_probs.extend(probs)
                todos_labels.extend(labels.squeeze(1).cpu().numpy())

        train_loss /= len(loader_train)
        val_loss   /= len(loader_val)
        train_acc   = train_correctos / len(loader_train.dataset)
        val_acc     = val_correctos   / len(loader_val.dataset)
        val_auc     = roc_auc_score(todos_labels, todas_probs)

        print(f"      [ditto/{nombre}] época {epoca+1:02d}/{epochs} — "
              f"loss: {train_loss:.4f} acc: {train_acc:.4f} | "
              f"val_loss: {val_loss:.4f} acc: {val_acc:.4f} | auc: {val_auc:.4f}")

        if val_auc > mejor_val_auc:
            mejor_val_auc  = val_auc
            mejor_val_loss = val_loss
            mejor_val_acc  = val_acc
            mejor_estado   = copy.deepcopy(modelo_local.state_dict())
            print(f"        → mejor época local: {epoca+1} | auc: {mejor_val_auc:.4f}")

    # Cargar mejor estado en el modelo local
    if mejor_estado is not None:
        modelo_local.load_state_dict(mejor_estado)

    return mejor_val_loss, mejor_val_acc, mejor_val_auc

# %% [markdown]
# <h1><b>Entrenamiento

# %%
# Paso 1: cada centro entrena copia del global - FedAvg
# Paso 2: cada centro personaliza su modelo local - Ditto

mejor_val_global    = 0.0
mejores_val_locales = {nombre: 0.0 for nombre in CENTROS.keys()}
rondas_sin_mejora   = 0
total_muestras      = sum(d["n_train"] for d in datos_centros.values())

historial = {"ronda": [], "val_auc_global": [], "val_auc_locales": []}

for ronda in range(1, RONDAS + 1):

    print(f"\n{'='*60}")
    print(f"  RONDA {ronda}/{RONDAS}")
    print(f"{'='*60}")

    set_seed(SEED + ronda)

    # Reiniciar generator
    g = torch.Generator()
    g.manual_seed(SEED + ronda)
    for nombre, datos in datos_centros.items():
        datos["loader_train"] = DataLoader(
            datos["loader_train"].dataset,
            batch_size=BATCH_SIZE,
            shuffle=True,
            worker_init_fn=seed_worker,
            generator=g
        )

    # Entrenamiento global
    print(f"\n  ── Entrenamiento global ──")
    pesos_centros    = []
    val_aucs_global  = []
    muestras_centros = []

    for nombre, datos in datos_centros.items():
        print(f"\n  Centro: {nombre}")
        set_seed(SEED + ronda)
        pesos, val_loss, val_acc, val_auc = entrenar_global(
            nombre,
            modelo_global,
            datos["loader_train"],
            datos["loader_val"],
            EPOCHS_LOCAL
        )
        pesos_centros.append(pesos)
        val_aucs_global.append(val_auc)
        muestras_centros.append(datos["n_train"])

    # FedAvg — actualizar modelo global
    pesos_globales = agregar_pesos(pesos_centros, muestras_centros)
    modelo_global.load_state_dict(pesos_globales)

    # Val global ponderada por AUC
    val_global = sum(
        va * (n / total_muestras)
        for va, n in zip(val_aucs_global, muestras_centros)
    )

    # Guardar mejor modelo global + early stopping
    if val_global > mejor_val_global:
        mejor_val_global  = val_global
        rondas_sin_mejora = 0
        torch.save(modelo_global.state_dict(), MODELO_GLOBAL_PATH)
        print(f"\n  - Mejor modelo global guardado (val_auc: {mejor_val_global:.4f})")

        # ── Personalización Ditto — solo si el global mejoró ──
        print(f"\n  ── Personalización Ditto ──")
        val_aucs_locales = {}

        for nombre, datos in datos_centros.items():
            print(f"\n  Centro: {nombre}")
            set_seed(SEED + ronda)
            val_loss, val_acc, val_auc = entrenar_ditto(
                nombre,
                modelos_locales[nombre],
                modelo_global,
                datos["loader_train"],
                datos["loader_val"],
                EPOCHS_DITTO
            )
            val_aucs_locales[nombre] = val_auc

            if val_auc > mejores_val_locales[nombre]:
                mejores_val_locales[nombre] = val_auc
                torch.save(modelos_locales[nombre].state_dict(),
                           MODELOS_LOCALES_PATHS[nombre])
                print(f"    - Mejor modelo local guardado | auc: {val_auc:.4f}")

    else:
        rondas_sin_mejora += 1
        print(f"  Sin mejora global {rondas_sin_mejora}/{PACIENCIA}")
        val_aucs_locales = {nombre: mejores_val_locales[nombre] for nombre in CENTROS.keys()}

    # Resumen de ronda
    historial["ronda"].append(ronda)
    historial["val_auc_global"].append(val_global)
    historial["val_auc_locales"].append(val_aucs_locales)

    print(f"\n  {'─'*55}")
    print(f"  Ronda {ronda} — val_auc global: {val_global:.4f}")
    print(f"  Val AUC locales:")
    for nombre, auc in val_aucs_locales.items():
        print(f"    {nombre} → {auc:.4f}")

    # Early stopping
    if rondas_sin_mejora >= PACIENCIA:
        print(f"\n  Early stopping en ronda {ronda}")
        break

print(f"\n{'='*60}")
print(f"Entrenamiento Ditto finalizado")
print(f"Mejor val_auc global : {mejor_val_global:.4f}")
print(f"Mejores val_auc locales:")
for nombre, auc in mejores_val_locales.items():
    print(f"  {nombre} -> {auc:.4f}")
# Out:
# ============================================================
#   RONDA 1/30
# ============================================================
#
#   ── Entrenamiento global ──
#
#   Centro: center_1
#       [global/center_1] época 01/20 — loss: 0.2237 acc: 0.9054 | val_loss: 0.0802 acc: 0.9720 | auc: 0.9959
#         → mejor época global: 1 | auc: 0.9959
#       [global/center_1] época 02/20 — loss: 0.0673 acc: 0.9762 | val_loss: 0.0662 acc: 0.9819 | auc: 0.9965
#         → mejor época global: 2 | auc: 0.9965
#       [global/center_1] época 03/20 — loss: 0.0192 acc: 0.9938 | val_loss: 0.0851 acc: 0.9720 | auc: 0.9969
#         → mejor época global: 3 | auc: 0.9969
#       [global/center_1] época 04/20 — loss: 0.0238 acc: 0.9926 | val_loss: 0.0563 acc: 0.9786 | auc: 0.9990
#         → mejor época global: 4 | auc: 0.9990
#       [global/center_1] época 05/20 — loss: 0.0202 acc: 0.9926 | val_loss: 0.1468 acc: 0.9605 | auc: 0.9982
#       [global/center_1] época 06/20 — loss: 0.0186 acc: 0.9938 | val_loss: 0.0493 acc: 0.9819 | auc: 0.9989
#       [global/center_1] época 07/20 — loss: 0.0104 acc: 0.9955 | val_loss: 0.0179 acc: 0.9951 | auc: 0.9996
#         → mejor época global: 7 | auc: 0.9996
#       [global/center_1] época 08/20 — loss: 0.0032 acc: 0.9996 | val_loss: 0.0105 acc: 0.9967 | auc: 1.0000
#         → mejor época global: 8 | auc: 1.0000
#       [global/center_1] época 09/20 — loss: 0.0009 acc: 1.0000 | val_loss: 0.0104 acc: 0.9967 | auc: 0.9999
#       [global/center_1] época 10/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.0084 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 11/20 — loss: 0.0008 acc: 1.0000 | val_loss: 0.0199 acc: 0.9951 | auc: 0.9998
#       [global/center_1] época 12/20 — loss: 0.0470 acc: 0.9831 | val_loss: 0.0294 acc: 0.9868 | auc: 0.9996
#       [global/center_1] época 13/20 — loss: 0.0142 acc: 0.9963 | val_loss: 0.0286 acc: 0.9901 | auc: 0.9996
#       [global/center_1] época 14/20 — loss: 0.0051 acc: 0.9979 | val_loss: 0.0134 acc: 0.9951 | auc: 0.9998
#       [global/center_1] época 15/20 — loss: 0.0014 acc: 1.0000 | val_loss: 0.0088 acc: 0.9984 | auc: 0.9999
#       [global/center_1] época 16/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.0165 acc: 0.9934 | auc: 0.9999
#       [global/center_1] época 17/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.0142 acc: 0.9951 | auc: 0.9999
#       [global/center_1] época 18/20 — loss: 0.0087 acc: 0.9984 | val_loss: 0.0185 acc: 0.9901 | auc: 0.9998
#       [global/center_1] época 19/20 — loss: 0.0010 acc: 1.0000 | val_loss: 0.0131 acc: 0.9951 | auc: 0.9999
#       [global/center_1] época 20/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.0134 acc: 0.9951 | auc: 0.9999
#
#   Centro: center_2
#       [global/center_2] época 01/20 — loss: 0.3166 acc: 0.8568 | val_loss: 0.1847 acc: 0.9427 | auc: 0.9843
#         → mejor época global: 1 | auc: 0.9843
#       [global/center_2] época 02/20 — loss: 0.0657 acc: 0.9857 | val_loss: 0.0725 acc: 0.9740 | auc: 0.9977
#         → mejor época global: 2 | auc: 0.9977
#       [global/center_2] época 03/20 — loss: 0.0376 acc: 0.9896 | val_loss: 0.0832 acc: 0.9844 | auc: 0.9916
#       [global/center_2] época 04/20 — loss: 0.0369 acc: 0.9896 | val_loss: 0.1305 acc: 0.9583 | auc: 0.9896
#       [global/center_2] época 05/20 — loss: 0.0382 acc: 0.9870 | val_loss: 0.1685 acc: 0.9583 | auc: 0.9925
#       [global/center_2] época 06/20 — loss: 0.0572 acc: 0.9792 | val_loss: 0.2708 acc: 0.9115 | auc: 0.9864
#       [global/center_2] época 07/20 — loss: 0.0331 acc: 0.9870 | val_loss: 0.0645 acc: 0.9844 | auc: 0.9931
#       [global/center_2] época 08/20 — loss: 0.0065 acc: 0.9987 | val_loss: 0.0750 acc: 0.9844 | auc: 0.9933
#       [global/center_2] época 09/20 — loss: 0.0041 acc: 1.0000 | val_loss: 0.0912 acc: 0.9844 | auc: 0.9941
#       [global/center_2] época 10/20 — loss: 0.0018 acc: 1.0000 | val_loss: 0.0803 acc: 0.9844 | auc: 0.9955
#       [global/center_2] época 11/20 — loss: 0.0032 acc: 0.9987 | val_loss: 0.0479 acc: 0.9896 | auc: 0.9977
#       [global/center_2] época 12/20 — loss: 0.0018 acc: 1.0000 | val_loss: 0.0890 acc: 0.9844 | auc: 0.9968
#       [global/center_2] época 13/20 — loss: 0.0010 acc: 1.0000 | val_loss: 0.0865 acc: 0.9844 | auc: 0.9971
#       [global/center_2] época 14/20 — loss: 0.0008 acc: 1.0000 | val_loss: 0.0890 acc: 0.9844 | auc: 0.9972
#       [global/center_2] época 15/20 — loss: 0.0009 acc: 1.0000 | val_loss: 0.0752 acc: 0.9844 | auc: 0.9973
#       [global/center_2] época 16/20 — loss: 0.0006 acc: 1.0000 | val_loss: 0.0897 acc: 0.9844 | auc: 0.9969
#       [global/center_2] época 17/20 — loss: 0.0006 acc: 1.0000 | val_loss: 0.0887 acc: 0.9844 | auc: 0.9971
#       [global/center_2] época 18/20 — loss: 0.0017 acc: 1.0000 | val_loss: 0.0412 acc: 0.9896 | auc: 0.9992
#         → mejor época global: 18 | auc: 0.9992
#       [global/center_2] época 19/20 — loss: 0.0012 acc: 1.0000 | val_loss: 0.0747 acc: 0.9844 | auc: 0.9983
#       [global/center_2] época 20/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.0732 acc: 0.9844 | auc: 0.9980
#
#   Centro: center_3
#       [global/center_3] época 01/20 — loss: 0.1492 acc: 0.6838 | val_loss: 0.1478 acc: 0.7111 | auc: 0.7773
#         → mejor época global: 1 | auc: 0.7773
#       [global/center_3] época 02/20 — loss: 0.0497 acc: 0.9412 | val_loss: 0.4242 acc: 0.5111 | auc: 0.7826
#         → mejor época global: 2 | auc: 0.7826
#       [global/center_3] época 03/20 — loss: 0.0386 acc: 0.9596 | val_loss: 0.7831 acc: 0.4222 | auc: 0.8582
#         → mejor época global: 3 | auc: 0.8582
#       [global/center_3] época 04/20 — loss: 0.0314 acc: 0.9540 | val_loss: 0.1729 acc: 0.7407 | auc: 0.8757
#         → mejor época global: 4 | auc: 0.8757
#       [global/center_3] época 05/20 — loss: 0.0067 acc: 0.9926 | val_loss: 0.1735 acc: 0.7778 | auc: 0.8479
#       [global/center_3] época 06/20 — loss: 0.0080 acc: 0.9926 | val_loss: 0.1881 acc: 0.7852 | auc: 0.8561
#       [global/center_3] época 07/20 — loss: 0.0067 acc: 0.9926 | val_loss: 0.1629 acc: 0.7852 | auc: 0.8657
#       [global/center_3] época 08/20 — loss: 0.0052 acc: 0.9926 | val_loss: 0.2270 acc: 0.7778 | auc: 0.8726
#       [global/center_3] época 09/20 — loss: 0.0057 acc: 0.9908 | val_loss: 0.2056 acc: 0.7704 | auc: 0.8733
#       [global/center_3] época 10/20 — loss: 0.0261 acc: 0.9669 | val_loss: 0.2049 acc: 0.7926 | auc: 0.8453
#       [global/center_3] época 11/20 — loss: 0.0437 acc: 0.9449 | val_loss: 0.1648 acc: 0.7407 | auc: 0.8546
#       [global/center_3] época 12/20 — loss: 0.0182 acc: 0.9761 | val_loss: 0.1232 acc: 0.7926 | auc: 0.8942
#         → mejor época global: 12 | auc: 0.8942
#       [global/center_3] época 13/20 — loss: 0.0100 acc: 0.9890 | val_loss: 0.1726 acc: 0.7852 | auc: 0.8858
#       [global/center_3] época 14/20 — loss: 0.0057 acc: 0.9926 | val_loss: 0.1864 acc: 0.7852 | auc: 0.8934
#       [global/center_3] época 15/20 — loss: 0.0050 acc: 0.9963 | val_loss: 0.2238 acc: 0.7630 | auc: 0.8819
#       [global/center_3] época 16/20 — loss: 0.0049 acc: 0.9945 | val_loss: 0.2026 acc: 0.7926 | auc: 0.9045
#         → mejor época global: 16 | auc: 0.9045
#       [global/center_3] época 17/20 — loss: 0.0015 acc: 0.9982 | val_loss: 0.1663 acc: 0.8222 | auc: 0.9054
#         → mejor época global: 17 | auc: 0.9054
#       [global/center_3] época 18/20 — loss: 0.0011 acc: 1.0000 | val_loss: 0.1624 acc: 0.8370 | auc: 0.9076
#         → mejor época global: 18 | auc: 0.9076
#       [global/center_3] época 19/20 — loss: 0.0008 acc: 1.0000 | val_loss: 0.1769 acc: 0.8148 | auc: 0.9078
#         → mejor época global: 19 | auc: 0.9078
#       [global/center_3] época 20/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.1760 acc: 0.8296 | auc: 0.9078
#
#   Centro: center_4
#       [global/center_4] época 01/20 — loss: 0.4190 acc: 0.7637 | val_loss: 0.2979 acc: 0.8555 | auc: 0.9374
#         → mejor época global: 1 | auc: 0.9374
#       [global/center_4] época 02/20 — loss: 0.1802 acc: 0.9336 | val_loss: 0.2695 acc: 0.8984 | auc: 0.9580
#         → mejor época global: 2 | auc: 0.9580
#       [global/center_4] época 03/20 — loss: 0.1071 acc: 0.9561 | val_loss: 0.3542 acc: 0.8594 | auc: 0.9698
#         → mejor época global: 3 | auc: 0.9698
#       [global/center_4] época 04/20 — loss: 0.0476 acc: 0.9854 | val_loss: 0.2250 acc: 0.9102 | auc: 0.9693
#       [global/center_4] época 05/20 — loss: 0.0436 acc: 0.9844 | val_loss: 0.2681 acc: 0.9180 | auc: 0.9598
#       [global/center_4] época 06/20 — loss: 0.0190 acc: 0.9941 | val_loss: 0.2686 acc: 0.9258 | auc: 0.9652
#       [global/center_4] época 07/20 — loss: 0.0472 acc: 0.9795 | val_loss: 0.5866 acc: 0.8672 | auc: 0.9573
#       [global/center_4] época 08/20 — loss: 0.0500 acc: 0.9766 | val_loss: 0.2227 acc: 0.9336 | auc: 0.9724
#         → mejor época global: 8 | auc: 0.9724
#       [global/center_4] época 09/20 — loss: 0.0404 acc: 0.9854 | val_loss: 0.2489 acc: 0.9180 | auc: 0.9711
#       [global/center_4] época 10/20 — loss: 0.0314 acc: 0.9902 | val_loss: 0.2867 acc: 0.8945 | auc: 0.9689
#       [global/center_4] época 11/20 — loss: 0.0300 acc: 0.9902 | val_loss: 0.4324 acc: 0.8906 | auc: 0.9701
#       [global/center_4] época 12/20 — loss: 0.0505 acc: 0.9795 | val_loss: 0.2955 acc: 0.8945 | auc: 0.9665
#       [global/center_4] época 13/20 — loss: 0.0370 acc: 0.9912 | val_loss: 0.3668 acc: 0.9023 | auc: 0.9653
#       [global/center_4] época 14/20 — loss: 0.0397 acc: 0.9854 | val_loss: 0.2474 acc: 0.9180 | auc: 0.9699
#       [global/center_4] época 15/20 — loss: 0.0088 acc: 0.9980 | val_loss: 0.3529 acc: 0.8984 | auc: 0.9735
#         → mejor época global: 15 | auc: 0.9735
#       [global/center_4] época 16/20 — loss: 0.0033 acc: 1.0000 | val_loss: 0.3355 acc: 0.9102 | auc: 0.9792
#         → mejor época global: 16 | auc: 0.9792
#       [global/center_4] época 17/20 — loss: 0.0018 acc: 1.0000 | val_loss: 0.3110 acc: 0.9102 | auc: 0.9821
#         → mejor época global: 17 | auc: 0.9821
#       [global/center_4] época 18/20 — loss: 0.0012 acc: 1.0000 | val_loss: 0.3172 acc: 0.9102 | auc: 0.9816
#       [global/center_4] época 19/20 — loss: 0.0007 acc: 1.0000 | val_loss: 0.3011 acc: 0.9102 | auc: 0.9819
#       [global/center_4] época 20/20 — loss: 0.0009 acc: 1.0000 | val_loss: 0.3665 acc: 0.9102 | auc: 0.9819
#
#   - Mejor modelo global guardado (val_auc: 0.9855)
#
#   ── Personalización Ditto ──
#
#   Centro: center_1
#       [ditto/center_1] época 01/15 — loss: 0.1061 acc: 0.9581 | val_loss: 0.0491 acc: 0.9836 | auc: 0.9982
#         → mejor época local: 1 | auc: 0.9982
#       [ditto/center_1] época 02/15 — loss: 0.0146 acc: 0.9975 | val_loss: 0.0352 acc: 0.9868 | auc: 0.9995
#         → mejor época local: 2 | auc: 0.9995
#       [ditto/center_1] época 03/15 — loss: 0.0091 acc: 0.9988 | val_loss: 0.0277 acc: 0.9934 | auc: 0.9996
#         → mejor época local: 3 | auc: 0.9996
#       [ditto/center_1] época 04/15 — loss: 0.0080 acc: 0.9992 | val_loss: 0.0337 acc: 0.9934 | auc: 0.9988
#       [ditto/center_1] época 05/15 — loss: 0.0194 acc: 0.9947 | val_loss: 0.0276 acc: 0.9951 | auc: 0.9995
#       [ditto/center_1] época 06/15 — loss: 0.0474 acc: 0.9836 | val_loss: 0.1062 acc: 0.9589 | auc: 0.9957
#       [ditto/center_1] época 07/15 — loss: 0.0112 acc: 0.9963 | val_loss: 0.0882 acc: 0.9704 | auc: 0.9987
#       [ditto/center_1] época 08/15 — loss: 0.0061 acc: 0.9992 | val_loss: 0.0515 acc: 0.9836 | auc: 0.9994
#       [ditto/center_1] época 09/15 — loss: 0.0124 acc: 0.9959 | val_loss: 0.1428 acc: 0.9539 | auc: 0.9993
#       [ditto/center_1] época 10/15 — loss: 0.0137 acc: 0.9967 | val_loss: 0.0449 acc: 0.9868 | auc: 0.9994
#       [ditto/center_1] época 11/15 — loss: 0.0145 acc: 0.9963 | val_loss: 0.0344 acc: 0.9901 | auc: 0.9994
#       [ditto/center_1] época 12/15 — loss: 0.0096 acc: 0.9984 | val_loss: 0.0269 acc: 0.9951 | auc: 0.9996
#         → mejor época local: 12 | auc: 0.9996
#       [ditto/center_1] época 13/15 — loss: 0.0072 acc: 0.9992 | val_loss: 0.0274 acc: 0.9951 | auc: 0.9997
#         → mejor época local: 13 | auc: 0.9997
#       [ditto/center_1] época 14/15 — loss: 0.0200 acc: 0.9930 | val_loss: 0.0364 acc: 0.9868 | auc: 0.9991
#       [ditto/center_1] época 15/15 — loss: 0.0072 acc: 0.9988 | val_loss: 0.0346 acc: 0.9885 | auc: 0.9989
#     - Mejor modelo local guardado | auc: 0.9997
#
#   Centro: center_2
#       [ditto/center_2] época 01/15 — loss: 0.2858 acc: 0.8841 | val_loss: 0.1143 acc: 0.9740 | auc: 0.9935
#         → mejor época local: 1 | auc: 0.9935
#       [ditto/center_2] época 02/15 — loss: 0.0903 acc: 0.9805 | val_loss: 0.1146 acc: 0.9635 | auc: 0.9911
#       [ditto/center_2] época 03/15 — loss: 0.0382 acc: 0.9935 | val_loss: 0.0807 acc: 0.9792 | auc: 0.9969
#         → mejor época local: 3 | auc: 0.9969
#       [ditto/center_2] época 04/15 — loss: 0.0514 acc: 0.9870 | val_loss: 0.0793 acc: 0.9792 | auc: 0.9914
#       [ditto/center_2] época 05/15 — loss: 0.0711 acc: 0.9740 | val_loss: 0.1234 acc: 0.9479 | auc: 0.9920
#       [ditto/center_2] época 06/15 — loss: 0.0337 acc: 0.9935 | val_loss: 0.0761 acc: 0.9740 | auc: 0.9956
#       [ditto/center_2] época 07/15 — loss: 0.0290 acc: 0.9922 | val_loss: 0.0637 acc: 0.9792 | auc: 0.9921
#       [ditto/center_2] época 08/15 — loss: 0.0615 acc: 0.9740 | val_loss: 0.1400 acc: 0.9635 | auc: 0.9807
#       [ditto/center_2] época 09/15 — loss: 0.0709 acc: 0.9766 | val_loss: 0.3718 acc: 0.9115 | auc: 0.9906
#       [ditto/center_2] época 10/15 — loss: 0.0459 acc: 0.9870 | val_loss: 0.1257 acc: 0.9635 | auc: 0.9936
#       [ditto/center_2] época 11/15 — loss: 0.0292 acc: 0.9922 | val_loss: 0.0905 acc: 0.9740 | auc: 0.9942
#       [ditto/center_2] época 12/15 — loss: 0.0179 acc: 0.9974 | val_loss: 0.0849 acc: 0.9792 | auc: 0.9928
#       [ditto/center_2] época 13/15 — loss: 0.0167 acc: 0.9974 | val_loss: 0.0949 acc: 0.9688 | auc: 0.9918
#       [ditto/center_2] época 14/15 — loss: 0.0153 acc: 0.9987 | val_loss: 0.1148 acc: 0.9688 | auc: 0.9955
#       [ditto/center_2] época 15/15 — loss: 0.0472 acc: 0.9909 | val_loss: 0.1077 acc: 0.9635 | auc: 0.9896
#     - Mejor modelo local guardado | auc: 0.9969
#
#   Centro: center_3
#       [ditto/center_3] época 01/15 — loss: 0.1513 acc: 0.7077 | val_loss: 0.2991 acc: 0.5481 | auc: 0.8178
#         → mejor época local: 1 | auc: 0.8178
#       [ditto/center_3] época 02/15 — loss: 0.0549 acc: 0.9099 | val_loss: 0.2677 acc: 0.6815 | auc: 0.8345
#         → mejor época local: 2 | auc: 0.8345
#       [ditto/center_3] época 03/15 — loss: 0.0562 acc: 0.9118 | val_loss: 0.4034 acc: 0.6444 | auc: 0.8436
#         → mejor época local: 3 | auc: 0.8436
#       [ditto/center_3] época 04/15 — loss: 0.0304 acc: 0.9577 | val_loss: 0.2421 acc: 0.7778 | auc: 0.8360
#       [ditto/center_3] época 05/15 — loss: 0.0451 acc: 0.9596 | val_loss: 0.5398 acc: 0.6667 | auc: 0.8240
#       [ditto/center_3] época 06/15 — loss: 0.0231 acc: 0.9651 | val_loss: 0.2933 acc: 0.7556 | auc: 0.7945
#       [ditto/center_3] época 07/15 — loss: 0.0375 acc: 0.9504 | val_loss: 0.3084 acc: 0.7407 | auc: 0.8137
#       [ditto/center_3] época 08/15 — loss: 0.0510 acc: 0.9265 | val_loss: 0.2097 acc: 0.7556 | auc: 0.8329
#       [ditto/center_3] época 09/15 — loss: 0.0450 acc: 0.9449 | val_loss: 0.4851 acc: 0.6741 | auc: 0.8422
#       [ditto/center_3] época 10/15 — loss: 0.0315 acc: 0.9522 | val_loss: 0.2253 acc: 0.8000 | auc: 0.8609
#         → mejor época local: 10 | auc: 0.8609
#       [ditto/center_3] época 11/15 — loss: 0.0342 acc: 0.9669 | val_loss: 0.1908 acc: 0.7778 | auc: 0.8666
#         → mejor época local: 11 | auc: 0.8666
#       [ditto/center_3] época 12/15 — loss: 0.0494 acc: 0.9210 | val_loss: 0.4115 acc: 0.7185 | auc: 0.8707
#         → mejor época local: 12 | auc: 0.8707
#       [ditto/center_3] época 13/15 — loss: 0.0266 acc: 0.9706 | val_loss: 0.4351 acc: 0.6889 | auc: 0.8625
#       [ditto/center_3] época 14/15 — loss: 0.0107 acc: 0.9908 | val_loss: 0.6840 acc: 0.6741 | auc: 0.8429
#       [ditto/center_3] época 15/15 — loss: 0.0102 acc: 0.9853 | val_loss: 0.4934 acc: 0.7037 | auc: 0.8321
#     - Mejor modelo local guardado | auc: 0.8707
#
#   Centro: center_4
#       [ditto/center_4] época 01/15 — loss: 0.3436 acc: 0.8330 | val_loss: 0.3080 acc: 0.8867 | auc: 0.9275
#         → mejor época local: 1 | auc: 0.9275
#       [ditto/center_4] época 02/15 — loss: 0.1246 acc: 0.9570 | val_loss: 0.2712 acc: 0.8750 | auc: 0.9446
#         → mejor época local: 2 | auc: 0.9446
#       [ditto/center_4] época 03/15 — loss: 0.0854 acc: 0.9697 | val_loss: 0.2663 acc: 0.8984 | auc: 0.9464
#         → mejor época local: 3 | auc: 0.9464
#       [ditto/center_4] época 04/15 — loss: 0.0803 acc: 0.9629 | val_loss: 0.5567 acc: 0.8203 | auc: 0.9208
#       [ditto/center_4] época 05/15 — loss: 0.0790 acc: 0.9688 | val_loss: 0.4972 acc: 0.8242 | auc: 0.9450
#       [ditto/center_4] época 06/15 — loss: 0.0936 acc: 0.9648 | val_loss: 0.9064 acc: 0.6289 | auc: 0.9455
#       [ditto/center_4] época 07/15 — loss: 0.0689 acc: 0.9756 | val_loss: 0.2619 acc: 0.9062 | auc: 0.9515
#         → mejor época local: 7 | auc: 0.9515
#       [ditto/center_4] época 08/15 — loss: 0.0587 acc: 0.9814 | val_loss: 0.4083 acc: 0.8711 | auc: 0.9279
#       [ditto/center_4] época 09/15 — loss: 0.0555 acc: 0.9775 | val_loss: 0.3164 acc: 0.8750 | auc: 0.9472
#       [ditto/center_4] época 10/15 — loss: 0.0754 acc: 0.9678 | val_loss: 0.2875 acc: 0.9062 | auc: 0.9476
#       [ditto/center_4] época 11/15 — loss: 0.0525 acc: 0.9834 | val_loss: 0.4177 acc: 0.8672 | auc: 0.9331
#       [ditto/center_4] época 12/15 — loss: 0.0778 acc: 0.9639 | val_loss: 0.3490 acc: 0.8789 | auc: 0.9313
#       [ditto/center_4] época 13/15 — loss: 0.0741 acc: 0.9697 | val_loss: 0.3080 acc: 0.8945 | auc: 0.9482
#       [ditto/center_4] época 14/15 — loss: 0.0625 acc: 0.9746 | val_loss: 0.3501 acc: 0.8594 | auc: 0.9419
#       [ditto/center_4] época 15/15 — loss: 0.0338 acc: 0.9912 | val_loss: 0.3494 acc: 0.9062 | auc: 0.9354
#     - Mejor modelo local guardado | auc: 0.9515
#
#   ───────────────────────────────────────────────────────
#   Ronda 1 — val_auc global: 0.9855
#   Val AUC locales:
#     center_1 → 0.9997
#     center_2 → 0.9969
#     center_3 → 0.8707
#     center_4 → 0.9515
#
# ============================================================
#   RONDA 2/30
# ============================================================
#
#   ── Entrenamiento global ──
#
#   Centro: center_1
#       [global/center_1] época 01/20 — loss: 0.0297 acc: 0.9868 | val_loss: 0.0478 acc: 0.9852 | auc: 0.9984
#         → mejor época global: 1 | auc: 0.9984
#       [global/center_1] época 02/20 — loss: 0.0217 acc: 0.9938 | val_loss: 0.0877 acc: 0.9671 | auc: 0.9968
#       [global/center_1] época 03/20 — loss: 0.0208 acc: 0.9926 | val_loss: 0.0492 acc: 0.9868 | auc: 0.9988
#         → mejor época global: 3 | auc: 0.9988
#       [global/center_1] época 04/20 — loss: 0.0085 acc: 0.9979 | val_loss: 0.0239 acc: 0.9918 | auc: 0.9998
#         → mejor época global: 4 | auc: 0.9998
#       [global/center_1] época 05/20 — loss: 0.0092 acc: 0.9971 | val_loss: 0.0462 acc: 0.9852 | auc: 0.9994
#       [global/center_1] época 06/20 — loss: 0.0026 acc: 0.9996 | val_loss: 0.0296 acc: 0.9918 | auc: 0.9996
#       [global/center_1] época 07/20 — loss: 0.0099 acc: 0.9967 | val_loss: 0.0638 acc: 0.9836 | auc: 0.9977
#       [global/center_1] época 08/20 — loss: 0.0309 acc: 0.9868 | val_loss: 0.0334 acc: 0.9836 | auc: 0.9995
#       [global/center_1] época 09/20 — loss: 0.0031 acc: 1.0000 | val_loss: 0.0268 acc: 0.9868 | auc: 0.9998
#         → mejor época global: 9 | auc: 0.9998
#       [global/center_1] época 10/20 — loss: 0.0009 acc: 1.0000 | val_loss: 0.0227 acc: 0.9885 | auc: 0.9998
#         → mejor época global: 10 | auc: 0.9998
#       [global/center_1] época 11/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.0308 acc: 0.9885 | auc: 0.9998
#       [global/center_1] época 12/20 — loss: 0.0048 acc: 0.9992 | val_loss: 0.1155 acc: 0.9655 | auc: 0.9988
#       [global/center_1] época 13/20 — loss: 0.0176 acc: 0.9934 | val_loss: 0.1472 acc: 0.9720 | auc: 0.9916
#       [global/center_1] época 14/20 — loss: 0.0146 acc: 0.9955 | val_loss: 0.0239 acc: 0.9901 | auc: 0.9997
#       [global/center_1] época 15/20 — loss: 0.0187 acc: 0.9951 | val_loss: 0.0282 acc: 0.9901 | auc: 1.0000
#         → mejor época global: 15 | auc: 1.0000
#       [global/center_1] época 16/20 — loss: 0.0038 acc: 0.9992 | val_loss: 0.0251 acc: 0.9951 | auc: 0.9996
#       [global/center_1] época 17/20 — loss: 0.0038 acc: 0.9992 | val_loss: 0.0277 acc: 0.9934 | auc: 0.9999
#       [global/center_1] época 18/20 — loss: 0.0005 acc: 1.0000 | val_loss: 0.0149 acc: 0.9967 | auc: 0.9999
#       [global/center_1] época 19/20 — loss: 0.0057 acc: 0.9971 | val_loss: 0.0194 acc: 0.9951 | auc: 1.0000
#       [global/center_1] época 20/20 — loss: 0.0067 acc: 0.9984 | val_loss: 0.0197 acc: 0.9901 | auc: 0.9999
#
#   Centro: center_2
#       [global/center_2] época 01/20 — loss: 0.2019 acc: 0.9206 | val_loss: 0.0523 acc: 0.9844 | auc: 0.9991
#         → mejor época global: 1 | auc: 0.9991
#       [global/center_2] época 02/20 — loss: 0.0241 acc: 0.9935 | val_loss: 0.0586 acc: 0.9896 | auc: 0.9984
#       [global/center_2] época 03/20 — loss: 0.0093 acc: 0.9987 | val_loss: 0.0402 acc: 0.9896 | auc: 0.9991
#       [global/center_2] época 04/20 — loss: 0.0048 acc: 1.0000 | val_loss: 0.0608 acc: 0.9844 | auc: 0.9983
#       [global/center_2] época 05/20 — loss: 0.0028 acc: 1.0000 | val_loss: 0.0487 acc: 0.9896 | auc: 0.9989
#       [global/center_2] época 06/20 — loss: 0.0014 acc: 1.0000 | val_loss: 0.0488 acc: 0.9896 | auc: 0.9986
#       [global/center_2] época 07/20 — loss: 0.0008 acc: 1.0000 | val_loss: 0.0515 acc: 0.9896 | auc: 0.9985
#       [global/center_2] época 08/20 — loss: 0.0019 acc: 1.0000 | val_loss: 0.0610 acc: 0.9896 | auc: 0.9983
#       [global/center_2] época 09/20 — loss: 0.0010 acc: 1.0000 | val_loss: 0.0652 acc: 0.9896 | auc: 0.9980
#       [global/center_2] época 10/20 — loss: 0.0008 acc: 1.0000 | val_loss: 0.0752 acc: 0.9896 | auc: 0.9980
#       [global/center_2] época 11/20 — loss: 0.0019 acc: 1.0000 | val_loss: 0.0815 acc: 0.9792 | auc: 0.9991
#         → mejor época global: 11 | auc: 0.9991
#       [global/center_2] época 12/20 — loss: 0.0028 acc: 0.9987 | val_loss: 0.0416 acc: 0.9896 | auc: 0.9998
#         → mejor época global: 12 | auc: 0.9998
#       [global/center_2] época 13/20 — loss: 0.1288 acc: 0.9596 | val_loss: 0.1691 acc: 0.9531 | auc: 0.9962
#       [global/center_2] época 14/20 — loss: 0.0873 acc: 0.9753 | val_loss: 0.0647 acc: 0.9740 | auc: 0.9991
#       [global/center_2] época 15/20 — loss: 0.0169 acc: 0.9974 | val_loss: 0.0400 acc: 0.9896 | auc: 0.9995
#       [global/center_2] época 16/20 — loss: 0.0028 acc: 1.0000 | val_loss: 0.0466 acc: 0.9844 | auc: 0.9993
#       [global/center_2] época 17/20 — loss: 0.0024 acc: 1.0000 | val_loss: 0.0392 acc: 0.9896 | auc: 1.0000
#         → mejor época global: 17 | auc: 1.0000
#       [global/center_2] época 18/20 — loss: 0.0008 acc: 1.0000 | val_loss: 0.0365 acc: 0.9896 | auc: 0.9999
#       [global/center_2] época 19/20 — loss: 0.0010 acc: 1.0000 | val_loss: 0.0451 acc: 0.9896 | auc: 0.9998
#       [global/center_2] época 20/20 — loss: 0.0009 acc: 1.0000 | val_loss: 0.0427 acc: 0.9896 | auc: 0.9998
#
#   Centro: center_3
#       [global/center_3] época 01/20 — loss: 0.2199 acc: 0.7904 | val_loss: 0.1929 acc: 0.6889 | auc: 0.8664
#         → mejor época global: 1 | auc: 0.8664
#       [global/center_3] época 02/20 — loss: 0.0469 acc: 0.9393 | val_loss: 0.1114 acc: 0.7704 | auc: 0.8657
#       [global/center_3] época 03/20 — loss: 0.0138 acc: 0.9908 | val_loss: 0.2005 acc: 0.7852 | auc: 0.8681
#         → mejor época global: 3 | auc: 0.8681
#       [global/center_3] época 04/20 — loss: 0.0031 acc: 1.0000 | val_loss: 0.1686 acc: 0.7852 | auc: 0.8764
#         → mejor época global: 4 | auc: 0.8764
#       [global/center_3] época 05/20 — loss: 0.0026 acc: 0.9982 | val_loss: 0.2487 acc: 0.8074 | auc: 0.8702
#       [global/center_3] época 06/20 — loss: 0.0017 acc: 0.9982 | val_loss: 0.2015 acc: 0.7704 | auc: 0.8805
#         → mejor época global: 6 | auc: 0.8805
#       [global/center_3] época 07/20 — loss: 0.0018 acc: 0.9982 | val_loss: 0.2209 acc: 0.7852 | auc: 0.8757
#       [global/center_3] época 08/20 — loss: 0.0005 acc: 1.0000 | val_loss: 0.2374 acc: 0.7704 | auc: 0.8798
#       [global/center_3] época 09/20 — loss: 0.0029 acc: 0.9963 | val_loss: 0.3391 acc: 0.7630 | auc: 0.8831
#         → mejor época global: 9 | auc: 0.8831
#       [global/center_3] época 10/20 — loss: 0.0060 acc: 0.9908 | val_loss: 0.1920 acc: 0.7630 | auc: 0.8863
#         → mejor época global: 10 | auc: 0.8863
#       [global/center_3] época 11/20 — loss: 0.0223 acc: 0.9724 | val_loss: 0.2405 acc: 0.7704 | auc: 0.8585
#       [global/center_3] época 12/20 — loss: 0.0504 acc: 0.9320 | val_loss: 0.2756 acc: 0.7926 | auc: 0.8714
#       [global/center_3] época 13/20 — loss: 0.0310 acc: 0.9596 | val_loss: 0.1415 acc: 0.7852 | auc: 0.8757
#       [global/center_3] época 14/20 — loss: 0.0104 acc: 0.9890 | val_loss: 0.1715 acc: 0.8000 | auc: 0.8798
#       [global/center_3] época 15/20 — loss: 0.0051 acc: 0.9945 | val_loss: 0.2391 acc: 0.8296 | auc: 0.8865
#         → mejor época global: 15 | auc: 0.8865
#       [global/center_3] época 16/20 — loss: 0.0011 acc: 1.0000 | val_loss: 0.1820 acc: 0.8074 | auc: 0.8894
#         → mejor época global: 16 | auc: 0.8894
#       [global/center_3] época 17/20 — loss: 0.0017 acc: 0.9982 | val_loss: 0.3566 acc: 0.8000 | auc: 0.8740
#       [global/center_3] época 18/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.2370 acc: 0.8000 | auc: 0.8788
#       [global/center_3] época 19/20 — loss: 0.0009 acc: 1.0000 | val_loss: 0.2386 acc: 0.8074 | auc: 0.8800
#       [global/center_3] época 20/20 — loss: 0.0009 acc: 0.9982 | val_loss: 0.2375 acc: 0.7852 | auc: 0.8760
#
#   Centro: center_4
#       [global/center_4] época 01/20 — loss: 0.2437 acc: 0.8906 | val_loss: 0.3272 acc: 0.8711 | auc: 0.9631
#         → mejor época global: 1 | auc: 0.9631
#       [global/center_4] época 02/20 — loss: 0.0427 acc: 0.9873 | val_loss: 0.4017 acc: 0.8828 | auc: 0.9549
#       [global/center_4] época 03/20 — loss: 0.0387 acc: 0.9883 | val_loss: 0.3993 acc: 0.8906 | auc: 0.9642
#         → mejor época global: 3 | auc: 0.9642
#       [global/center_4] época 04/20 — loss: 0.0446 acc: 0.9854 | val_loss: 0.5872 acc: 0.8438 | auc: 0.9487
#       [global/center_4] época 05/20 — loss: 0.0612 acc: 0.9707 | val_loss: 0.2236 acc: 0.9102 | auc: 0.9700
#         → mejor época global: 5 | auc: 0.9700
#       [global/center_4] época 06/20 — loss: 0.0306 acc: 0.9893 | val_loss: 0.2526 acc: 0.9180 | auc: 0.9804
#         → mejor época global: 6 | auc: 0.9804
#       [global/center_4] época 07/20 — loss: 0.0248 acc: 0.9902 | val_loss: 0.3366 acc: 0.8945 | auc: 0.9590
#       [global/center_4] época 08/20 — loss: 0.0598 acc: 0.9795 | val_loss: 0.2576 acc: 0.9102 | auc: 0.9646
#       [global/center_4] época 09/20 — loss: 0.0160 acc: 0.9951 | val_loss: 0.2808 acc: 0.9062 | auc: 0.9679
#       [global/center_4] época 10/20 — loss: 0.0041 acc: 1.0000 | val_loss: 0.3038 acc: 0.9102 | auc: 0.9697
#       [global/center_4] época 11/20 — loss: 0.0050 acc: 0.9990 | val_loss: 0.2842 acc: 0.9023 | auc: 0.9690
#       [global/center_4] época 12/20 — loss: 0.0051 acc: 0.9980 | val_loss: 0.3938 acc: 0.8945 | auc: 0.9653
#       [global/center_4] época 13/20 — loss: 0.0093 acc: 0.9951 | val_loss: 0.3696 acc: 0.8906 | auc: 0.9577
#       [global/center_4] época 14/20 — loss: 0.0378 acc: 0.9873 | val_loss: 0.2772 acc: 0.9062 | auc: 0.9673
#       [global/center_4] época 15/20 — loss: 0.0088 acc: 0.9980 | val_loss: 0.3493 acc: 0.9102 | auc: 0.9689
#       [global/center_4] época 16/20 — loss: 0.0220 acc: 0.9951 | val_loss: 0.3725 acc: 0.9180 | auc: 0.9668
#       [global/center_4] época 17/20 — loss: 0.0260 acc: 0.9912 | val_loss: 0.2897 acc: 0.9180 | auc: 0.9711
#       [global/center_4] época 18/20 — loss: 0.0119 acc: 0.9951 | val_loss: 0.2381 acc: 0.9258 | auc: 0.9746
#       [global/center_4] época 19/20 — loss: 0.0060 acc: 0.9980 | val_loss: 0.2922 acc: 0.9258 | auc: 0.9754
#       [global/center_4] época 20/20 — loss: 0.0059 acc: 0.9980 | val_loss: 0.2982 acc: 0.9336 | auc: 0.9710
#   Sin mejora global 1/10
#
#   ───────────────────────────────────────────────────────
#   Ronda 2 — val_auc global: 0.9831
#   Val AUC locales:
#     center_1 → 0.9997
#     center_2 → 0.9969
#     center_3 → 0.8707
#     center_4 → 0.9515
#
# ============================================================
#   RONDA 3/30
# ============================================================
#
#   ── Entrenamiento global ──
#
#   Centro: center_1
#       [global/center_1] época 01/20 — loss: 0.0026 acc: 0.9992 | val_loss: 0.1025 acc: 0.9819 | auc: 0.9994
#         → mejor época global: 1 | auc: 0.9994
#       [global/center_1] época 02/20 — loss: 0.0170 acc: 0.9942 | val_loss: 0.0191 acc: 0.9918 | auc: 0.9999
#         → mejor época global: 2 | auc: 0.9999
#       [global/center_1] época 03/20 — loss: 0.0101 acc: 0.9971 | val_loss: 0.0981 acc: 0.9836 | auc: 0.9985
#       [global/center_1] época 04/20 — loss: 0.0102 acc: 0.9959 | val_loss: 0.0090 acc: 0.9951 | auc: 1.0000
#         → mejor época global: 4 | auc: 1.0000
#       [global/center_1] época 05/20 — loss: 0.0027 acc: 0.9996 | val_loss: 0.0300 acc: 0.9852 | auc: 0.9997
#       [global/center_1] época 06/20 — loss: 0.0034 acc: 0.9988 | val_loss: 0.0251 acc: 0.9885 | auc: 0.9998
#       [global/center_1] época 07/20 — loss: 0.0026 acc: 0.9996 | val_loss: 0.0244 acc: 0.9901 | auc: 0.9998
#       [global/center_1] época 08/20 — loss: 0.0016 acc: 0.9996 | val_loss: 0.1411 acc: 0.9671 | auc: 0.9995
#       [global/center_1] época 09/20 — loss: 0.0118 acc: 0.9963 | val_loss: 0.0782 acc: 0.9704 | auc: 0.9998
#       [global/center_1] época 10/20 — loss: 0.0111 acc: 0.9967 | val_loss: 0.0159 acc: 0.9967 | auc: 0.9998
#       [global/center_1] época 11/20 — loss: 0.0106 acc: 0.9959 | val_loss: 0.0761 acc: 0.9737 | auc: 0.9998
#       [global/center_1] época 12/20 — loss: 0.0062 acc: 0.9979 | val_loss: 0.0199 acc: 0.9918 | auc: 1.0000
#       [global/center_1] época 13/20 — loss: 0.0009 acc: 0.9996 | val_loss: 0.0256 acc: 0.9901 | auc: 1.0000
#       [global/center_1] época 14/20 — loss: 0.0019 acc: 0.9988 | val_loss: 0.0095 acc: 0.9951 | auc: 1.0000
#       [global/center_1] época 15/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0150 acc: 0.9951 | auc: 1.0000
#         → mejor época global: 15 | auc: 1.0000
#       [global/center_1] época 16/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0044 acc: 0.9984 | auc: 1.0000
#       [global/center_1] época 17/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0035 acc: 0.9984 | auc: 1.0000
#       [global/center_1] época 18/20 — loss: 0.0193 acc: 0.9934 | val_loss: 0.0735 acc: 0.9836 | auc: 0.9998
#       [global/center_1] época 19/20 — loss: 0.0083 acc: 0.9971 | val_loss: 0.0246 acc: 0.9885 | auc: 0.9999
#       [global/center_1] época 20/20 — loss: 0.0013 acc: 0.9996 | val_loss: 0.0082 acc: 0.9967 | auc: 1.0000
#
#   Centro: center_2
#       [global/center_2] época 01/20 — loss: 0.2234 acc: 0.9258 | val_loss: 0.0747 acc: 0.9688 | auc: 0.9984
#         → mejor época global: 1 | auc: 0.9984
#       [global/center_2] época 02/20 — loss: 0.0212 acc: 0.9948 | val_loss: 0.0357 acc: 0.9948 | auc: 0.9989
#         → mejor época global: 2 | auc: 0.9989
#       [global/center_2] época 03/20 — loss: 0.0074 acc: 0.9961 | val_loss: 0.0308 acc: 0.9948 | auc: 0.9991
#         → mejor época global: 3 | auc: 0.9991
#       [global/center_2] época 04/20 — loss: 0.0034 acc: 1.0000 | val_loss: 0.0375 acc: 0.9792 | auc: 0.9993
#         → mejor época global: 4 | auc: 0.9993
#       [global/center_2] época 05/20 — loss: 0.0015 acc: 1.0000 | val_loss: 0.0349 acc: 0.9948 | auc: 0.9991
#       [global/center_2] época 06/20 — loss: 0.0024 acc: 1.0000 | val_loss: 0.0213 acc: 0.9896 | auc: 0.9999
#         → mejor época global: 6 | auc: 0.9999
#       [global/center_2] época 07/20 — loss: 0.0286 acc: 0.9883 | val_loss: 0.2466 acc: 0.9375 | auc: 0.9960
#       [global/center_2] época 08/20 — loss: 0.0208 acc: 0.9922 | val_loss: 0.0861 acc: 0.9792 | auc: 0.9969
#       [global/center_2] época 09/20 — loss: 0.0344 acc: 0.9883 | val_loss: 0.1096 acc: 0.9688 | auc: 0.9959
#       [global/center_2] época 10/20 — loss: 0.0070 acc: 0.9987 | val_loss: 0.0618 acc: 0.9792 | auc: 0.9996
#       [global/center_2] época 11/20 — loss: 0.0014 acc: 1.0000 | val_loss: 0.0545 acc: 0.9844 | auc: 0.9992
#       [global/center_2] época 12/20 — loss: 0.0009 acc: 1.0000 | val_loss: 0.0549 acc: 0.9844 | auc: 0.9991
#       [global/center_2] época 13/20 — loss: 0.0006 acc: 1.0000 | val_loss: 0.0725 acc: 0.9844 | auc: 0.9991
#       [global/center_2] época 14/20 — loss: 0.0005 acc: 1.0000 | val_loss: 0.0710 acc: 0.9844 | auc: 0.9991
#       [global/center_2] época 15/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.0639 acc: 0.9844 | auc: 0.9991
#       [global/center_2] época 16/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.0585 acc: 0.9844 | auc: 0.9991
#       [global/center_2] época 17/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.0568 acc: 0.9896 | auc: 0.9992
#       [global/center_2] época 18/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.0493 acc: 0.9896 | auc: 0.9992
#       [global/center_2] época 19/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.0550 acc: 0.9896 | auc: 0.9995
#       [global/center_2] época 20/20 — loss: 0.0005 acc: 1.0000 | val_loss: 0.0536 acc: 0.9896 | auc: 0.9995
#
#   Centro: center_3
#       [global/center_3] época 01/20 — loss: 0.3957 acc: 0.8162 | val_loss: 0.1415 acc: 0.7407 | auc: 0.8906
#         → mejor época global: 1 | auc: 0.8906
#       [global/center_3] época 02/20 — loss: 0.0615 acc: 0.8934 | val_loss: 0.1519 acc: 0.7704 | auc: 0.9054
#         → mejor época global: 2 | auc: 0.9054
#       [global/center_3] época 03/20 — loss: 0.0374 acc: 0.9485 | val_loss: 0.1137 acc: 0.8148 | auc: 0.9157
#         → mejor época global: 3 | auc: 0.9157
#       [global/center_3] época 04/20 — loss: 0.0127 acc: 0.9945 | val_loss: 0.1702 acc: 0.8148 | auc: 0.9205
#         → mejor época global: 4 | auc: 0.9205
#       [global/center_3] época 05/20 — loss: 0.0199 acc: 0.9743 | val_loss: 0.1528 acc: 0.8222 | auc: 0.9181
#       [global/center_3] época 06/20 — loss: 0.0023 acc: 0.9982 | val_loss: 0.1438 acc: 0.8296 | auc: 0.9239
#         → mejor época global: 6 | auc: 0.9239
#       [global/center_3] época 07/20 — loss: 0.0018 acc: 0.9982 | val_loss: 0.1514 acc: 0.8222 | auc: 0.9210
#       [global/center_3] época 08/20 — loss: 0.0006 acc: 1.0000 | val_loss: 0.1740 acc: 0.8074 | auc: 0.9179
#       [global/center_3] época 09/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.1869 acc: 0.8148 | auc: 0.9167
#       [global/center_3] época 10/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.1848 acc: 0.8000 | auc: 0.9188
#       [global/center_3] época 11/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.1801 acc: 0.8074 | auc: 0.9193
#       [global/center_3] época 12/20 — loss: 0.0023 acc: 0.9982 | val_loss: 0.2721 acc: 0.8000 | auc: 0.9167
#       [global/center_3] época 13/20 — loss: 0.0040 acc: 0.9963 | val_loss: 0.1893 acc: 0.8148 | auc: 0.9164
#       [global/center_3] época 14/20 — loss: 0.0249 acc: 0.9688 | val_loss: 0.1571 acc: 0.7778 | auc: 0.9033
#       [global/center_3] época 15/20 — loss: 0.0085 acc: 0.9871 | val_loss: 0.1516 acc: 0.8370 | auc: 0.9227
#       [global/center_3] época 16/20 — loss: 0.0050 acc: 0.9945 | val_loss: 0.1374 acc: 0.8444 | auc: 0.9227
#       [global/center_3] época 17/20 — loss: 0.0079 acc: 0.9890 | val_loss: 0.1412 acc: 0.8222 | auc: 0.9148
#       [global/center_3] época 18/20 — loss: 0.0066 acc: 0.9926 | val_loss: 0.2282 acc: 0.8000 | auc: 0.9325
#         → mejor época global: 18 | auc: 0.9325
#       [global/center_3] época 19/20 — loss: 0.0085 acc: 0.9890 | val_loss: 0.1887 acc: 0.8074 | auc: 0.9107
#       [global/center_3] época 20/20 — loss: 0.0026 acc: 0.9945 | val_loss: 0.2310 acc: 0.8000 | auc: 0.9258
#
#   Centro: center_4
#       [global/center_4] época 01/20 — loss: 0.2899 acc: 0.9004 | val_loss: 0.2606 acc: 0.8867 | auc: 0.9470
#         → mejor época global: 1 | auc: 0.9470
#       [global/center_4] época 02/20 — loss: 0.0611 acc: 0.9785 | val_loss: 0.4962 acc: 0.8750 | auc: 0.9550
#         → mejor época global: 2 | auc: 0.9550
#       [global/center_4] época 03/20 — loss: 0.0340 acc: 0.9854 | val_loss: 0.2869 acc: 0.8984 | auc: 0.9546
#       [global/center_4] época 04/20 — loss: 0.0521 acc: 0.9805 | val_loss: 0.4606 acc: 0.8828 | auc: 0.9449
#       [global/center_4] época 05/20 — loss: 0.0484 acc: 0.9834 | val_loss: 0.2647 acc: 0.8984 | auc: 0.9647
#         → mejor época global: 5 | auc: 0.9647
#       [global/center_4] época 06/20 — loss: 0.0124 acc: 0.9961 | val_loss: 0.3246 acc: 0.9023 | auc: 0.9660
#         → mejor época global: 6 | auc: 0.9660
#       [global/center_4] época 07/20 — loss: 0.0048 acc: 0.9990 | val_loss: 0.3324 acc: 0.8984 | auc: 0.9619
#       [global/center_4] época 08/20 — loss: 0.0038 acc: 0.9990 | val_loss: 0.3276 acc: 0.9062 | auc: 0.9692
#         → mejor época global: 8 | auc: 0.9692
#       [global/center_4] época 09/20 — loss: 0.0017 acc: 1.0000 | val_loss: 0.3279 acc: 0.9102 | auc: 0.9747
#         → mejor época global: 9 | auc: 0.9747
#       [global/center_4] época 10/20 — loss: 0.0008 acc: 1.0000 | val_loss: 0.3552 acc: 0.8906 | auc: 0.9726
#       [global/center_4] época 11/20 — loss: 0.0007 acc: 1.0000 | val_loss: 0.3259 acc: 0.9102 | auc: 0.9734
#       [global/center_4] época 12/20 — loss: 0.0649 acc: 0.9805 | val_loss: 0.2862 acc: 0.9180 | auc: 0.9627
#       [global/center_4] época 13/20 — loss: 0.0280 acc: 0.9902 | val_loss: 0.4984 acc: 0.8906 | auc: 0.9652
#       [global/center_4] época 14/20 — loss: 0.0314 acc: 0.9883 | val_loss: 0.4623 acc: 0.8828 | auc: 0.9551
#       [global/center_4] época 15/20 — loss: 0.0279 acc: 0.9902 | val_loss: 0.3967 acc: 0.8672 | auc: 0.9677
#       [global/center_4] época 16/20 — loss: 0.0473 acc: 0.9805 | val_loss: 0.2121 acc: 0.9180 | auc: 0.9726
#       [global/center_4] época 17/20 — loss: 0.0165 acc: 0.9961 | val_loss: 0.3500 acc: 0.9062 | auc: 0.9783
#         → mejor época global: 17 | auc: 0.9783
#       [global/center_4] época 18/20 — loss: 0.0027 acc: 1.0000 | val_loss: 0.2753 acc: 0.9219 | auc: 0.9783
#       [global/center_4] época 19/20 — loss: 0.0016 acc: 1.0000 | val_loss: 0.3163 acc: 0.9180 | auc: 0.9791
#         → mejor época global: 19 | auc: 0.9791
#       [global/center_4] época 20/20 — loss: 0.0039 acc: 0.9980 | val_loss: 0.3225 acc: 0.9102 | auc: 0.9778
#
#   - Mejor modelo global guardado (val_auc: 0.9878)
#
#   ── Personalización Ditto ──
#
#   Centro: center_1
#       [ditto/center_1] época 01/15 — loss: 0.0004 acc: 1.0000 | val_loss: 0.0090 acc: 0.9951 | auc: 1.0000
#         → mejor época local: 1 | auc: 1.0000
#       [ditto/center_1] época 02/15 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0084 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 03/15 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0078 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 04/15 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0094 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 05/15 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0087 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 06/15 — loss: 0.0009 acc: 0.9996 | val_loss: 0.0102 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 07/15 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0078 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 08/15 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0096 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 09/15 — loss: 0.0003 acc: 1.0000 | val_loss: 0.0065 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 10/15 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0084 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 11/15 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0094 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 12/15 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0094 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 13/15 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0081 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 14/15 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0078 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 15/15 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0088 acc: 0.9951 | auc: 1.0000
#     - Mejor modelo local guardado | auc: 1.0000
#
#   Centro: center_2
#       [ditto/center_2] época 01/15 — loss: 0.0525 acc: 0.9831 | val_loss: 0.1205 acc: 0.9688 | auc: 0.9914
#         → mejor época local: 1 | auc: 0.9914
#       [ditto/center_2] época 02/15 — loss: 0.0324 acc: 0.9857 | val_loss: 0.1433 acc: 0.9323 | auc: 0.9941
#         → mejor época local: 2 | auc: 0.9941
#       [ditto/center_2] época 03/15 — loss: 0.0398 acc: 0.9909 | val_loss: 0.1254 acc: 0.9688 | auc: 0.9929
#       [ditto/center_2] época 04/15 — loss: 0.0317 acc: 0.9896 | val_loss: 0.2321 acc: 0.9479 | auc: 0.9905
#       [ditto/center_2] época 05/15 — loss: 0.0417 acc: 0.9870 | val_loss: 0.1847 acc: 0.9583 | auc: 0.9926
#       [ditto/center_2] época 06/15 — loss: 0.0234 acc: 0.9922 | val_loss: 0.1898 acc: 0.9688 | auc: 0.9872
#       [ditto/center_2] época 07/15 — loss: 0.0090 acc: 0.9987 | val_loss: 0.1898 acc: 0.9688 | auc: 0.9875
#       [ditto/center_2] época 08/15 — loss: 0.0132 acc: 0.9948 | val_loss: 0.0782 acc: 0.9896 | auc: 0.9924
#       [ditto/center_2] época 09/15 — loss: 0.0390 acc: 0.9831 | val_loss: 0.1139 acc: 0.9792 | auc: 0.9917
#       [ditto/center_2] época 10/15 — loss: 0.0531 acc: 0.9805 | val_loss: 0.1338 acc: 0.9740 | auc: 0.9924
#       [ditto/center_2] época 11/15 — loss: 0.0139 acc: 0.9948 | val_loss: 0.0921 acc: 0.9740 | auc: 0.9935
#       [ditto/center_2] época 12/15 — loss: 0.0374 acc: 0.9883 | val_loss: 0.1160 acc: 0.9635 | auc: 0.9949
#         → mejor época local: 12 | auc: 0.9949
#       [ditto/center_2] época 13/15 — loss: 0.0465 acc: 0.9870 | val_loss: 0.1304 acc: 0.9740 | auc: 0.9914
#       [ditto/center_2] época 14/15 — loss: 0.0180 acc: 0.9909 | val_loss: 0.1449 acc: 0.9740 | auc: 0.9943
#       [ditto/center_2] época 15/15 — loss: 0.0339 acc: 0.9922 | val_loss: 0.0701 acc: 0.9844 | auc: 0.9950
#         → mejor época local: 15 | auc: 0.9950
#
#   Centro: center_3
#       [ditto/center_3] época 01/15 — loss: 0.0454 acc: 0.9485 | val_loss: 1.0558 acc: 0.6741 | auc: 0.8530
#         → mejor época local: 1 | auc: 0.8530
#       [ditto/center_3] época 02/15 — loss: 0.0461 acc: 0.9504 | val_loss: 0.3475 acc: 0.7407 | auc: 0.8697
#         → mejor época local: 2 | auc: 0.8697
#       [ditto/center_3] época 03/15 — loss: 0.0310 acc: 0.9632 | val_loss: 0.3744 acc: 0.7185 | auc: 0.8776
#         → mejor época local: 3 | auc: 0.8776
#       [ditto/center_3] época 04/15 — loss: 0.0460 acc: 0.9504 | val_loss: 0.2966 acc: 0.8074 | auc: 0.8774
#       [ditto/center_3] época 05/15 — loss: 0.0219 acc: 0.9706 | val_loss: 0.7015 acc: 0.7333 | auc: 0.8546
#       [ditto/center_3] época 06/15 — loss: 0.0340 acc: 0.9577 | val_loss: 0.3024 acc: 0.8000 | auc: 0.8779
#         → mejor época local: 6 | auc: 0.8779
#       [ditto/center_3] época 07/15 — loss: 0.0288 acc: 0.9651 | val_loss: 0.3834 acc: 0.7333 | auc: 0.8432
#       [ditto/center_3] época 08/15 — loss: 0.0381 acc: 0.9596 | val_loss: 0.4379 acc: 0.7333 | auc: 0.8647
#       [ditto/center_3] época 09/15 — loss: 0.0270 acc: 0.9706 | val_loss: 0.8699 acc: 0.7037 | auc: 0.8487
#       [ditto/center_3] época 10/15 — loss: 0.0345 acc: 0.9688 | val_loss: 0.3348 acc: 0.8074 | auc: 0.8755
#       [ditto/center_3] época 11/15 — loss: 0.0201 acc: 0.9798 | val_loss: 0.3400 acc: 0.7852 | auc: 0.8795
#         → mejor época local: 11 | auc: 0.8795
#       [ditto/center_3] época 12/15 — loss: 0.0270 acc: 0.9761 | val_loss: 0.4835 acc: 0.7037 | auc: 0.8429
#       [ditto/center_3] época 13/15 — loss: 0.0383 acc: 0.9577 | val_loss: 0.9153 acc: 0.7407 | auc: 0.8659
#       [ditto/center_3] época 14/15 — loss: 0.0386 acc: 0.9522 | val_loss: 0.2527 acc: 0.7556 | auc: 0.8611
#       [ditto/center_3] época 15/15 — loss: 0.0254 acc: 0.9706 | val_loss: 0.4071 acc: 0.8000 | auc: 0.8817
#         → mejor época local: 15 | auc: 0.8817
#     - Mejor modelo local guardado | auc: 0.8817
#
#   Centro: center_4
#       [ditto/center_4] época 01/15 — loss: 0.0459 acc: 0.9814 | val_loss: 0.4215 acc: 0.8711 | auc: 0.9408
#         → mejor época local: 1 | auc: 0.9408
#       [ditto/center_4] época 02/15 — loss: 0.0462 acc: 0.9814 | val_loss: 0.4644 acc: 0.8672 | auc: 0.9447
#         → mejor época local: 2 | auc: 0.9447
#       [ditto/center_4] época 03/15 — loss: 0.0775 acc: 0.9717 | val_loss: 0.4618 acc: 0.8945 | auc: 0.9463
#         → mejor época local: 3 | auc: 0.9463
#       [ditto/center_4] época 04/15 — loss: 0.0395 acc: 0.9854 | val_loss: 0.4830 acc: 0.8672 | auc: 0.9313
#       [ditto/center_4] época 05/15 — loss: 0.0548 acc: 0.9805 | val_loss: 0.9234 acc: 0.8438 | auc: 0.9359
#       [ditto/center_4] época 06/15 — loss: 0.0385 acc: 0.9854 | val_loss: 0.6534 acc: 0.8867 | auc: 0.9401
#       [ditto/center_4] época 07/15 — loss: 0.0356 acc: 0.9873 | val_loss: 0.5540 acc: 0.8828 | auc: 0.9295
#       [ditto/center_4] época 08/15 — loss: 0.0422 acc: 0.9854 | val_loss: 0.4895 acc: 0.8672 | auc: 0.9385
#       [ditto/center_4] época 09/15 — loss: 0.0583 acc: 0.9775 | val_loss: 0.9673 acc: 0.8633 | auc: 0.9439
#       [ditto/center_4] época 10/15 — loss: 0.0251 acc: 0.9883 | val_loss: 0.5937 acc: 0.8711 | auc: 0.9319
#       [ditto/center_4] época 11/15 — loss: 0.0512 acc: 0.9795 | val_loss: 0.7942 acc: 0.8672 | auc: 0.9520
#         → mejor época local: 11 | auc: 0.9520
#       [ditto/center_4] época 12/15 — loss: 0.0308 acc: 0.9883 | val_loss: 0.4795 acc: 0.8203 | auc: 0.9493
#       [ditto/center_4] época 13/15 — loss: 0.0484 acc: 0.9795 | val_loss: 0.4861 acc: 0.8711 | auc: 0.9397
#       [ditto/center_4] época 14/15 — loss: 0.0221 acc: 0.9941 | val_loss: 0.5448 acc: 0.8906 | auc: 0.9463
#       [ditto/center_4] época 15/15 — loss: 0.0357 acc: 0.9873 | val_loss: 0.7259 acc: 0.8789 | auc: 0.9301
#     - Mejor modelo local guardado | auc: 0.9520
#
#   ───────────────────────────────────────────────────────
#   Ronda 3 — val_auc global: 0.9878
#   Val AUC locales:
#     center_1 → 1.0000
#     center_2 → 0.9950
#     center_3 → 0.8817
#     center_4 → 0.9520
#
# ============================================================
#   RONDA 4/30
# ============================================================
#
#   ── Entrenamiento global ──
#
#   Centro: center_1
#       [global/center_1] época 01/20 — loss: 0.0074 acc: 0.9975 | val_loss: 0.0606 acc: 0.9885 | auc: 0.9990
#         → mejor época global: 1 | auc: 0.9990
#       [global/center_1] época 02/20 — loss: 0.0051 acc: 0.9984 | val_loss: 0.0364 acc: 0.9918 | auc: 0.9997
#         → mejor época global: 2 | auc: 0.9997
#       [global/center_1] época 03/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.0243 acc: 0.9918 | auc: 0.9998
#         → mejor época global: 3 | auc: 0.9998
#       [global/center_1] época 04/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0229 acc: 0.9934 | auc: 0.9998
#         → mejor época global: 4 | auc: 0.9998
#       [global/center_1] época 05/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0236 acc: 0.9934 | auc: 0.9998
#       [global/center_1] época 06/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0309 acc: 0.9934 | auc: 0.9998
#         → mejor época global: 6 | auc: 0.9998
#       [global/center_1] época 07/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0276 acc: 0.9934 | auc: 0.9998
#       [global/center_1] época 08/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0272 acc: 0.9934 | auc: 0.9998
#       [global/center_1] época 09/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0272 acc: 0.9934 | auc: 0.9998
#       [global/center_1] época 10/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0270 acc: 0.9918 | auc: 0.9999
#         → mejor época global: 10 | auc: 0.9999
#       [global/center_1] época 11/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0258 acc: 0.9918 | auc: 0.9999
#         → mejor época global: 11 | auc: 0.9999
#       [global/center_1] época 12/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0500 acc: 0.9901 | auc: 0.9998
#       [global/center_1] época 13/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0351 acc: 0.9918 | auc: 0.9998
#       [global/center_1] época 14/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0390 acc: 0.9918 | auc: 0.9998
#       [global/center_1] época 15/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0367 acc: 0.9918 | auc: 0.9999
#         → mejor época global: 15 | auc: 0.9999
#       [global/center_1] época 16/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0368 acc: 0.9918 | auc: 0.9998
#       [global/center_1] época 17/20 — loss: 0.0154 acc: 0.9963 | val_loss: 0.1203 acc: 0.9737 | auc: 0.9927
#       [global/center_1] época 18/20 — loss: 0.0450 acc: 0.9852 | val_loss: 0.0506 acc: 0.9803 | auc: 0.9992
# ...
#       [global/center_2] época 19/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0592 acc: 0.9844 | auc: 0.9992
#       [global/center_2] época 20/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0623 acc: 0.9844 | auc: 0.9993
#
#   Centro: center_3
#       [global/center_3] época 01/20 — loss: 0.3254 acc: 0.9246 | val_loss: 0.3345 acc: 0.7481 | auc: 0.9191
#         → mejor época global: 1 | auc: 0.9191
#       [global/center_3] época 02/20 — loss: 0.0285 acc: 0.9522 | val_loss: 0.1851 acc: 0.8222 | auc: 0.9243
#         → mejor época global: 2 | auc: 0.9243
#       [global/center_3] época 03/20 — loss: 0.0029 acc: 0.9982 | val_loss: 0.2551 acc: 0.8296 | auc: 0.9246
#         → mejor época global: 3 | auc: 0.9246
#       [global/center_3] época 04/20 — loss: 0.0017 acc: 1.0000 | val_loss: 0.2725 acc: 0.8296 | auc: 0.9258
#         → mejor época global: 4 | auc: 0.9258
#       [global/center_3] época 05/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.2754 acc: 0.8296 | auc: 0.9260
#         → mejor época global: 5 | auc: 0.9260
#       [global/center_3] época 06/20 — loss: 0.0005 acc: 1.0000 | val_loss: 0.2723 acc: 0.8148 | auc: 0.9272
#         → mejor época global: 6 | auc: 0.9272
#       [global/center_3] época 07/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.2803 acc: 0.8222 | auc: 0.9274
#         → mejor época global: 7 | auc: 0.9274
#       [global/center_3] época 08/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.2813 acc: 0.8148 | auc: 0.9279
#         → mejor época global: 8 | auc: 0.9279
#       [global/center_3] época 09/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.2873 acc: 0.8148 | auc: 0.9282
#         → mejor época global: 9 | auc: 0.9282
#       [global/center_3] época 10/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.2914 acc: 0.8222 | auc: 0.9274
#       [global/center_3] época 11/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.2940 acc: 0.8148 | auc: 0.9272
#       [global/center_3] época 12/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.2942 acc: 0.8296 | auc: 0.9267
#       [global/center_3] época 13/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.3415 acc: 0.8074 | auc: 0.9250
#       [global/center_3] época 14/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.3315 acc: 0.8074 | auc: 0.9262
#       [global/center_3] época 15/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.3347 acc: 0.8074 | auc: 0.9255
#       [global/center_3] época 16/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.3413 acc: 0.8074 | auc: 0.9250
#       [global/center_3] época 17/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.3276 acc: 0.8296 | auc: 0.9255
#       [global/center_3] época 18/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.3387 acc: 0.8148 | auc: 0.9250
#       [global/center_3] época 19/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.3386 acc: 0.8148 | auc: 0.9253
#       [global/center_3] época 20/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.3478 acc: 0.8148 | auc: 0.9234
#
#   Centro: center_4
#       [global/center_4] época 01/20 — loss: 0.0228 acc: 0.9980 | val_loss: 0.5198 acc: 0.9180 | auc: 0.9628
#         → mejor época global: 1 | auc: 0.9628
#       [global/center_4] época 02/20 — loss: 0.0286 acc: 0.9912 | val_loss: 0.7844 acc: 0.8945 | auc: 0.9545
#       [global/center_4] época 03/20 — loss: 0.0198 acc: 0.9932 | val_loss: 0.3188 acc: 0.9141 | auc: 0.9706
#         → mejor época global: 3 | auc: 0.9706
#       [global/center_4] época 04/20 — loss: 0.0098 acc: 0.9951 | val_loss: 0.3641 acc: 0.9297 | auc: 0.9722
#         → mejor época global: 4 | auc: 0.9722
#       [global/center_4] época 05/20 — loss: 0.0006 acc: 1.0000 | val_loss: 0.3947 acc: 0.9297 | auc: 0.9722
#       [global/center_4] época 06/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.4059 acc: 0.9297 | auc: 0.9722
#       [global/center_4] época 07/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.4041 acc: 0.9258 | auc: 0.9730
#         → mejor época global: 7 | auc: 0.9730
#       [global/center_4] época 08/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.4188 acc: 0.9297 | auc: 0.9724
#       [global/center_4] época 09/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.4229 acc: 0.9297 | auc: 0.9728
#       [global/center_4] época 10/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.5420 acc: 0.9219 | auc: 0.9734
#         → mejor época global: 10 | auc: 0.9734
#       [global/center_4] época 11/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.4075 acc: 0.9258 | auc: 0.9722
#       [global/center_4] época 12/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.4508 acc: 0.9258 | auc: 0.9729
#       [global/center_4] época 13/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.4540 acc: 0.9297 | auc: 0.9731
#       [global/center_4] época 14/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.4398 acc: 0.9258 | auc: 0.9725
#       [global/center_4] época 15/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.4317 acc: 0.9258 | auc: 0.9725
#       [global/center_4] época 16/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.4528 acc: 0.9258 | auc: 0.9723
#       [global/center_4] época 17/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.4775 acc: 0.9297 | auc: 0.9723
#       [global/center_4] época 18/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.4652 acc: 0.9258 | auc: 0.9722
#       [global/center_4] época 19/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.4850 acc: 0.9297 | auc: 0.9728
#       [global/center_4] época 20/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.5053 acc: 0.9297 | auc: 0.9724
#   Sin mejora global 9/10
#
#   ───────────────────────────────────────────────────────
#   Ronda 13 — val_auc global: 0.9861
#   Val AUC locales:
#     center_1 → 1.0000
#     center_2 → 0.9984
#     center_3 → 0.9191
#     center_4 → 0.9590
#
# ============================================================
#   RONDA 14/30
# ============================================================
#
#   ── Entrenamiento global ──
#
#   Centro: center_1
#       [global/center_1] época 01/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0363 acc: 0.9951 | auc: 1.0000
#         → mejor época global: 1 | auc: 1.0000
#       [global/center_1] época 02/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0270 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 03/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0390 acc: 0.9951 | auc: 1.0000
#       [global/center_1] época 04/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0229 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 05/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0221 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 06/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0278 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 07/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0286 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 08/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0289 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 09/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0184 acc: 0.9984 | auc: 1.0000
#       [global/center_1] época 10/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0194 acc: 0.9984 | auc: 1.0000
#       [global/center_1] época 11/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0193 acc: 0.9984 | auc: 1.0000
#       [global/center_1] época 12/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0286 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 13/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0350 acc: 0.9951 | auc: 1.0000
#       [global/center_1] época 14/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0288 acc: 0.9951 | auc: 1.0000
#       [global/center_1] época 15/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0166 acc: 0.9951 | auc: 1.0000
#       [global/center_1] época 16/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0388 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 17/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0546 acc: 0.9934 | auc: 0.9999
#       [global/center_1] época 18/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0489 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 19/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0586 acc: 0.9934 | auc: 1.0000
#       [global/center_1] época 20/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0539 acc: 0.9934 | auc: 1.0000
#
#   Centro: center_2
#       [global/center_2] época 01/20 — loss: 0.0089 acc: 0.9961 | val_loss: 0.1883 acc: 0.9792 | auc: 0.9981
#         → mejor época global: 1 | auc: 0.9981
#       [global/center_2] época 02/20 — loss: 0.0050 acc: 0.9987 | val_loss: 0.0229 acc: 0.9896 | auc: 1.0000
#         → mejor época global: 2 | auc: 1.0000
#       [global/center_2] época 03/20 — loss: 0.0453 acc: 0.9883 | val_loss: 0.1416 acc: 0.9635 | auc: 0.9992
#       [global/center_2] época 04/20 — loss: 0.0019 acc: 1.0000 | val_loss: 0.0461 acc: 0.9844 | auc: 0.9996
#       [global/center_2] época 05/20 — loss: 0.0025 acc: 0.9987 | val_loss: 0.0238 acc: 0.9844 | auc: 0.9998
#       [global/center_2] época 06/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.0212 acc: 0.9896 | auc: 0.9998
#       [global/center_2] época 07/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0211 acc: 0.9896 | auc: 0.9998
#       [global/center_2] época 08/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0221 acc: 0.9896 | auc: 0.9998
#       [global/center_2] época 09/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0239 acc: 0.9948 | auc: 0.9998
#       [global/center_2] época 10/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0236 acc: 0.9948 | auc: 0.9998
#       [global/center_2] época 11/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0226 acc: 0.9948 | auc: 0.9998
#       [global/center_2] época 12/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0248 acc: 0.9948 | auc: 0.9998
#       [global/center_2] época 13/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0233 acc: 0.9896 | auc: 0.9998
#       [global/center_2] época 14/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0226 acc: 0.9948 | auc: 0.9998
#       [global/center_2] época 15/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0258 acc: 0.9896 | auc: 0.9998
#       [global/center_2] época 16/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0238 acc: 0.9896 | auc: 0.9998
#       [global/center_2] época 17/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0234 acc: 0.9948 | auc: 0.9998
#       [global/center_2] época 18/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0234 acc: 0.9948 | auc: 0.9998
#       [global/center_2] época 19/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0258 acc: 0.9896 | auc: 0.9998
#       [global/center_2] época 20/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0230 acc: 0.9948 | auc: 0.9998
#
#   Centro: center_3
#       [global/center_3] época 01/20 — loss: 0.3425 acc: 0.9118 | val_loss: 0.2067 acc: 0.8222 | auc: 0.9195
#         → mejor época global: 1 | auc: 0.9195
#       [global/center_3] época 02/20 — loss: 0.0104 acc: 0.9853 | val_loss: 0.2129 acc: 0.8519 | auc: 0.9250
#         → mejor época global: 2 | auc: 0.9250
#       [global/center_3] época 03/20 — loss: 0.0047 acc: 0.9945 | val_loss: 0.2868 acc: 0.8519 | auc: 0.9239
#       [global/center_3] época 04/20 — loss: 0.0019 acc: 0.9982 | val_loss: 0.2765 acc: 0.8444 | auc: 0.9229
#       [global/center_3] época 05/20 — loss: 0.0006 acc: 1.0000 | val_loss: 0.2842 acc: 0.8444 | auc: 0.9219
#       [global/center_3] época 06/20 — loss: 0.0006 acc: 1.0000 | val_loss: 0.3011 acc: 0.8519 | auc: 0.9231
#       [global/center_3] época 07/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.3016 acc: 0.8519 | auc: 0.9253
#         → mejor época global: 7 | auc: 0.9253
#       [global/center_3] época 08/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.2935 acc: 0.8444 | auc: 0.9246
#       [global/center_3] época 09/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.3453 acc: 0.8667 | auc: 0.9265
#         → mejor época global: 9 | auc: 0.9265
#       [global/center_3] época 10/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.3538 acc: 0.8667 | auc: 0.9265
#         → mejor época global: 10 | auc: 0.9265
#       [global/center_3] época 11/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.3450 acc: 0.8593 | auc: 0.9260
#       [global/center_3] época 12/20 — loss: 0.0020 acc: 0.9982 | val_loss: 0.5098 acc: 0.8296 | auc: 0.9183
#       [global/center_3] época 13/20 — loss: 0.0014 acc: 0.9982 | val_loss: 0.3117 acc: 0.8444 | auc: 0.9320
#         → mejor época global: 13 | auc: 0.9320
#       [global/center_3] época 14/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.3207 acc: 0.8519 | auc: 0.9375
#         → mejor época global: 14 | auc: 0.9375
#       [global/center_3] época 15/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.3042 acc: 0.8444 | auc: 0.9399
#         → mejor época global: 15 | auc: 0.9399
#       [global/center_3] época 16/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.2893 acc: 0.8593 | auc: 0.9382
#       [global/center_3] época 17/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.3072 acc: 0.8444 | auc: 0.9392
#       [global/center_3] época 18/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.3057 acc: 0.8519 | auc: 0.9385
#       [global/center_3] época 19/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.3071 acc: 0.8444 | auc: 0.9387
#       [global/center_3] época 20/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.3434 acc: 0.8444 | auc: 0.9392
#
#   Centro: center_4
#       [global/center_4] época 01/20 — loss: 0.0085 acc: 0.9971 | val_loss: 0.5718 acc: 0.9219 | auc: 0.9655
#         → mejor época global: 1 | auc: 0.9655
#       [global/center_4] época 02/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.5719 acc: 0.9219 | auc: 0.9668
#         → mejor época global: 2 | auc: 0.9668
#       [global/center_4] época 03/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.6096 acc: 0.9336 | auc: 0.9673
#         → mejor época global: 3 | auc: 0.9673
#       [global/center_4] época 04/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.6151 acc: 0.9297 | auc: 0.9691
#         → mejor época global: 4 | auc: 0.9691
#       [global/center_4] época 05/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.6629 acc: 0.9180 | auc: 0.9670
#       [global/center_4] época 06/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.6044 acc: 0.9219 | auc: 0.9695
#         → mejor época global: 6 | auc: 0.9695
#       [global/center_4] época 07/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6354 acc: 0.9258 | auc: 0.9704
#         → mejor época global: 7 | auc: 0.9704
#       [global/center_4] época 08/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6264 acc: 0.9258 | auc: 0.9705
#         → mejor época global: 8 | auc: 0.9705
#       [global/center_4] época 09/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6438 acc: 0.9180 | auc: 0.9713
#         → mejor época global: 9 | auc: 0.9713
#       [global/center_4] época 10/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6659 acc: 0.9180 | auc: 0.9722
#         → mejor época global: 10 | auc: 0.9722
#       [global/center_4] época 11/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6544 acc: 0.9219 | auc: 0.9718
#       [global/center_4] época 12/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6872 acc: 0.9180 | auc: 0.9723
#         → mejor época global: 12 | auc: 0.9723
#       [global/center_4] época 13/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6582 acc: 0.9219 | auc: 0.9728
#         → mejor época global: 13 | auc: 0.9728
#       [global/center_4] época 14/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.7194 acc: 0.9180 | auc: 0.9724
#       [global/center_4] época 15/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6814 acc: 0.9180 | auc: 0.9728
#         → mejor época global: 15 | auc: 0.9728
#       [global/center_4] época 16/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6526 acc: 0.9219 | auc: 0.9737
#         → mejor época global: 16 | auc: 0.9737
#       [global/center_4] época 17/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6644 acc: 0.9219 | auc: 0.9732
#       [global/center_4] época 18/20 — loss: 0.1286 acc: 0.9590 | val_loss: 0.2505 acc: 0.8711 | auc: 0.9550
#       [global/center_4] época 19/20 — loss: 0.0878 acc: 0.9580 | val_loss: 0.3249 acc: 0.9062 | auc: 0.9603
#       [global/center_4] época 20/20 — loss: 0.0095 acc: 0.9971 | val_loss: 0.2769 acc: 0.9336 | auc: 0.9683
#   Sin mejora global 10/10
#
#   ───────────────────────────────────────────────────────
#   Ronda 14 — val_auc global: 0.9875
#   Val AUC locales:
#     center_1 → 1.0000
#     center_2 → 0.9984
#     center_3 → 0.9191
#     center_4 → 0.9590
#
#   Early stopping en ronda 14
#
# ============================================================
# Entrenamiento Ditto finalizado
# Mejor val_auc global : 0.9892
# Mejores val_auc locales:
#   center_1 -> 1.0000
#   center_2 -> 0.9984
#   center_3 -> 0.9191
#   center_4 -> 0.9590

# %% [markdown]
# <h1><b> Evaluación

# %%
def evaluar_modelo(nombre, modelo, loader_test):
    modelo.eval()
    todos_labels = []
    todos_probs  = []
    todos_preds  = []

    with torch.no_grad():
        for imagenes, labels in loader_test:
            imagenes = imagenes.to(DEVICE)
            salida   = modelo(imagenes)
            probs    = torch.sigmoid(salida).squeeze(1).cpu().numpy()
            preds    = (probs >= 0.5).astype(int)
            todos_labels.extend(labels.numpy().astype(int))
            todos_probs.extend(probs)
            todos_preds.extend(preds)

    return {
        "auc"          : roc_auc_score(todos_labels, todos_probs),
        "f1"           : f1_score(todos_labels, todos_preds),
        "sensibilidad" : recall_score(todos_labels, todos_preds),
        "especificidad": recall_score(todos_labels, todos_preds, pos_label=0),
        "precision"    : precision_score(todos_labels, todos_preds),
        "accuracy"     : sum(p == l for p, l in zip(todos_preds, todos_labels)) / len(todos_labels),
        "cm"           : confusion_matrix(todos_labels, todos_preds),
    }

# Cargar mejor modelo global
modelo_global.load_state_dict(torch.load(MODELO_GLOBAL_PATH, map_location=DEVICE))

# Cargar mejores modelos locales
for nombre in CENTROS.keys():
    modelos_locales[nombre].load_state_dict(
        torch.load(MODELOS_LOCALES_PATHS[nombre], map_location=DEVICE)
    )

# Evaluar
resultados_global = {}
resultados_local  = {}

for nombre, datos in datos_centros.items():
    resultados_global[nombre] = evaluar_modelo(nombre, modelo_global, datos["loader_test"])
    resultados_local[nombre]  = evaluar_modelo(nombre, modelos_locales[nombre], datos["loader_test"])

# Tabla comparativa
metricas = ["auc", "accuracy", "f1", "sensibilidad", "especificidad", "precision"]
nombres  = ["AUC-ROC", "Accuracy", "F1-Score", "Sensibilidad", "Especificidad", "Precisión"]

for nombre in CENTROS.keys():
    print(f"\n{'='*55}")
    print(f"  {nombre.upper()}")
    print(f"{'='*55}")
    print(f"  {'Métrica':<16} {'Global':>12} {'Local Ditto':>12}")
    print(f"  {'─'*42}")
    for metrica, nombre_m in zip(metricas, nombres):
        vg = resultados_global[nombre][metrica]
        vl = resultados_local[nombre][metrica]
        mejor = "←" if vl > vg else ""
        print(f"  {nombre_m:<16} {vg:>12.4f} {vl:>12.4f}  {mejor}")

# Resumen AUC
print(f"\n{'='*55}")
print(f"  RESUMEN AUC-ROC")
print(f"{'='*55}")
print(f"  {'Centro':<12} {'Global':>10} {'Local':>10} {'Mejor':>10}")
print(f"  {'─'*45}")
for nombre in CENTROS.keys():
    vg = resultados_global[nombre]["auc"]
    vl = resultados_local[nombre]["auc"]
    mejor = "Local" if vl > vg else "Global"
    print(f"  {nombre:<12} {vg:>10.4f} {vl:>10.4f} {mejor:>10}")
# Out:
# =======================================================
#   CENTER_1
# =======================================================
#   Métrica                Global  Local Ditto
#   ──────────────────────────────────────────
#   AUC-ROC                0.9661       0.9676  ←
#   Accuracy               0.9171       0.9197  ←
#   F1-Score               0.9168       0.9142
#   Sensibilidad           0.9132       0.8553
#   Especificidad          0.9211       0.9842  ←
#   Precisión              0.9204       0.9819  ←
#
# =======================================================
#   CENTER_2
# =======================================================
#   Métrica                Global  Local Ditto
#   ──────────────────────────────────────────
#   AUC-ROC                0.8438       0.9791  ←
#   Accuracy               0.7167       0.9542  ←
#   F1-Score               0.7748       0.9591  ←
#   Sensibilidad           0.8357       0.9214  ←
#   Especificidad          0.5500       1.0000  ←
#   Precisión              0.7222       1.0000  ←
#
# =======================================================
#   CENTER_3
# =======================================================
#   Métrica                Global  Local Ditto
#   ──────────────────────────────────────────
#   AUC-ROC                0.1673       0.7634  ←
#   Accuracy               0.3099       0.7251  ←
#   F1-Score               0.4636       0.7773  ←
#   Sensibilidad           0.4766       0.7664  ←
#   Especificidad          0.0312       0.6562  ←
#   Precisión              0.4513       0.7885  ←
#
# =======================================================
#   CENTER_4
# =======================================================
#   Métrica                Global  Local Ditto
#   ──────────────────────────────────────────
#   AUC-ROC                0.2705       0.4447  ←
#   Accuracy               0.4375       0.4625  ←
#   F1-Score               0.5853       0.3485
#   Sensibilidad           0.7341       0.2659
#   Especificidad          0.0884       0.6939  ←
#   Precisión              0.4866       0.5055  ←
#
# =======================================================
#   RESUMEN AUC-ROC
# =======================================================
#   Centro           Global      Local      Mejor
#   ─────────────────────────────────────────────
#   center_1         0.9661     0.9676      Local
#   center_2         0.8438     0.9791      Local
#   center_3         0.1673     0.7634      Local
#   center_4         0.2705     0.4447      Local

# %% [markdown]
# <h1><b> Entrenamiento con lambda distintos

# %%
LAMBDA_POR_CENTRO = {
    "center_1": 0.1,
    "center_2": 0.1,
    "center_3": 0.5,
    "center_4": 0.8,
}

# %%
MODELO_GLOBAL_PATH = PESOS_DIR / "modelo_global_ditto_v2.pth"

MODELOS_LOCALES_PATHS = {
    nombre: PESOS_DIR / f"{nombre}_local_ditto_{str(LAMBDA_POR_CENTRO[nombre]).replace('.', '')}.pth"
    for nombre in CENTROS.keys()
}

# %%
# Paso 1: cada centro entrena copia del global - FedAvg
# Paso 2: cada centro personaliza su modelo local - Ditto

mejor_val_global    = 0.0
mejores_val_locales = {nombre: 0.0 for nombre in CENTROS.keys()}
rondas_sin_mejora   = 0
total_muestras      = sum(d["n_train"] for d in datos_centros.values())

historial = {"ronda": [], "val_auc_global": [], "val_auc_locales": []}

for ronda in range(1, RONDAS + 1):

    print(f"\n{'='*60}")
    print(f"  RONDA {ronda}/{RONDAS}")
    print(f"{'='*60}")

    set_seed(SEED + ronda)

    # Reiniciar generator
    g = torch.Generator()
    g.manual_seed(SEED + ronda)
    for nombre, datos in datos_centros.items():
        datos["loader_train"] = DataLoader(
            datos["loader_train"].dataset,
            batch_size=BATCH_SIZE,
            shuffle=True,
            worker_init_fn=seed_worker,
            generator=g
        )

    # Entrenamiento global
    print(f"\n  ── Entrenamiento global ──")
    pesos_centros    = []
    val_aucs_global  = []
    muestras_centros = []

    for nombre, datos in datos_centros.items():
        print(f"\n  Centro: {nombre}")
        set_seed(SEED + ronda)
        pesos, val_loss, val_acc, val_auc = entrenar_global(
            nombre,
            modelo_global,
            datos["loader_train"],
            datos["loader_val"],
            EPOCHS_LOCAL
        )
        pesos_centros.append(pesos)
        val_aucs_global.append(val_auc)
        muestras_centros.append(datos["n_train"])

    # FedAvg — actualizar modelo global
    pesos_globales = agregar_pesos(pesos_centros, muestras_centros)
    modelo_global.load_state_dict(pesos_globales)

    # Val global ponderada por AUC
    val_global = sum(
        va * (n / total_muestras)
        for va, n in zip(val_aucs_global, muestras_centros)
    )

    # Guardar mejor modelo global + early stopping
    if val_global > mejor_val_global:
        mejor_val_global  = val_global
        rondas_sin_mejora = 0
        torch.save(modelo_global.state_dict(), MODELO_GLOBAL_PATH)
        print(f"\n  - Mejor modelo global guardado (val_auc: {mejor_val_global:.4f})")

        # ── Personalización Ditto — solo si el global mejoró ──
        print(f"\n  ── Personalización Ditto ──")
        val_aucs_locales = {}

        for nombre, datos in datos_centros.items():
            print(f"\n  Centro: {nombre}")
            set_seed(SEED + ronda)
            val_loss, val_acc, val_auc = entrenar_ditto(
                nombre,
                modelos_locales[nombre],
                modelo_global,
                datos["loader_train"],
                datos["loader_val"],
                EPOCHS_DITTO,
                lam=LAMBDA_POR_CENTRO[nombre]
            )
            val_aucs_locales[nombre] = val_auc

            if val_auc > mejores_val_locales[nombre]:
                mejores_val_locales[nombre] = val_auc
                torch.save(modelos_locales[nombre].state_dict(),
                           MODELOS_LOCALES_PATHS[nombre])
                print(f"    - Mejor modelo local guardado | auc: {val_auc:.4f}")

    else:
        rondas_sin_mejora += 1
        print(f"  Sin mejora global {rondas_sin_mejora}/{PACIENCIA}")
        val_aucs_locales = {nombre: mejores_val_locales[nombre] for nombre in CENTROS.keys()}

    # Resumen de ronda
    historial["ronda"].append(ronda)
    historial["val_auc_global"].append(val_global)
    historial["val_auc_locales"].append(val_aucs_locales)

    print(f"\n  {'─'*55}")
    print(f"  Ronda {ronda} — val_auc global: {val_global:.4f}")
    print(f"  Val AUC locales:")
    for nombre, auc in val_aucs_locales.items():
        print(f"    {nombre} → {auc:.4f}")

    # Early stopping
    if rondas_sin_mejora >= PACIENCIA:
        print(f"\n  Early stopping en ronda {ronda}")
        break

print(f"\n{'='*60}")
print(f"Entrenamiento Ditto finalizado")
print(f"Mejor val_auc global : {mejor_val_global:.4f}")
print(f"Mejores val_auc locales:")
for nombre, auc in mejores_val_locales.items():
    print(f"  {nombre} -> {auc:.4f}")
# Out:
# ============================================================
#   RONDA 1/30
# ============================================================
#
#   ── Entrenamiento global ──
#
#   Centro: center_1
#       [global/center_1] época 01/20 — loss: 0.2237 acc: 0.9054 | val_loss: 0.0802 acc: 0.9720 | auc: 0.9959
#         → mejor época global: 1 | auc: 0.9959
#       [global/center_1] época 02/20 — loss: 0.0673 acc: 0.9762 | val_loss: 0.0662 acc: 0.9819 | auc: 0.9965
#         → mejor época global: 2 | auc: 0.9965
#       [global/center_1] época 03/20 — loss: 0.0192 acc: 0.9938 | val_loss: 0.0851 acc: 0.9720 | auc: 0.9969
#         → mejor época global: 3 | auc: 0.9969
#       [global/center_1] época 04/20 — loss: 0.0238 acc: 0.9926 | val_loss: 0.0563 acc: 0.9786 | auc: 0.9990
#         → mejor época global: 4 | auc: 0.9990
#       [global/center_1] época 05/20 — loss: 0.0202 acc: 0.9926 | val_loss: 0.1468 acc: 0.9605 | auc: 0.9982
#       [global/center_1] época 06/20 — loss: 0.0186 acc: 0.9938 | val_loss: 0.0493 acc: 0.9819 | auc: 0.9989
#       [global/center_1] época 07/20 — loss: 0.0104 acc: 0.9955 | val_loss: 0.0179 acc: 0.9951 | auc: 0.9996
#         → mejor época global: 7 | auc: 0.9996
#       [global/center_1] época 08/20 — loss: 0.0032 acc: 0.9996 | val_loss: 0.0105 acc: 0.9967 | auc: 1.0000
#         → mejor época global: 8 | auc: 1.0000
#       [global/center_1] época 09/20 — loss: 0.0009 acc: 1.0000 | val_loss: 0.0104 acc: 0.9967 | auc: 0.9999
#       [global/center_1] época 10/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.0084 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 11/20 — loss: 0.0008 acc: 1.0000 | val_loss: 0.0199 acc: 0.9951 | auc: 0.9998
#       [global/center_1] época 12/20 — loss: 0.0470 acc: 0.9831 | val_loss: 0.0294 acc: 0.9868 | auc: 0.9996
#       [global/center_1] época 13/20 — loss: 0.0142 acc: 0.9963 | val_loss: 0.0286 acc: 0.9901 | auc: 0.9996
#       [global/center_1] época 14/20 — loss: 0.0051 acc: 0.9979 | val_loss: 0.0134 acc: 0.9951 | auc: 0.9998
#       [global/center_1] época 15/20 — loss: 0.0014 acc: 1.0000 | val_loss: 0.0088 acc: 0.9984 | auc: 0.9999
#       [global/center_1] época 16/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.0165 acc: 0.9934 | auc: 0.9999
#       [global/center_1] época 17/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.0142 acc: 0.9951 | auc: 0.9999
#       [global/center_1] época 18/20 — loss: 0.0087 acc: 0.9984 | val_loss: 0.0185 acc: 0.9901 | auc: 0.9998
#       [global/center_1] época 19/20 — loss: 0.0010 acc: 1.0000 | val_loss: 0.0131 acc: 0.9951 | auc: 0.9999
#       [global/center_1] época 20/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.0134 acc: 0.9951 | auc: 0.9999
#
#   Centro: center_2
#       [global/center_2] época 01/20 — loss: 0.3166 acc: 0.8568 | val_loss: 0.1847 acc: 0.9427 | auc: 0.9843
#         → mejor época global: 1 | auc: 0.9843
#       [global/center_2] época 02/20 — loss: 0.0657 acc: 0.9857 | val_loss: 0.0725 acc: 0.9740 | auc: 0.9977
#         → mejor época global: 2 | auc: 0.9977
#       [global/center_2] época 03/20 — loss: 0.0376 acc: 0.9896 | val_loss: 0.0832 acc: 0.9844 | auc: 0.9916
#       [global/center_2] época 04/20 — loss: 0.0369 acc: 0.9896 | val_loss: 0.1305 acc: 0.9583 | auc: 0.9896
#       [global/center_2] época 05/20 — loss: 0.0382 acc: 0.9870 | val_loss: 0.1685 acc: 0.9583 | auc: 0.9925
#       [global/center_2] época 06/20 — loss: 0.0572 acc: 0.9792 | val_loss: 0.2708 acc: 0.9115 | auc: 0.9864
#       [global/center_2] época 07/20 — loss: 0.0331 acc: 0.9870 | val_loss: 0.0645 acc: 0.9844 | auc: 0.9931
#       [global/center_2] época 08/20 — loss: 0.0065 acc: 0.9987 | val_loss: 0.0750 acc: 0.9844 | auc: 0.9933
#       [global/center_2] época 09/20 — loss: 0.0041 acc: 1.0000 | val_loss: 0.0912 acc: 0.9844 | auc: 0.9941
#       [global/center_2] época 10/20 — loss: 0.0018 acc: 1.0000 | val_loss: 0.0803 acc: 0.9844 | auc: 0.9955
#       [global/center_2] época 11/20 — loss: 0.0032 acc: 0.9987 | val_loss: 0.0479 acc: 0.9896 | auc: 0.9977
#       [global/center_2] época 12/20 — loss: 0.0018 acc: 1.0000 | val_loss: 0.0890 acc: 0.9844 | auc: 0.9968
#       [global/center_2] época 13/20 — loss: 0.0010 acc: 1.0000 | val_loss: 0.0865 acc: 0.9844 | auc: 0.9971
#       [global/center_2] época 14/20 — loss: 0.0008 acc: 1.0000 | val_loss: 0.0890 acc: 0.9844 | auc: 0.9972
#       [global/center_2] época 15/20 — loss: 0.0009 acc: 1.0000 | val_loss: 0.0752 acc: 0.9844 | auc: 0.9973
#       [global/center_2] época 16/20 — loss: 0.0006 acc: 1.0000 | val_loss: 0.0897 acc: 0.9844 | auc: 0.9969
#       [global/center_2] época 17/20 — loss: 0.0006 acc: 1.0000 | val_loss: 0.0887 acc: 0.9844 | auc: 0.9971
#       [global/center_2] época 18/20 — loss: 0.0017 acc: 1.0000 | val_loss: 0.0412 acc: 0.9896 | auc: 0.9992
#         → mejor época global: 18 | auc: 0.9992
#       [global/center_2] época 19/20 — loss: 0.0012 acc: 1.0000 | val_loss: 0.0747 acc: 0.9844 | auc: 0.9983
#       [global/center_2] época 20/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.0732 acc: 0.9844 | auc: 0.9980
#
#   Centro: center_3
#       [global/center_3] época 01/20 — loss: 0.1492 acc: 0.6838 | val_loss: 0.1478 acc: 0.7111 | auc: 0.7773
#         → mejor época global: 1 | auc: 0.7773
#       [global/center_3] época 02/20 — loss: 0.0497 acc: 0.9412 | val_loss: 0.4242 acc: 0.5111 | auc: 0.7826
#         → mejor época global: 2 | auc: 0.7826
#       [global/center_3] época 03/20 — loss: 0.0386 acc: 0.9596 | val_loss: 0.7831 acc: 0.4222 | auc: 0.8582
#         → mejor época global: 3 | auc: 0.8582
#       [global/center_3] época 04/20 — loss: 0.0314 acc: 0.9540 | val_loss: 0.1729 acc: 0.7407 | auc: 0.8757
#         → mejor época global: 4 | auc: 0.8757
#       [global/center_3] época 05/20 — loss: 0.0067 acc: 0.9926 | val_loss: 0.1735 acc: 0.7778 | auc: 0.8479
#       [global/center_3] época 06/20 — loss: 0.0080 acc: 0.9926 | val_loss: 0.1881 acc: 0.7852 | auc: 0.8561
#       [global/center_3] época 07/20 — loss: 0.0067 acc: 0.9926 | val_loss: 0.1629 acc: 0.7852 | auc: 0.8657
#       [global/center_3] época 08/20 — loss: 0.0052 acc: 0.9926 | val_loss: 0.2270 acc: 0.7778 | auc: 0.8726
#       [global/center_3] época 09/20 — loss: 0.0057 acc: 0.9908 | val_loss: 0.2056 acc: 0.7704 | auc: 0.8733
#       [global/center_3] época 10/20 — loss: 0.0261 acc: 0.9669 | val_loss: 0.2049 acc: 0.7926 | auc: 0.8453
#       [global/center_3] época 11/20 — loss: 0.0437 acc: 0.9449 | val_loss: 0.1648 acc: 0.7407 | auc: 0.8546
#       [global/center_3] época 12/20 — loss: 0.0182 acc: 0.9761 | val_loss: 0.1232 acc: 0.7926 | auc: 0.8942
#         → mejor época global: 12 | auc: 0.8942
#       [global/center_3] época 13/20 — loss: 0.0100 acc: 0.9890 | val_loss: 0.1726 acc: 0.7852 | auc: 0.8858
#       [global/center_3] época 14/20 — loss: 0.0057 acc: 0.9926 | val_loss: 0.1864 acc: 0.7852 | auc: 0.8934
#       [global/center_3] época 15/20 — loss: 0.0050 acc: 0.9963 | val_loss: 0.2238 acc: 0.7630 | auc: 0.8819
#       [global/center_3] época 16/20 — loss: 0.0049 acc: 0.9945 | val_loss: 0.2026 acc: 0.7926 | auc: 0.9045
#         → mejor época global: 16 | auc: 0.9045
#       [global/center_3] época 17/20 — loss: 0.0015 acc: 0.9982 | val_loss: 0.1663 acc: 0.8222 | auc: 0.9054
#         → mejor época global: 17 | auc: 0.9054
#       [global/center_3] época 18/20 — loss: 0.0011 acc: 1.0000 | val_loss: 0.1624 acc: 0.8370 | auc: 0.9076
#         → mejor época global: 18 | auc: 0.9076
#       [global/center_3] época 19/20 — loss: 0.0008 acc: 1.0000 | val_loss: 0.1769 acc: 0.8148 | auc: 0.9078
#         → mejor época global: 19 | auc: 0.9078
#       [global/center_3] época 20/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.1760 acc: 0.8296 | auc: 0.9078
#
#   Centro: center_4
#       [global/center_4] época 01/20 — loss: 0.4190 acc: 0.7637 | val_loss: 0.2979 acc: 0.8555 | auc: 0.9374
#         → mejor época global: 1 | auc: 0.9374
#       [global/center_4] época 02/20 — loss: 0.1802 acc: 0.9336 | val_loss: 0.2695 acc: 0.8984 | auc: 0.9580
#         → mejor época global: 2 | auc: 0.9580
#       [global/center_4] época 03/20 — loss: 0.1071 acc: 0.9561 | val_loss: 0.3542 acc: 0.8594 | auc: 0.9698
#         → mejor época global: 3 | auc: 0.9698
#       [global/center_4] época 04/20 — loss: 0.0476 acc: 0.9854 | val_loss: 0.2250 acc: 0.9102 | auc: 0.9693
#       [global/center_4] época 05/20 — loss: 0.0436 acc: 0.9844 | val_loss: 0.2681 acc: 0.9180 | auc: 0.9598
#       [global/center_4] época 06/20 — loss: 0.0190 acc: 0.9941 | val_loss: 0.2686 acc: 0.9258 | auc: 0.9652
#       [global/center_4] época 07/20 — loss: 0.0472 acc: 0.9795 | val_loss: 0.5866 acc: 0.8672 | auc: 0.9573
#       [global/center_4] época 08/20 — loss: 0.0500 acc: 0.9766 | val_loss: 0.2227 acc: 0.9336 | auc: 0.9724
#         → mejor época global: 8 | auc: 0.9724
#       [global/center_4] época 09/20 — loss: 0.0404 acc: 0.9854 | val_loss: 0.2489 acc: 0.9180 | auc: 0.9711
#       [global/center_4] época 10/20 — loss: 0.0314 acc: 0.9902 | val_loss: 0.2867 acc: 0.8945 | auc: 0.9689
#       [global/center_4] época 11/20 — loss: 0.0300 acc: 0.9902 | val_loss: 0.4324 acc: 0.8906 | auc: 0.9701
#       [global/center_4] época 12/20 — loss: 0.0505 acc: 0.9795 | val_loss: 0.2955 acc: 0.8945 | auc: 0.9665
#       [global/center_4] época 13/20 — loss: 0.0370 acc: 0.9912 | val_loss: 0.3668 acc: 0.9023 | auc: 0.9653
#       [global/center_4] época 14/20 — loss: 0.0397 acc: 0.9854 | val_loss: 0.2474 acc: 0.9180 | auc: 0.9699
#       [global/center_4] época 15/20 — loss: 0.0088 acc: 0.9980 | val_loss: 0.3529 acc: 0.8984 | auc: 0.9735
#         → mejor época global: 15 | auc: 0.9735
#       [global/center_4] época 16/20 — loss: 0.0033 acc: 1.0000 | val_loss: 0.3355 acc: 0.9102 | auc: 0.9792
#         → mejor época global: 16 | auc: 0.9792
#       [global/center_4] época 17/20 — loss: 0.0018 acc: 1.0000 | val_loss: 0.3110 acc: 0.9102 | auc: 0.9821
#         → mejor época global: 17 | auc: 0.9821
#       [global/center_4] época 18/20 — loss: 0.0012 acc: 1.0000 | val_loss: 0.3172 acc: 0.9102 | auc: 0.9816
#       [global/center_4] época 19/20 — loss: 0.0007 acc: 1.0000 | val_loss: 0.3011 acc: 0.9102 | auc: 0.9819
#       [global/center_4] época 20/20 — loss: 0.0009 acc: 1.0000 | val_loss: 0.3665 acc: 0.9102 | auc: 0.9819
#
#   - Mejor modelo global guardado (val_auc: 0.9855)
#
#   ── Personalización Ditto ──
#
#   Centro: center_1
#       [ditto/center_1] época 01/15 — loss: 0.1698 acc: 0.9293 | val_loss: 0.0578 acc: 0.9819 | auc: 0.9980
#         → mejor época local: 1 | auc: 0.9980
#       [ditto/center_1] época 02/15 — loss: 0.0251 acc: 0.9938 | val_loss: 0.0471 acc: 0.9852 | auc: 0.9989
#         → mejor época local: 2 | auc: 0.9989
#       [ditto/center_1] época 03/15 — loss: 0.0147 acc: 0.9967 | val_loss: 0.0393 acc: 0.9803 | auc: 0.9990
#         → mejor época local: 3 | auc: 0.9990
#       [ditto/center_1] época 04/15 — loss: 0.0214 acc: 0.9914 | val_loss: 0.0663 acc: 0.9786 | auc: 0.9987
#       [ditto/center_1] época 05/15 — loss: 0.0202 acc: 0.9942 | val_loss: 0.0514 acc: 0.9868 | auc: 0.9984
#       [ditto/center_1] época 06/15 — loss: 0.0325 acc: 0.9885 | val_loss: 0.0509 acc: 0.9836 | auc: 0.9976
#       [ditto/center_1] época 07/15 — loss: 0.0063 acc: 0.9996 | val_loss: 0.0534 acc: 0.9852 | auc: 0.9995
#         → mejor época local: 7 | auc: 0.9995
#       [ditto/center_1] época 08/15 — loss: 0.0041 acc: 0.9988 | val_loss: 0.0257 acc: 0.9934 | auc: 0.9997
#         → mejor época local: 8 | auc: 0.9997
#       [ditto/center_1] época 09/15 — loss: 0.0082 acc: 0.9988 | val_loss: 0.0396 acc: 0.9868 | auc: 0.9992
#       [ditto/center_1] época 10/15 — loss: 0.0076 acc: 0.9975 | val_loss: 0.0405 acc: 0.9885 | auc: 0.9994
#       [ditto/center_1] época 11/15 — loss: 0.0048 acc: 0.9996 | val_loss: 0.0336 acc: 0.9901 | auc: 0.9992
#       [ditto/center_1] época 12/15 — loss: 0.0116 acc: 0.9971 | val_loss: 0.1129 acc: 0.9688 | auc: 0.9979
#       [ditto/center_1] época 13/15 — loss: 0.0281 acc: 0.9910 | val_loss: 0.0610 acc: 0.9819 | auc: 0.9990
#       [ditto/center_1] época 14/15 — loss: 0.0273 acc: 0.9905 | val_loss: 0.1194 acc: 0.9671 | auc: 0.9986
#       [ditto/center_1] época 15/15 — loss: 0.0110 acc: 0.9963 | val_loss: 0.0223 acc: 0.9901 | auc: 0.9998
#         → mejor época local: 15 | auc: 0.9998
#     - Mejor modelo local guardado | auc: 0.9998
#
#   Centro: center_2
#       [ditto/center_2] época 01/15 — loss: 0.2936 acc: 0.8750 | val_loss: 0.1255 acc: 0.9740 | auc: 0.9866
#         → mejor época local: 1 | auc: 0.9866
#       [ditto/center_2] época 02/15 — loss: 0.0900 acc: 0.9805 | val_loss: 0.0974 acc: 0.9740 | auc: 0.9938
#         → mejor época local: 2 | auc: 0.9938
#       [ditto/center_2] época 03/15 — loss: 0.0247 acc: 0.9974 | val_loss: 0.0818 acc: 0.9792 | auc: 0.9985
#         → mejor época local: 3 | auc: 0.9985
#       [ditto/center_2] época 04/15 — loss: 0.0138 acc: 0.9974 | val_loss: 0.0512 acc: 0.9792 | auc: 0.9985
#       [ditto/center_2] época 05/15 — loss: 0.0475 acc: 0.9857 | val_loss: 0.1236 acc: 0.9740 | auc: 0.9892
#       [ditto/center_2] época 06/15 — loss: 0.0428 acc: 0.9870 | val_loss: 0.0740 acc: 0.9740 | auc: 0.9927
#       [ditto/center_2] época 07/15 — loss: 0.0282 acc: 0.9909 | val_loss: 0.0783 acc: 0.9844 | auc: 0.9933
#       [ditto/center_2] época 08/15 — loss: 0.0605 acc: 0.9792 | val_loss: 0.1425 acc: 0.9427 | auc: 0.9893
#       [ditto/center_2] época 09/15 — loss: 0.0371 acc: 0.9870 | val_loss: 0.4669 acc: 0.9062 | auc: 0.9866
#       [ditto/center_2] época 10/15 — loss: 0.0273 acc: 0.9935 | val_loss: 0.0583 acc: 0.9896 | auc: 0.9968
#       [ditto/center_2] época 11/15 — loss: 0.0108 acc: 0.9987 | val_loss: 0.0783 acc: 0.9792 | auc: 0.9928
#       [ditto/center_2] época 12/15 — loss: 0.0065 acc: 1.0000 | val_loss: 0.0746 acc: 0.9792 | auc: 0.9943
#       [ditto/center_2] época 13/15 — loss: 0.0058 acc: 0.9987 | val_loss: 0.0806 acc: 0.9792 | auc: 0.9959
#       [ditto/center_2] época 14/15 — loss: 0.0042 acc: 1.0000 | val_loss: 0.0769 acc: 0.9740 | auc: 0.9959
#       [ditto/center_2] época 15/15 — loss: 0.0051 acc: 1.0000 | val_loss: 0.0655 acc: 0.9844 | auc: 0.9944
#     - Mejor modelo local guardado | auc: 0.9985
#
#   Centro: center_3
#       [ditto/center_3] época 01/15 — loss: 0.1513 acc: 0.7077 | val_loss: 0.2991 acc: 0.5481 | auc: 0.8178
#         → mejor época local: 1 | auc: 0.8178
#       [ditto/center_3] época 02/15 — loss: 0.0549 acc: 0.9099 | val_loss: 0.2677 acc: 0.6815 | auc: 0.8345
#         → mejor época local: 2 | auc: 0.8345
#       [ditto/center_3] época 03/15 — loss: 0.0562 acc: 0.9118 | val_loss: 0.4034 acc: 0.6444 | auc: 0.8436
#         → mejor época local: 3 | auc: 0.8436
#       [ditto/center_3] época 04/15 — loss: 0.0304 acc: 0.9577 | val_loss: 0.2421 acc: 0.7778 | auc: 0.8360
#       [ditto/center_3] época 05/15 — loss: 0.0451 acc: 0.9596 | val_loss: 0.5398 acc: 0.6667 | auc: 0.8240
#       [ditto/center_3] época 06/15 — loss: 0.0231 acc: 0.9651 | val_loss: 0.2933 acc: 0.7556 | auc: 0.7945
#       [ditto/center_3] época 07/15 — loss: 0.0375 acc: 0.9504 | val_loss: 0.3084 acc: 0.7407 | auc: 0.8137
#       [ditto/center_3] época 08/15 — loss: 0.0510 acc: 0.9265 | val_loss: 0.2097 acc: 0.7556 | auc: 0.8329
#       [ditto/center_3] época 09/15 — loss: 0.0450 acc: 0.9449 | val_loss: 0.4851 acc: 0.6741 | auc: 0.8422
#       [ditto/center_3] época 10/15 — loss: 0.0315 acc: 0.9522 | val_loss: 0.2253 acc: 0.8000 | auc: 0.8609
#         → mejor época local: 10 | auc: 0.8609
#       [ditto/center_3] época 11/15 — loss: 0.0342 acc: 0.9669 | val_loss: 0.1908 acc: 0.7778 | auc: 0.8666
#         → mejor época local: 11 | auc: 0.8666
#       [ditto/center_3] época 12/15 — loss: 0.0494 acc: 0.9210 | val_loss: 0.4115 acc: 0.7185 | auc: 0.8707
#         → mejor época local: 12 | auc: 0.8707
#       [ditto/center_3] época 13/15 — loss: 0.0266 acc: 0.9706 | val_loss: 0.4351 acc: 0.6889 | auc: 0.8625
#       [ditto/center_3] época 14/15 — loss: 0.0107 acc: 0.9908 | val_loss: 0.6840 acc: 0.6741 | auc: 0.8429
#       [ditto/center_3] época 15/15 — loss: 0.0102 acc: 0.9853 | val_loss: 0.4934 acc: 0.7037 | auc: 0.8321
#     - Mejor modelo local guardado | auc: 0.8707
#
#   Centro: center_4
#       [ditto/center_4] época 01/15 — loss: 0.3386 acc: 0.8350 | val_loss: 0.3129 acc: 0.8945 | auc: 0.9265
#         → mejor época local: 1 | auc: 0.9265
#       [ditto/center_4] época 02/15 — loss: 0.1440 acc: 0.9463 | val_loss: 0.3038 acc: 0.8828 | auc: 0.9290
#         → mejor época local: 2 | auc: 0.9290
#       [ditto/center_4] época 03/15 — loss: 0.1200 acc: 0.9551 | val_loss: 0.2883 acc: 0.8906 | auc: 0.9340
#         → mejor época local: 3 | auc: 0.9340
#       [ditto/center_4] época 04/15 — loss: 0.0993 acc: 0.9668 | val_loss: 0.3114 acc: 0.8594 | auc: 0.9309
#       [ditto/center_4] época 05/15 — loss: 0.0914 acc: 0.9678 | val_loss: 0.5059 acc: 0.8516 | auc: 0.9302
#       [ditto/center_4] época 06/15 — loss: 0.0844 acc: 0.9609 | val_loss: 0.3965 acc: 0.8398 | auc: 0.9463
#         → mejor época local: 6 | auc: 0.9463
#       [ditto/center_4] época 07/15 — loss: 0.0764 acc: 0.9717 | val_loss: 0.2818 acc: 0.8945 | auc: 0.9410
#       [ditto/center_4] época 08/15 — loss: 0.0814 acc: 0.9727 | val_loss: 0.5440 acc: 0.8359 | auc: 0.9287
#       [ditto/center_4] época 09/15 — loss: 0.0734 acc: 0.9697 | val_loss: 0.3372 acc: 0.8750 | auc: 0.9343
#       [ditto/center_4] época 10/15 — loss: 0.0812 acc: 0.9639 | val_loss: 0.3008 acc: 0.8828 | auc: 0.9412
#       [ditto/center_4] época 11/15 — loss: 0.0627 acc: 0.9766 | val_loss: 0.3179 acc: 0.8945 | auc: 0.9410
#       [ditto/center_4] época 12/15 — loss: 0.1076 acc: 0.9521 | val_loss: 0.4142 acc: 0.8711 | auc: 0.9260
#       [ditto/center_4] época 13/15 — loss: 0.0913 acc: 0.9570 | val_loss: 0.2505 acc: 0.9023 | auc: 0.9494
#         → mejor época local: 13 | auc: 0.9494
#       [ditto/center_4] época 14/15 — loss: 0.0843 acc: 0.9648 | val_loss: 0.5478 acc: 0.8320 | auc: 0.9433
#       [ditto/center_4] época 15/15 — loss: 0.0552 acc: 0.9824 | val_loss: 0.3428 acc: 0.8672 | auc: 0.9341
#     - Mejor modelo local guardado | auc: 0.9494
#
#   ───────────────────────────────────────────────────────
#   Ronda 1 — val_auc global: 0.9855
#   Val AUC locales:
#     center_1 → 0.9998
#     center_2 → 0.9985
#     center_3 → 0.8707
#     center_4 → 0.9494
#
# ============================================================
#   RONDA 2/30
# ============================================================
#
#   ── Entrenamiento global ──
#
#   Centro: center_1
#       [global/center_1] época 01/20 — loss: 0.0297 acc: 0.9868 | val_loss: 0.0478 acc: 0.9852 | auc: 0.9984
#         → mejor época global: 1 | auc: 0.9984
#       [global/center_1] época 02/20 — loss: 0.0217 acc: 0.9938 | val_loss: 0.0877 acc: 0.9671 | auc: 0.9968
#       [global/center_1] época 03/20 — loss: 0.0208 acc: 0.9926 | val_loss: 0.0492 acc: 0.9868 | auc: 0.9988
#         → mejor época global: 3 | auc: 0.9988
#       [global/center_1] época 04/20 — loss: 0.0085 acc: 0.9979 | val_loss: 0.0239 acc: 0.9918 | auc: 0.9998
#         → mejor época global: 4 | auc: 0.9998
#       [global/center_1] época 05/20 — loss: 0.0092 acc: 0.9971 | val_loss: 0.0462 acc: 0.9852 | auc: 0.9994
#       [global/center_1] época 06/20 — loss: 0.0026 acc: 0.9996 | val_loss: 0.0296 acc: 0.9918 | auc: 0.9996
#       [global/center_1] época 07/20 — loss: 0.0099 acc: 0.9967 | val_loss: 0.0638 acc: 0.9836 | auc: 0.9977
#       [global/center_1] época 08/20 — loss: 0.0309 acc: 0.9868 | val_loss: 0.0334 acc: 0.9836 | auc: 0.9995
#       [global/center_1] época 09/20 — loss: 0.0031 acc: 1.0000 | val_loss: 0.0268 acc: 0.9868 | auc: 0.9998
#         → mejor época global: 9 | auc: 0.9998
#       [global/center_1] época 10/20 — loss: 0.0009 acc: 1.0000 | val_loss: 0.0227 acc: 0.9885 | auc: 0.9998
#         → mejor época global: 10 | auc: 0.9998
#       [global/center_1] época 11/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.0308 acc: 0.9885 | auc: 0.9998
#       [global/center_1] época 12/20 — loss: 0.0048 acc: 0.9992 | val_loss: 0.1155 acc: 0.9655 | auc: 0.9988
#       [global/center_1] época 13/20 — loss: 0.0176 acc: 0.9934 | val_loss: 0.1472 acc: 0.9720 | auc: 0.9916
#       [global/center_1] época 14/20 — loss: 0.0146 acc: 0.9955 | val_loss: 0.0239 acc: 0.9901 | auc: 0.9997
#       [global/center_1] época 15/20 — loss: 0.0187 acc: 0.9951 | val_loss: 0.0282 acc: 0.9901 | auc: 1.0000
#         → mejor época global: 15 | auc: 1.0000
#       [global/center_1] época 16/20 — loss: 0.0038 acc: 0.9992 | val_loss: 0.0251 acc: 0.9951 | auc: 0.9996
#       [global/center_1] época 17/20 — loss: 0.0038 acc: 0.9992 | val_loss: 0.0277 acc: 0.9934 | auc: 0.9999
#       [global/center_1] época 18/20 — loss: 0.0005 acc: 1.0000 | val_loss: 0.0149 acc: 0.9967 | auc: 0.9999
#       [global/center_1] época 19/20 — loss: 0.0057 acc: 0.9971 | val_loss: 0.0194 acc: 0.9951 | auc: 1.0000
#       [global/center_1] época 20/20 — loss: 0.0067 acc: 0.9984 | val_loss: 0.0197 acc: 0.9901 | auc: 0.9999
#
#   Centro: center_2
#       [global/center_2] época 01/20 — loss: 0.2019 acc: 0.9206 | val_loss: 0.0523 acc: 0.9844 | auc: 0.9991
#         → mejor época global: 1 | auc: 0.9991
#       [global/center_2] época 02/20 — loss: 0.0241 acc: 0.9935 | val_loss: 0.0586 acc: 0.9896 | auc: 0.9984
#       [global/center_2] época 03/20 — loss: 0.0093 acc: 0.9987 | val_loss: 0.0402 acc: 0.9896 | auc: 0.9991
#       [global/center_2] época 04/20 — loss: 0.0048 acc: 1.0000 | val_loss: 0.0608 acc: 0.9844 | auc: 0.9983
#       [global/center_2] época 05/20 — loss: 0.0028 acc: 1.0000 | val_loss: 0.0487 acc: 0.9896 | auc: 0.9989
#       [global/center_2] época 06/20 — loss: 0.0014 acc: 1.0000 | val_loss: 0.0488 acc: 0.9896 | auc: 0.9986
#       [global/center_2] época 07/20 — loss: 0.0008 acc: 1.0000 | val_loss: 0.0515 acc: 0.9896 | auc: 0.9985
#       [global/center_2] época 08/20 — loss: 0.0019 acc: 1.0000 | val_loss: 0.0610 acc: 0.9896 | auc: 0.9983
#       [global/center_2] época 09/20 — loss: 0.0010 acc: 1.0000 | val_loss: 0.0652 acc: 0.9896 | auc: 0.9980
#       [global/center_2] época 10/20 — loss: 0.0008 acc: 1.0000 | val_loss: 0.0752 acc: 0.9896 | auc: 0.9980
#       [global/center_2] época 11/20 — loss: 0.0019 acc: 1.0000 | val_loss: 0.0815 acc: 0.9792 | auc: 0.9991
#         → mejor época global: 11 | auc: 0.9991
#       [global/center_2] época 12/20 — loss: 0.0028 acc: 0.9987 | val_loss: 0.0416 acc: 0.9896 | auc: 0.9998
#         → mejor época global: 12 | auc: 0.9998
#       [global/center_2] época 13/20 — loss: 0.1288 acc: 0.9596 | val_loss: 0.1691 acc: 0.9531 | auc: 0.9962
#       [global/center_2] época 14/20 — loss: 0.0873 acc: 0.9753 | val_loss: 0.0647 acc: 0.9740 | auc: 0.9991
#       [global/center_2] época 15/20 — loss: 0.0169 acc: 0.9974 | val_loss: 0.0400 acc: 0.9896 | auc: 0.9995
#       [global/center_2] época 16/20 — loss: 0.0028 acc: 1.0000 | val_loss: 0.0466 acc: 0.9844 | auc: 0.9993
#       [global/center_2] época 17/20 — loss: 0.0024 acc: 1.0000 | val_loss: 0.0392 acc: 0.9896 | auc: 1.0000
#         → mejor época global: 17 | auc: 1.0000
#       [global/center_2] época 18/20 — loss: 0.0008 acc: 1.0000 | val_loss: 0.0365 acc: 0.9896 | auc: 0.9999
#       [global/center_2] época 19/20 — loss: 0.0010 acc: 1.0000 | val_loss: 0.0451 acc: 0.9896 | auc: 0.9998
#       [global/center_2] época 20/20 — loss: 0.0009 acc: 1.0000 | val_loss: 0.0427 acc: 0.9896 | auc: 0.9998
#
#   Centro: center_3
#       [global/center_3] época 01/20 — loss: 0.2199 acc: 0.7904 | val_loss: 0.1929 acc: 0.6889 | auc: 0.8664
#         → mejor época global: 1 | auc: 0.8664
#       [global/center_3] época 02/20 — loss: 0.0469 acc: 0.9393 | val_loss: 0.1114 acc: 0.7704 | auc: 0.8657
#       [global/center_3] época 03/20 — loss: 0.0138 acc: 0.9908 | val_loss: 0.2005 acc: 0.7852 | auc: 0.8681
#         → mejor época global: 3 | auc: 0.8681
#       [global/center_3] época 04/20 — loss: 0.0031 acc: 1.0000 | val_loss: 0.1686 acc: 0.7852 | auc: 0.8764
#         → mejor época global: 4 | auc: 0.8764
#       [global/center_3] época 05/20 — loss: 0.0026 acc: 0.9982 | val_loss: 0.2487 acc: 0.8074 | auc: 0.8702
#       [global/center_3] época 06/20 — loss: 0.0017 acc: 0.9982 | val_loss: 0.2015 acc: 0.7704 | auc: 0.8805
#         → mejor época global: 6 | auc: 0.8805
#       [global/center_3] época 07/20 — loss: 0.0018 acc: 0.9982 | val_loss: 0.2209 acc: 0.7852 | auc: 0.8757
#       [global/center_3] época 08/20 — loss: 0.0005 acc: 1.0000 | val_loss: 0.2374 acc: 0.7704 | auc: 0.8798
#       [global/center_3] época 09/20 — loss: 0.0029 acc: 0.9963 | val_loss: 0.3391 acc: 0.7630 | auc: 0.8831
#         → mejor época global: 9 | auc: 0.8831
#       [global/center_3] época 10/20 — loss: 0.0060 acc: 0.9908 | val_loss: 0.1920 acc: 0.7630 | auc: 0.8863
#         → mejor época global: 10 | auc: 0.8863
#       [global/center_3] época 11/20 — loss: 0.0223 acc: 0.9724 | val_loss: 0.2405 acc: 0.7704 | auc: 0.8585
#       [global/center_3] época 12/20 — loss: 0.0504 acc: 0.9320 | val_loss: 0.2756 acc: 0.7926 | auc: 0.8714
#       [global/center_3] época 13/20 — loss: 0.0310 acc: 0.9596 | val_loss: 0.1415 acc: 0.7852 | auc: 0.8757
#       [global/center_3] época 14/20 — loss: 0.0104 acc: 0.9890 | val_loss: 0.1715 acc: 0.8000 | auc: 0.8798
#       [global/center_3] época 15/20 — loss: 0.0051 acc: 0.9945 | val_loss: 0.2391 acc: 0.8296 | auc: 0.8865
#         → mejor época global: 15 | auc: 0.8865
#       [global/center_3] época 16/20 — loss: 0.0011 acc: 1.0000 | val_loss: 0.1820 acc: 0.8074 | auc: 0.8894
#         → mejor época global: 16 | auc: 0.8894
#       [global/center_3] época 17/20 — loss: 0.0017 acc: 0.9982 | val_loss: 0.3566 acc: 0.8000 | auc: 0.8740
#       [global/center_3] época 18/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.2370 acc: 0.8000 | auc: 0.8788
#       [global/center_3] época 19/20 — loss: 0.0009 acc: 1.0000 | val_loss: 0.2386 acc: 0.8074 | auc: 0.8800
#       [global/center_3] época 20/20 — loss: 0.0009 acc: 0.9982 | val_loss: 0.2375 acc: 0.7852 | auc: 0.8760
#
#   Centro: center_4
#       [global/center_4] época 01/20 — loss: 0.2437 acc: 0.8906 | val_loss: 0.3272 acc: 0.8711 | auc: 0.9631
#         → mejor época global: 1 | auc: 0.9631
#       [global/center_4] época 02/20 — loss: 0.0427 acc: 0.9873 | val_loss: 0.4017 acc: 0.8828 | auc: 0.9549
#       [global/center_4] época 03/20 — loss: 0.0387 acc: 0.9883 | val_loss: 0.3993 acc: 0.8906 | auc: 0.9642
#         → mejor época global: 3 | auc: 0.9642
#       [global/center_4] época 04/20 — loss: 0.0446 acc: 0.9854 | val_loss: 0.5872 acc: 0.8438 | auc: 0.9487
#       [global/center_4] época 05/20 — loss: 0.0612 acc: 0.9707 | val_loss: 0.2236 acc: 0.9102 | auc: 0.9700
#         → mejor época global: 5 | auc: 0.9700
#       [global/center_4] época 06/20 — loss: 0.0306 acc: 0.9893 | val_loss: 0.2526 acc: 0.9180 | auc: 0.9804
#         → mejor época global: 6 | auc: 0.9804
#       [global/center_4] época 07/20 — loss: 0.0248 acc: 0.9902 | val_loss: 0.3366 acc: 0.8945 | auc: 0.9590
#       [global/center_4] época 08/20 — loss: 0.0598 acc: 0.9795 | val_loss: 0.2576 acc: 0.9102 | auc: 0.9646
#       [global/center_4] época 09/20 — loss: 0.0160 acc: 0.9951 | val_loss: 0.2808 acc: 0.9062 | auc: 0.9679
#       [global/center_4] época 10/20 — loss: 0.0041 acc: 1.0000 | val_loss: 0.3038 acc: 0.9102 | auc: 0.9697
#       [global/center_4] época 11/20 — loss: 0.0050 acc: 0.9990 | val_loss: 0.2842 acc: 0.9023 | auc: 0.9690
#       [global/center_4] época 12/20 — loss: 0.0051 acc: 0.9980 | val_loss: 0.3938 acc: 0.8945 | auc: 0.9653
#       [global/center_4] época 13/20 — loss: 0.0093 acc: 0.9951 | val_loss: 0.3696 acc: 0.8906 | auc: 0.9577
#       [global/center_4] época 14/20 — loss: 0.0378 acc: 0.9873 | val_loss: 0.2772 acc: 0.9062 | auc: 0.9673
#       [global/center_4] época 15/20 — loss: 0.0088 acc: 0.9980 | val_loss: 0.3493 acc: 0.9102 | auc: 0.9689
#       [global/center_4] época 16/20 — loss: 0.0220 acc: 0.9951 | val_loss: 0.3725 acc: 0.9180 | auc: 0.9668
#       [global/center_4] época 17/20 — loss: 0.0260 acc: 0.9912 | val_loss: 0.2897 acc: 0.9180 | auc: 0.9711
#       [global/center_4] época 18/20 — loss: 0.0119 acc: 0.9951 | val_loss: 0.2381 acc: 0.9258 | auc: 0.9746
#       [global/center_4] época 19/20 — loss: 0.0060 acc: 0.9980 | val_loss: 0.2922 acc: 0.9258 | auc: 0.9754
#       [global/center_4] época 20/20 — loss: 0.0059 acc: 0.9980 | val_loss: 0.2982 acc: 0.9336 | auc: 0.9710
#   Sin mejora global 1/10
#
#   ───────────────────────────────────────────────────────
#   Ronda 2 — val_auc global: 0.9831
#   Val AUC locales:
#     center_1 → 0.9998
#     center_2 → 0.9985
#     center_3 → 0.8707
#     center_4 → 0.9494
#
# ============================================================
#   RONDA 3/30
# ============================================================
#
#   ── Entrenamiento global ──
#
#   Centro: center_1
#       [global/center_1] época 01/20 — loss: 0.0026 acc: 0.9992 | val_loss: 0.1025 acc: 0.9819 | auc: 0.9994
#         → mejor época global: 1 | auc: 0.9994
#       [global/center_1] época 02/20 — loss: 0.0170 acc: 0.9942 | val_loss: 0.0191 acc: 0.9918 | auc: 0.9999
#         → mejor época global: 2 | auc: 0.9999
#       [global/center_1] época 03/20 — loss: 0.0101 acc: 0.9971 | val_loss: 0.0981 acc: 0.9836 | auc: 0.9985
#       [global/center_1] época 04/20 — loss: 0.0102 acc: 0.9959 | val_loss: 0.0090 acc: 0.9951 | auc: 1.0000
#         → mejor época global: 4 | auc: 1.0000
#       [global/center_1] época 05/20 — loss: 0.0027 acc: 0.9996 | val_loss: 0.0300 acc: 0.9852 | auc: 0.9997
#       [global/center_1] época 06/20 — loss: 0.0034 acc: 0.9988 | val_loss: 0.0251 acc: 0.9885 | auc: 0.9998
#       [global/center_1] época 07/20 — loss: 0.0026 acc: 0.9996 | val_loss: 0.0244 acc: 0.9901 | auc: 0.9998
#       [global/center_1] época 08/20 — loss: 0.0016 acc: 0.9996 | val_loss: 0.1411 acc: 0.9671 | auc: 0.9995
#       [global/center_1] época 09/20 — loss: 0.0118 acc: 0.9963 | val_loss: 0.0782 acc: 0.9704 | auc: 0.9998
#       [global/center_1] época 10/20 — loss: 0.0111 acc: 0.9967 | val_loss: 0.0159 acc: 0.9967 | auc: 0.9998
#       [global/center_1] época 11/20 — loss: 0.0106 acc: 0.9959 | val_loss: 0.0761 acc: 0.9737 | auc: 0.9998
#       [global/center_1] época 12/20 — loss: 0.0062 acc: 0.9979 | val_loss: 0.0199 acc: 0.9918 | auc: 1.0000
#       [global/center_1] época 13/20 — loss: 0.0009 acc: 0.9996 | val_loss: 0.0256 acc: 0.9901 | auc: 1.0000
#       [global/center_1] época 14/20 — loss: 0.0019 acc: 0.9988 | val_loss: 0.0095 acc: 0.9951 | auc: 1.0000
#       [global/center_1] época 15/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0150 acc: 0.9951 | auc: 1.0000
#         → mejor época global: 15 | auc: 1.0000
#       [global/center_1] época 16/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0044 acc: 0.9984 | auc: 1.0000
#       [global/center_1] época 17/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0035 acc: 0.9984 | auc: 1.0000
#       [global/center_1] época 18/20 — loss: 0.0193 acc: 0.9934 | val_loss: 0.0735 acc: 0.9836 | auc: 0.9998
#       [global/center_1] época 19/20 — loss: 0.0083 acc: 0.9971 | val_loss: 0.0246 acc: 0.9885 | auc: 0.9999
#       [global/center_1] época 20/20 — loss: 0.0013 acc: 0.9996 | val_loss: 0.0082 acc: 0.9967 | auc: 1.0000
#
#   Centro: center_2
#       [global/center_2] época 01/20 — loss: 0.2234 acc: 0.9258 | val_loss: 0.0747 acc: 0.9688 | auc: 0.9984
#         → mejor época global: 1 | auc: 0.9984
#       [global/center_2] época 02/20 — loss: 0.0212 acc: 0.9948 | val_loss: 0.0357 acc: 0.9948 | auc: 0.9989
#         → mejor época global: 2 | auc: 0.9989
#       [global/center_2] época 03/20 — loss: 0.0074 acc: 0.9961 | val_loss: 0.0308 acc: 0.9948 | auc: 0.9991
#         → mejor época global: 3 | auc: 0.9991
#       [global/center_2] época 04/20 — loss: 0.0034 acc: 1.0000 | val_loss: 0.0375 acc: 0.9792 | auc: 0.9993
#         → mejor época global: 4 | auc: 0.9993
#       [global/center_2] época 05/20 — loss: 0.0015 acc: 1.0000 | val_loss: 0.0349 acc: 0.9948 | auc: 0.9991
#       [global/center_2] época 06/20 — loss: 0.0024 acc: 1.0000 | val_loss: 0.0213 acc: 0.9896 | auc: 0.9999
#         → mejor época global: 6 | auc: 0.9999
#       [global/center_2] época 07/20 — loss: 0.0286 acc: 0.9883 | val_loss: 0.2466 acc: 0.9375 | auc: 0.9960
#       [global/center_2] época 08/20 — loss: 0.0208 acc: 0.9922 | val_loss: 0.0861 acc: 0.9792 | auc: 0.9969
#       [global/center_2] época 09/20 — loss: 0.0344 acc: 0.9883 | val_loss: 0.1096 acc: 0.9688 | auc: 0.9959
#       [global/center_2] época 10/20 — loss: 0.0070 acc: 0.9987 | val_loss: 0.0618 acc: 0.9792 | auc: 0.9996
#       [global/center_2] época 11/20 — loss: 0.0014 acc: 1.0000 | val_loss: 0.0545 acc: 0.9844 | auc: 0.9992
#       [global/center_2] época 12/20 — loss: 0.0009 acc: 1.0000 | val_loss: 0.0549 acc: 0.9844 | auc: 0.9991
#       [global/center_2] época 13/20 — loss: 0.0006 acc: 1.0000 | val_loss: 0.0725 acc: 0.9844 | auc: 0.9991
#       [global/center_2] época 14/20 — loss: 0.0005 acc: 1.0000 | val_loss: 0.0710 acc: 0.9844 | auc: 0.9991
#       [global/center_2] época 15/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.0639 acc: 0.9844 | auc: 0.9991
#       [global/center_2] época 16/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.0585 acc: 0.9844 | auc: 0.9991
#       [global/center_2] época 17/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.0568 acc: 0.9896 | auc: 0.9992
#       [global/center_2] época 18/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.0493 acc: 0.9896 | auc: 0.9992
#       [global/center_2] época 19/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.0550 acc: 0.9896 | auc: 0.9995
#       [global/center_2] época 20/20 — loss: 0.0005 acc: 1.0000 | val_loss: 0.0536 acc: 0.9896 | auc: 0.9995
#
#   Centro: center_3
#       [global/center_3] época 01/20 — loss: 0.3957 acc: 0.8162 | val_loss: 0.1415 acc: 0.7407 | auc: 0.8906
#         → mejor época global: 1 | auc: 0.8906
#       [global/center_3] época 02/20 — loss: 0.0615 acc: 0.8934 | val_loss: 0.1519 acc: 0.7704 | auc: 0.9054
#         → mejor época global: 2 | auc: 0.9054
#       [global/center_3] época 03/20 — loss: 0.0374 acc: 0.9485 | val_loss: 0.1137 acc: 0.8148 | auc: 0.9157
#         → mejor época global: 3 | auc: 0.9157
#       [global/center_3] época 04/20 — loss: 0.0127 acc: 0.9945 | val_loss: 0.1702 acc: 0.8148 | auc: 0.9205
#         → mejor época global: 4 | auc: 0.9205
#       [global/center_3] época 05/20 — loss: 0.0199 acc: 0.9743 | val_loss: 0.1528 acc: 0.8222 | auc: 0.9181
#       [global/center_3] época 06/20 — loss: 0.0023 acc: 0.9982 | val_loss: 0.1438 acc: 0.8296 | auc: 0.9239
#         → mejor época global: 6 | auc: 0.9239
#       [global/center_3] época 07/20 — loss: 0.0018 acc: 0.9982 | val_loss: 0.1514 acc: 0.8222 | auc: 0.9210
#       [global/center_3] época 08/20 — loss: 0.0006 acc: 1.0000 | val_loss: 0.1740 acc: 0.8074 | auc: 0.9179
#       [global/center_3] época 09/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.1869 acc: 0.8148 | auc: 0.9167
#       [global/center_3] época 10/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.1848 acc: 0.8000 | auc: 0.9188
#       [global/center_3] época 11/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.1801 acc: 0.8074 | auc: 0.9193
#       [global/center_3] época 12/20 — loss: 0.0023 acc: 0.9982 | val_loss: 0.2721 acc: 0.8000 | auc: 0.9167
#       [global/center_3] época 13/20 — loss: 0.0040 acc: 0.9963 | val_loss: 0.1893 acc: 0.8148 | auc: 0.9164
#       [global/center_3] época 14/20 — loss: 0.0249 acc: 0.9688 | val_loss: 0.1571 acc: 0.7778 | auc: 0.9033
#       [global/center_3] época 15/20 — loss: 0.0085 acc: 0.9871 | val_loss: 0.1516 acc: 0.8370 | auc: 0.9227
#       [global/center_3] época 16/20 — loss: 0.0050 acc: 0.9945 | val_loss: 0.1374 acc: 0.8444 | auc: 0.9227
#       [global/center_3] época 17/20 — loss: 0.0079 acc: 0.9890 | val_loss: 0.1412 acc: 0.8222 | auc: 0.9148
#       [global/center_3] época 18/20 — loss: 0.0066 acc: 0.9926 | val_loss: 0.2282 acc: 0.8000 | auc: 0.9325
#         → mejor época global: 18 | auc: 0.9325
#       [global/center_3] época 19/20 — loss: 0.0085 acc: 0.9890 | val_loss: 0.1887 acc: 0.8074 | auc: 0.9107
#       [global/center_3] época 20/20 — loss: 0.0026 acc: 0.9945 | val_loss: 0.2310 acc: 0.8000 | auc: 0.9258
#
#   Centro: center_4
#       [global/center_4] época 01/20 — loss: 0.2899 acc: 0.9004 | val_loss: 0.2606 acc: 0.8867 | auc: 0.9470
#         → mejor época global: 1 | auc: 0.9470
#       [global/center_4] época 02/20 — loss: 0.0611 acc: 0.9785 | val_loss: 0.4962 acc: 0.8750 | auc: 0.9550
#         → mejor época global: 2 | auc: 0.9550
#       [global/center_4] época 03/20 — loss: 0.0340 acc: 0.9854 | val_loss: 0.2869 acc: 0.8984 | auc: 0.9546
#       [global/center_4] época 04/20 — loss: 0.0521 acc: 0.9805 | val_loss: 0.4606 acc: 0.8828 | auc: 0.9449
#       [global/center_4] época 05/20 — loss: 0.0484 acc: 0.9834 | val_loss: 0.2647 acc: 0.8984 | auc: 0.9647
#         → mejor época global: 5 | auc: 0.9647
#       [global/center_4] época 06/20 — loss: 0.0124 acc: 0.9961 | val_loss: 0.3246 acc: 0.9023 | auc: 0.9660
#         → mejor época global: 6 | auc: 0.9660
#       [global/center_4] época 07/20 — loss: 0.0048 acc: 0.9990 | val_loss: 0.3324 acc: 0.8984 | auc: 0.9619
#       [global/center_4] época 08/20 — loss: 0.0038 acc: 0.9990 | val_loss: 0.3276 acc: 0.9062 | auc: 0.9692
#         → mejor época global: 8 | auc: 0.9692
#       [global/center_4] época 09/20 — loss: 0.0017 acc: 1.0000 | val_loss: 0.3279 acc: 0.9102 | auc: 0.9747
#         → mejor época global: 9 | auc: 0.9747
#       [global/center_4] época 10/20 — loss: 0.0008 acc: 1.0000 | val_loss: 0.3552 acc: 0.8906 | auc: 0.9726
#       [global/center_4] época 11/20 — loss: 0.0007 acc: 1.0000 | val_loss: 0.3259 acc: 0.9102 | auc: 0.9734
#       [global/center_4] época 12/20 — loss: 0.0649 acc: 0.9805 | val_loss: 0.2862 acc: 0.9180 | auc: 0.9627
#       [global/center_4] época 13/20 — loss: 0.0280 acc: 0.9902 | val_loss: 0.4984 acc: 0.8906 | auc: 0.9652
#       [global/center_4] época 14/20 — loss: 0.0314 acc: 0.9883 | val_loss: 0.4623 acc: 0.8828 | auc: 0.9551
#       [global/center_4] época 15/20 — loss: 0.0279 acc: 0.9902 | val_loss: 0.3967 acc: 0.8672 | auc: 0.9677
#       [global/center_4] época 16/20 — loss: 0.0473 acc: 0.9805 | val_loss: 0.2121 acc: 0.9180 | auc: 0.9726
#       [global/center_4] época 17/20 — loss: 0.0165 acc: 0.9961 | val_loss: 0.3500 acc: 0.9062 | auc: 0.9783
#         → mejor época global: 17 | auc: 0.9783
#       [global/center_4] época 18/20 — loss: 0.0027 acc: 1.0000 | val_loss: 0.2753 acc: 0.9219 | auc: 0.9783
#       [global/center_4] época 19/20 — loss: 0.0016 acc: 1.0000 | val_loss: 0.3163 acc: 0.9180 | auc: 0.9791
#         → mejor época global: 19 | auc: 0.9791
#       [global/center_4] época 20/20 — loss: 0.0039 acc: 0.9980 | val_loss: 0.3225 acc: 0.9102 | auc: 0.9778
#
#   - Mejor modelo global guardado (val_auc: 0.9878)
#
#   ── Personalización Ditto ──
#
#   Centro: center_1
#       [ditto/center_1] época 01/15 — loss: 0.0003 acc: 1.0000 | val_loss: 0.0107 acc: 0.9951 | auc: 1.0000
#         → mejor época local: 1 | auc: 1.0000
#       [ditto/center_1] época 02/15 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0085 acc: 0.9951 | auc: 1.0000
#         → mejor época local: 2 | auc: 1.0000
#       [ditto/center_1] época 03/15 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0091 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 04/15 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0128 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 05/15 — loss: 0.0274 acc: 0.9905 | val_loss: 0.0364 acc: 0.9852 | auc: 0.9996
#       [ditto/center_1] época 06/15 — loss: 0.0038 acc: 0.9992 | val_loss: 0.0075 acc: 0.9967 | auc: 1.0000
#       [ditto/center_1] época 07/15 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0109 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 08/15 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0113 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 09/15 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0080 acc: 0.9967 | auc: 1.0000
#       [ditto/center_1] época 10/15 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0126 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 11/15 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0135 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 12/15 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0136 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 13/15 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0120 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 14/15 — loss: 0.0002 acc: 1.0000 | val_loss: 0.0118 acc: 0.9951 | auc: 1.0000
#       [ditto/center_1] época 15/15 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0119 acc: 0.9951 | auc: 1.0000
#     - Mejor modelo local guardado | auc: 1.0000
#
#   Centro: center_2
#       [ditto/center_2] época 01/15 — loss: 0.0354 acc: 0.9922 | val_loss: 0.1276 acc: 0.9740 | auc: 0.9961
#         → mejor época local: 1 | auc: 0.9961
#       [ditto/center_2] época 02/15 — loss: 0.0464 acc: 0.9857 | val_loss: 0.1127 acc: 0.9740 | auc: 0.9943
#       [ditto/center_2] época 03/15 — loss: 0.0118 acc: 0.9961 | val_loss: 0.1224 acc: 0.9740 | auc: 0.9938
#       [ditto/center_2] época 04/15 — loss: 0.0090 acc: 0.9987 | val_loss: 0.1046 acc: 0.9740 | auc: 0.9916
#       [ditto/center_2] época 05/15 — loss: 0.0029 acc: 1.0000 | val_loss: 0.1166 acc: 0.9792 | auc: 0.9927
#       [ditto/center_2] época 06/15 — loss: 0.0016 acc: 1.0000 | val_loss: 0.1132 acc: 0.9792 | auc: 0.9935
#       [ditto/center_2] época 07/15 — loss: 0.0019 acc: 1.0000 | val_loss: 0.0976 acc: 0.9792 | auc: 0.9915
#       [ditto/center_2] época 08/15 — loss: 0.0015 acc: 1.0000 | val_loss: 0.1192 acc: 0.9740 | auc: 0.9925
#       [ditto/center_2] época 09/15 — loss: 0.0821 acc: 0.9753 | val_loss: 0.1699 acc: 0.9427 | auc: 0.9969
#         → mejor época local: 9 | auc: 0.9969
#       [ditto/center_2] época 10/15 — loss: 0.1064 acc: 0.9661 | val_loss: 0.0485 acc: 0.9844 | auc: 0.9987
#         → mejor época local: 10 | auc: 0.9987
#       [ditto/center_2] época 11/15 — loss: 0.0229 acc: 0.9922 | val_loss: 0.0390 acc: 0.9896 | auc: 0.9989
#         → mejor época local: 11 | auc: 0.9989
#       [ditto/center_2] época 12/15 — loss: 0.0069 acc: 0.9974 | val_loss: 0.0668 acc: 0.9740 | auc: 0.9981
#       [ditto/center_2] época 13/15 — loss: 0.0023 acc: 1.0000 | val_loss: 0.0604 acc: 0.9844 | auc: 0.9987
#       [ditto/center_2] época 14/15 — loss: 0.0018 acc: 1.0000 | val_loss: 0.0612 acc: 0.9844 | auc: 0.9985
#       [ditto/center_2] época 15/15 — loss: 0.0015 acc: 1.0000 | val_loss: 0.0750 acc: 0.9844 | auc: 0.9975
#     - Mejor modelo local guardado | auc: 0.9989
#
#   Centro: center_3
#       [ditto/center_3] época 01/15 — loss: 0.0454 acc: 0.9485 | val_loss: 1.0558 acc: 0.6741 | auc: 0.8530
#         → mejor época local: 1 | auc: 0.8530
#       [ditto/center_3] época 02/15 — loss: 0.0461 acc: 0.9504 | val_loss: 0.3475 acc: 0.7407 | auc: 0.8697
#         → mejor época local: 2 | auc: 0.8697
#       [ditto/center_3] época 03/15 — loss: 0.0310 acc: 0.9632 | val_loss: 0.3744 acc: 0.7185 | auc: 0.8776
#         → mejor época local: 3 | auc: 0.8776
#       [ditto/center_3] época 04/15 — loss: 0.0460 acc: 0.9504 | val_loss: 0.2966 acc: 0.8074 | auc: 0.8774
#       [ditto/center_3] época 05/15 — loss: 0.0219 acc: 0.9706 | val_loss: 0.7015 acc: 0.7333 | auc: 0.8546
#       [ditto/center_3] época 06/15 — loss: 0.0340 acc: 0.9577 | val_loss: 0.3024 acc: 0.8000 | auc: 0.8779
#         → mejor época local: 6 | auc: 0.8779
#       [ditto/center_3] época 07/15 — loss: 0.0288 acc: 0.9651 | val_loss: 0.3834 acc: 0.7333 | auc: 0.8432
#       [ditto/center_3] época 08/15 — loss: 0.0381 acc: 0.9596 | val_loss: 0.4379 acc: 0.7333 | auc: 0.8647
#       [ditto/center_3] época 09/15 — loss: 0.0270 acc: 0.9706 | val_loss: 0.8699 acc: 0.7037 | auc: 0.8487
#       [ditto/center_3] época 10/15 — loss: 0.0345 acc: 0.9688 | val_loss: 0.3348 acc: 0.8074 | auc: 0.8755
#       [ditto/center_3] época 11/15 — loss: 0.0201 acc: 0.9798 | val_loss: 0.3400 acc: 0.7852 | auc: 0.8795
#         → mejor época local: 11 | auc: 0.8795
#       [ditto/center_3] época 12/15 — loss: 0.0270 acc: 0.9761 | val_loss: 0.4835 acc: 0.7037 | auc: 0.8429
#       [ditto/center_3] época 13/15 — loss: 0.0383 acc: 0.9577 | val_loss: 0.9153 acc: 0.7407 | auc: 0.8659
#       [ditto/center_3] época 14/15 — loss: 0.0386 acc: 0.9522 | val_loss: 0.2527 acc: 0.7556 | auc: 0.8611
#       [ditto/center_3] época 15/15 — loss: 0.0254 acc: 0.9706 | val_loss: 0.4071 acc: 0.8000 | auc: 0.8817
#         → mejor época local: 15 | auc: 0.8817
#     - Mejor modelo local guardado | auc: 0.8817
#
#   Centro: center_4
#       [ditto/center_4] época 01/15 — loss: 0.0682 acc: 0.9678 | val_loss: 0.3823 acc: 0.8906 | auc: 0.9379
#         → mejor época local: 1 | auc: 0.9379
#       [ditto/center_4] época 02/15 — loss: 0.0582 acc: 0.9756 | val_loss: 0.4470 acc: 0.8750 | auc: 0.9381
#         → mejor época local: 2 | auc: 0.9381
#       [ditto/center_4] época 03/15 — loss: 0.0444 acc: 0.9795 | val_loss: 0.5602 acc: 0.8828 | auc: 0.9484
#         → mejor época local: 3 | auc: 0.9484
#       [ditto/center_4] época 04/15 — loss: 0.0566 acc: 0.9814 | val_loss: 0.4100 acc: 0.8633 | auc: 0.9459
#       [ditto/center_4] época 05/15 — loss: 0.0581 acc: 0.9775 | val_loss: 0.4817 acc: 0.8711 | auc: 0.9437
#       [ditto/center_4] época 06/15 — loss: 0.0463 acc: 0.9824 | val_loss: 0.5102 acc: 0.8828 | auc: 0.9368
#       [ditto/center_4] época 07/15 — loss: 0.0770 acc: 0.9717 | val_loss: 0.4616 acc: 0.8906 | auc: 0.9374
#       [ditto/center_4] época 08/15 — loss: 0.0320 acc: 0.9883 | val_loss: 0.4290 acc: 0.8750 | auc: 0.9412
#       [ditto/center_4] época 09/15 — loss: 0.0481 acc: 0.9824 | val_loss: 0.8059 acc: 0.8672 | auc: 0.9347
#       [ditto/center_4] época 10/15 — loss: 0.0513 acc: 0.9756 | val_loss: 0.5536 acc: 0.8750 | auc: 0.9359
#       [ditto/center_4] época 11/15 — loss: 0.0514 acc: 0.9805 | val_loss: 0.4601 acc: 0.8867 | auc: 0.9467
#       [ditto/center_4] época 12/15 — loss: 0.0449 acc: 0.9795 | val_loss: 0.4565 acc: 0.8750 | auc: 0.9471
#       [ditto/center_4] época 13/15 — loss: 0.0542 acc: 0.9756 | val_loss: 0.6037 acc: 0.8750 | auc: 0.9407
#       [ditto/center_4] época 14/15 — loss: 0.0441 acc: 0.9863 | val_loss: 0.5437 acc: 0.8828 | auc: 0.9452
#       [ditto/center_4] época 15/15 — loss: 0.0398 acc: 0.9805 | val_loss: 0.8604 acc: 0.8594 | auc: 0.9426
#
#   ───────────────────────────────────────────────────────
#   Ronda 3 — val_auc global: 0.9878
#   Val AUC locales:
#     center_1 → 1.0000
#     center_2 → 0.9989
#     center_3 → 0.8817
#     center_4 → 0.9484
#
# ============================================================
#   RONDA 4/30
# ============================================================
#
#   ── Entrenamiento global ──
#
#   Centro: center_1
#       [global/center_1] época 01/20 — loss: 0.0074 acc: 0.9975 | val_loss: 0.0606 acc: 0.9885 | auc: 0.9990
#         → mejor época global: 1 | auc: 0.9990
#       [global/center_1] época 02/20 — loss: 0.0051 acc: 0.9984 | val_loss: 0.0364 acc: 0.9918 | auc: 0.9997
#         → mejor época global: 2 | auc: 0.9997
#       [global/center_1] época 03/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.0243 acc: 0.9918 | auc: 0.9998
#         → mejor época global: 3 | auc: 0.9998
#       [global/center_1] época 04/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0229 acc: 0.9934 | auc: 0.9998
#         → mejor época global: 4 | auc: 0.9998
#       [global/center_1] época 05/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0236 acc: 0.9934 | auc: 0.9998
#       [global/center_1] época 06/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0309 acc: 0.9934 | auc: 0.9998
#         → mejor época global: 6 | auc: 0.9998
#       [global/center_1] época 07/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0276 acc: 0.9934 | auc: 0.9998
#       [global/center_1] época 08/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0272 acc: 0.9934 | auc: 0.9998
#       [global/center_1] época 09/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0272 acc: 0.9934 | auc: 0.9998
#       [global/center_1] época 10/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0270 acc: 0.9918 | auc: 0.9999
#         → mejor época global: 10 | auc: 0.9999
#       [global/center_1] época 11/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0258 acc: 0.9918 | auc: 0.9999
#         → mejor época global: 11 | auc: 0.9999
#       [global/center_1] época 12/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0500 acc: 0.9901 | auc: 0.9998
#       [global/center_1] época 13/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0351 acc: 0.9918 | auc: 0.9998
#       [global/center_1] época 14/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0390 acc: 0.9918 | auc: 0.9998
#       [global/center_1] época 15/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0367 acc: 0.9918 | auc: 0.9999
#         → mejor época global: 15 | auc: 0.9999
#       [global/center_1] época 16/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0368 acc: 0.9918 | auc: 0.9998
# ...
#       [global/center_2] época 19/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0592 acc: 0.9844 | auc: 0.9992
#       [global/center_2] época 20/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0623 acc: 0.9844 | auc: 0.9993
#
#   Centro: center_3
#       [global/center_3] época 01/20 — loss: 0.3254 acc: 0.9246 | val_loss: 0.3345 acc: 0.7481 | auc: 0.9191
#         → mejor época global: 1 | auc: 0.9191
#       [global/center_3] época 02/20 — loss: 0.0285 acc: 0.9522 | val_loss: 0.1851 acc: 0.8222 | auc: 0.9243
#         → mejor época global: 2 | auc: 0.9243
#       [global/center_3] época 03/20 — loss: 0.0029 acc: 0.9982 | val_loss: 0.2551 acc: 0.8296 | auc: 0.9246
#         → mejor época global: 3 | auc: 0.9246
#       [global/center_3] época 04/20 — loss: 0.0017 acc: 1.0000 | val_loss: 0.2725 acc: 0.8296 | auc: 0.9258
#         → mejor época global: 4 | auc: 0.9258
#       [global/center_3] época 05/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.2754 acc: 0.8296 | auc: 0.9260
#         → mejor época global: 5 | auc: 0.9260
#       [global/center_3] época 06/20 — loss: 0.0005 acc: 1.0000 | val_loss: 0.2723 acc: 0.8148 | auc: 0.9272
#         → mejor época global: 6 | auc: 0.9272
#       [global/center_3] época 07/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.2803 acc: 0.8222 | auc: 0.9274
#         → mejor época global: 7 | auc: 0.9274
#       [global/center_3] época 08/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.2813 acc: 0.8148 | auc: 0.9279
#         → mejor época global: 8 | auc: 0.9279
#       [global/center_3] época 09/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.2873 acc: 0.8148 | auc: 0.9282
#         → mejor época global: 9 | auc: 0.9282
#       [global/center_3] época 10/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.2914 acc: 0.8222 | auc: 0.9274
#       [global/center_3] época 11/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.2940 acc: 0.8148 | auc: 0.9272
#       [global/center_3] época 12/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.2942 acc: 0.8296 | auc: 0.9267
#       [global/center_3] época 13/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.3415 acc: 0.8074 | auc: 0.9250
#       [global/center_3] época 14/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.3315 acc: 0.8074 | auc: 0.9262
#       [global/center_3] época 15/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.3347 acc: 0.8074 | auc: 0.9255
#       [global/center_3] época 16/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.3413 acc: 0.8074 | auc: 0.9250
#       [global/center_3] época 17/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.3276 acc: 0.8296 | auc: 0.9255
#       [global/center_3] época 18/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.3387 acc: 0.8148 | auc: 0.9250
#       [global/center_3] época 19/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.3386 acc: 0.8148 | auc: 0.9253
#       [global/center_3] época 20/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.3478 acc: 0.8148 | auc: 0.9234
#
#   Centro: center_4
#       [global/center_4] época 01/20 — loss: 0.0228 acc: 0.9980 | val_loss: 0.5198 acc: 0.9180 | auc: 0.9628
#         → mejor época global: 1 | auc: 0.9628
#       [global/center_4] época 02/20 — loss: 0.0286 acc: 0.9912 | val_loss: 0.7844 acc: 0.8945 | auc: 0.9545
#       [global/center_4] época 03/20 — loss: 0.0198 acc: 0.9932 | val_loss: 0.3188 acc: 0.9141 | auc: 0.9706
#         → mejor época global: 3 | auc: 0.9706
#       [global/center_4] época 04/20 — loss: 0.0098 acc: 0.9951 | val_loss: 0.3641 acc: 0.9297 | auc: 0.9722
#         → mejor época global: 4 | auc: 0.9722
#       [global/center_4] época 05/20 — loss: 0.0006 acc: 1.0000 | val_loss: 0.3947 acc: 0.9297 | auc: 0.9722
#       [global/center_4] época 06/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.4059 acc: 0.9297 | auc: 0.9722
#       [global/center_4] época 07/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.4041 acc: 0.9258 | auc: 0.9730
#         → mejor época global: 7 | auc: 0.9730
#       [global/center_4] época 08/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.4188 acc: 0.9297 | auc: 0.9724
#       [global/center_4] época 09/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.4229 acc: 0.9297 | auc: 0.9728
#       [global/center_4] época 10/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.5420 acc: 0.9219 | auc: 0.9734
#         → mejor época global: 10 | auc: 0.9734
#       [global/center_4] época 11/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.4075 acc: 0.9258 | auc: 0.9722
#       [global/center_4] época 12/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.4508 acc: 0.9258 | auc: 0.9729
#       [global/center_4] época 13/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.4540 acc: 0.9297 | auc: 0.9731
#       [global/center_4] época 14/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.4398 acc: 0.9258 | auc: 0.9725
#       [global/center_4] época 15/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.4317 acc: 0.9258 | auc: 0.9725
#       [global/center_4] época 16/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.4528 acc: 0.9258 | auc: 0.9723
#       [global/center_4] época 17/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.4775 acc: 0.9297 | auc: 0.9723
#       [global/center_4] época 18/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.4652 acc: 0.9258 | auc: 0.9722
#       [global/center_4] época 19/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.4850 acc: 0.9297 | auc: 0.9728
#       [global/center_4] época 20/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.5053 acc: 0.9297 | auc: 0.9724
#   Sin mejora global 9/10
#
#   ───────────────────────────────────────────────────────
#   Ronda 13 — val_auc global: 0.9861
#   Val AUC locales:
#     center_1 → 1.0000
#     center_2 → 0.9993
#     center_3 → 0.9191
#     center_4 → 0.9598
#
# ============================================================
#   RONDA 14/30
# ============================================================
#
#   ── Entrenamiento global ──
#
#   Centro: center_1
#       [global/center_1] época 01/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0363 acc: 0.9951 | auc: 1.0000
#         → mejor época global: 1 | auc: 1.0000
#       [global/center_1] época 02/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0270 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 03/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0390 acc: 0.9951 | auc: 1.0000
#       [global/center_1] época 04/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0229 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 05/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0221 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 06/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0278 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 07/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0286 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 08/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0289 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 09/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0184 acc: 0.9984 | auc: 1.0000
#       [global/center_1] época 10/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0194 acc: 0.9984 | auc: 1.0000
#       [global/center_1] época 11/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0193 acc: 0.9984 | auc: 1.0000
#       [global/center_1] época 12/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0286 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 13/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0350 acc: 0.9951 | auc: 1.0000
#       [global/center_1] época 14/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0288 acc: 0.9951 | auc: 1.0000
#       [global/center_1] época 15/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0166 acc: 0.9951 | auc: 1.0000
#       [global/center_1] época 16/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0388 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 17/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0546 acc: 0.9934 | auc: 0.9999
#       [global/center_1] época 18/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0489 acc: 0.9967 | auc: 1.0000
#       [global/center_1] época 19/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0586 acc: 0.9934 | auc: 1.0000
#       [global/center_1] época 20/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0539 acc: 0.9934 | auc: 1.0000
#
#   Centro: center_2
#       [global/center_2] época 01/20 — loss: 0.0089 acc: 0.9961 | val_loss: 0.1883 acc: 0.9792 | auc: 0.9981
#         → mejor época global: 1 | auc: 0.9981
#       [global/center_2] época 02/20 — loss: 0.0050 acc: 0.9987 | val_loss: 0.0229 acc: 0.9896 | auc: 1.0000
#         → mejor época global: 2 | auc: 1.0000
#       [global/center_2] época 03/20 — loss: 0.0453 acc: 0.9883 | val_loss: 0.1416 acc: 0.9635 | auc: 0.9992
#       [global/center_2] época 04/20 — loss: 0.0019 acc: 1.0000 | val_loss: 0.0461 acc: 0.9844 | auc: 0.9996
#       [global/center_2] época 05/20 — loss: 0.0025 acc: 0.9987 | val_loss: 0.0238 acc: 0.9844 | auc: 0.9998
#       [global/center_2] época 06/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.0212 acc: 0.9896 | auc: 0.9998
#       [global/center_2] época 07/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0211 acc: 0.9896 | auc: 0.9998
#       [global/center_2] época 08/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.0221 acc: 0.9896 | auc: 0.9998
#       [global/center_2] época 09/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0239 acc: 0.9948 | auc: 0.9998
#       [global/center_2] época 10/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0236 acc: 0.9948 | auc: 0.9998
#       [global/center_2] época 11/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0226 acc: 0.9948 | auc: 0.9998
#       [global/center_2] época 12/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0248 acc: 0.9948 | auc: 0.9998
#       [global/center_2] época 13/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0233 acc: 0.9896 | auc: 0.9998
#       [global/center_2] época 14/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0226 acc: 0.9948 | auc: 0.9998
#       [global/center_2] época 15/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0258 acc: 0.9896 | auc: 0.9998
#       [global/center_2] época 16/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0238 acc: 0.9896 | auc: 0.9998
#       [global/center_2] época 17/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0234 acc: 0.9948 | auc: 0.9998
#       [global/center_2] época 18/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0234 acc: 0.9948 | auc: 0.9998
#       [global/center_2] época 19/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0258 acc: 0.9896 | auc: 0.9998
#       [global/center_2] época 20/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.0230 acc: 0.9948 | auc: 0.9998
#
#   Centro: center_3
#       [global/center_3] época 01/20 — loss: 0.3425 acc: 0.9118 | val_loss: 0.2067 acc: 0.8222 | auc: 0.9195
#         → mejor época global: 1 | auc: 0.9195
#       [global/center_3] época 02/20 — loss: 0.0104 acc: 0.9853 | val_loss: 0.2129 acc: 0.8519 | auc: 0.9250
#         → mejor época global: 2 | auc: 0.9250
#       [global/center_3] época 03/20 — loss: 0.0047 acc: 0.9945 | val_loss: 0.2868 acc: 0.8519 | auc: 0.9239
#       [global/center_3] época 04/20 — loss: 0.0019 acc: 0.9982 | val_loss: 0.2765 acc: 0.8444 | auc: 0.9229
#       [global/center_3] época 05/20 — loss: 0.0006 acc: 1.0000 | val_loss: 0.2842 acc: 0.8444 | auc: 0.9219
#       [global/center_3] época 06/20 — loss: 0.0006 acc: 1.0000 | val_loss: 0.3011 acc: 0.8519 | auc: 0.9231
#       [global/center_3] época 07/20 — loss: 0.0004 acc: 1.0000 | val_loss: 0.3016 acc: 0.8519 | auc: 0.9253
#         → mejor época global: 7 | auc: 0.9253
#       [global/center_3] época 08/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.2935 acc: 0.8444 | auc: 0.9246
#       [global/center_3] época 09/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.3453 acc: 0.8667 | auc: 0.9265
#         → mejor época global: 9 | auc: 0.9265
#       [global/center_3] época 10/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.3538 acc: 0.8667 | auc: 0.9265
#         → mejor época global: 10 | auc: 0.9265
#       [global/center_3] época 11/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.3450 acc: 0.8593 | auc: 0.9260
#       [global/center_3] época 12/20 — loss: 0.0020 acc: 0.9982 | val_loss: 0.5098 acc: 0.8296 | auc: 0.9183
#       [global/center_3] época 13/20 — loss: 0.0014 acc: 0.9982 | val_loss: 0.3117 acc: 0.8444 | auc: 0.9320
#         → mejor época global: 13 | auc: 0.9320
#       [global/center_3] época 14/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.3207 acc: 0.8519 | auc: 0.9375
#         → mejor época global: 14 | auc: 0.9375
#       [global/center_3] época 15/20 — loss: 0.0002 acc: 1.0000 | val_loss: 0.3042 acc: 0.8444 | auc: 0.9399
#         → mejor época global: 15 | auc: 0.9399
#       [global/center_3] época 16/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.2893 acc: 0.8593 | auc: 0.9382
#       [global/center_3] época 17/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.3072 acc: 0.8444 | auc: 0.9392
#       [global/center_3] época 18/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.3057 acc: 0.8519 | auc: 0.9385
#       [global/center_3] época 19/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.3071 acc: 0.8444 | auc: 0.9387
#       [global/center_3] época 20/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.3434 acc: 0.8444 | auc: 0.9392
#
#   Centro: center_4
#       [global/center_4] época 01/20 — loss: 0.0085 acc: 0.9971 | val_loss: 0.5718 acc: 0.9219 | auc: 0.9655
#         → mejor época global: 1 | auc: 0.9655
#       [global/center_4] época 02/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.5719 acc: 0.9219 | auc: 0.9668
#         → mejor época global: 2 | auc: 0.9668
#       [global/center_4] época 03/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.6096 acc: 0.9336 | auc: 0.9673
#         → mejor época global: 3 | auc: 0.9673
#       [global/center_4] época 04/20 — loss: 0.0003 acc: 1.0000 | val_loss: 0.6151 acc: 0.9297 | auc: 0.9691
#         → mejor época global: 4 | auc: 0.9691
#       [global/center_4] época 05/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.6629 acc: 0.9180 | auc: 0.9670
#       [global/center_4] época 06/20 — loss: 0.0001 acc: 1.0000 | val_loss: 0.6044 acc: 0.9219 | auc: 0.9695
#         → mejor época global: 6 | auc: 0.9695
#       [global/center_4] época 07/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6354 acc: 0.9258 | auc: 0.9704
#         → mejor época global: 7 | auc: 0.9704
#       [global/center_4] época 08/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6264 acc: 0.9258 | auc: 0.9705
#         → mejor época global: 8 | auc: 0.9705
#       [global/center_4] época 09/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6438 acc: 0.9180 | auc: 0.9713
#         → mejor época global: 9 | auc: 0.9713
#       [global/center_4] época 10/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6659 acc: 0.9180 | auc: 0.9722
#         → mejor época global: 10 | auc: 0.9722
#       [global/center_4] época 11/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6544 acc: 0.9219 | auc: 0.9718
#       [global/center_4] época 12/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6872 acc: 0.9180 | auc: 0.9723
#         → mejor época global: 12 | auc: 0.9723
#       [global/center_4] época 13/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6582 acc: 0.9219 | auc: 0.9728
#         → mejor época global: 13 | auc: 0.9728
#       [global/center_4] época 14/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.7194 acc: 0.9180 | auc: 0.9724
#       [global/center_4] época 15/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6814 acc: 0.9180 | auc: 0.9728
#         → mejor época global: 15 | auc: 0.9728
#       [global/center_4] época 16/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6526 acc: 0.9219 | auc: 0.9737
#         → mejor época global: 16 | auc: 0.9737
#       [global/center_4] época 17/20 — loss: 0.0000 acc: 1.0000 | val_loss: 0.6644 acc: 0.9219 | auc: 0.9732
#       [global/center_4] época 18/20 — loss: 0.1286 acc: 0.9590 | val_loss: 0.2505 acc: 0.8711 | auc: 0.9550
#       [global/center_4] época 19/20 — loss: 0.0878 acc: 0.9580 | val_loss: 0.3249 acc: 0.9062 | auc: 0.9603
#       [global/center_4] época 20/20 — loss: 0.0095 acc: 0.9971 | val_loss: 0.2769 acc: 0.9336 | auc: 0.9683
#   Sin mejora global 10/10
#
#   ───────────────────────────────────────────────────────
#   Ronda 14 — val_auc global: 0.9875
#   Val AUC locales:
#     center_1 → 1.0000
#     center_2 → 0.9993
#     center_3 → 0.9191
#     center_4 → 0.9598
#
#   Early stopping en ronda 14
#
# ============================================================
# Entrenamiento Ditto finalizado
# Mejor val_auc global : 0.9892
# Mejores val_auc locales:
#   center_1 -> 1.0000
#   center_2 -> 0.9993
#   center_3 -> 0.9191
#   center_4 -> 0.9598

# %%
modelo_global.load_state_dict(torch.load(MODELO_GLOBAL_PATH, map_location=DEVICE))

for nombre in CENTROS.keys():
    modelos_locales[nombre].load_state_dict(
        torch.load(MODELOS_LOCALES_PATHS[nombre], map_location=DEVICE)
    )

# %%
def evaluar_modelo(nombre, modelo, loader_test):
    modelo.eval()
    todos_labels = []
    todos_probs  = []
    todos_preds  = []

    with torch.no_grad():
        for imagenes, labels in loader_test:
            imagenes = imagenes.to(DEVICE)
            salida   = modelo(imagenes)
            probs    = torch.sigmoid(salida).squeeze(1).cpu().numpy()
            preds    = (probs >= 0.5).astype(int)
            todos_labels.extend(labels.numpy().astype(int))
            todos_probs.extend(probs)
            todos_preds.extend(preds)

    return {
        "auc"          : roc_auc_score(todos_labels, todos_probs),
        "f1"           : f1_score(todos_labels, todos_preds),
        "sensibilidad" : recall_score(todos_labels, todos_preds),
        "especificidad": recall_score(todos_labels, todos_preds, pos_label=0),
        "precision"    : precision_score(todos_labels, todos_preds),
        "accuracy"     : sum(p == l for p, l in zip(todos_preds, todos_labels)) / len(todos_labels),
        "cm"           : confusion_matrix(todos_labels, todos_preds),
    }

# Cargar mejor modelo global
modelo_global.load_state_dict(torch.load(MODELO_GLOBAL_PATH, map_location=DEVICE))

# Cargar mejores modelos locales
for nombre in CENTROS.keys():
    modelos_locales[nombre].load_state_dict(
        torch.load(MODELOS_LOCALES_PATHS[nombre], map_location=DEVICE)
    )

# Evaluar
resultados_global = {}
resultados_local  = {}

for nombre, datos in datos_centros.items():
    resultados_global[nombre] = evaluar_modelo(nombre, modelo_global, datos["loader_test"])
    resultados_local[nombre]  = evaluar_modelo(nombre, modelos_locales[nombre], datos["loader_test"])

# Tabla comparativa
metricas = ["auc", "accuracy", "f1", "sensibilidad", "especificidad", "precision"]
nombres  = ["AUC-ROC", "Accuracy", "F1-Score", "Sensibilidad", "Especificidad", "Precisión"]

for nombre in CENTROS.keys():
    print(f"\n{'='*55}")
    print(f"  {nombre.upper()}")
    print(f"{'='*55}")
    print(f"  {'Métrica':<16} {'Global':>12} {'Local Ditto':>12}")
    print(f"  {'─'*42}")
    for metrica, nombre_m in zip(metricas, nombres):
        vg = resultados_global[nombre][metrica]
        vl = resultados_local[nombre][metrica]
        mejor = "←" if vl > vg else ""
        print(f"  {nombre_m:<16} {vg:>12.4f} {vl:>12.4f}  {mejor}")

# Resumen AUC
print(f"\n{'='*55}")
print(f"  RESUMEN AUC-ROC")
print(f"{'='*55}")
print(f"  {'Centro':<12} {'Global':>10} {'Local':>10} {'Mejor':>10}")
print(f"  {'─'*45}")
for nombre in CENTROS.keys():
    vg = resultados_global[nombre]["auc"]
    vl = resultados_local[nombre]["auc"]
    mejor = "Local" if vl > vg else "Global"
    print(f"  {nombre:<12} {vg:>10.4f} {vl:>10.4f} {mejor:>10}")
# Out:
# =======================================================
#   CENTER_1
# =======================================================
#   Métrica                Global  Local Ditto
#   ──────────────────────────────────────────
#   AUC-ROC                0.9661       0.9658
#   Accuracy               0.9171       0.9158
#   F1-Score               0.9168       0.9101
#   Sensibilidad           0.9132       0.8526
#   Especificidad          0.9211       0.9789  ←
#   Precisión              0.9204       0.9759  ←
#
# =======================================================
#   CENTER_2
# =======================================================
#   Métrica                Global  Local Ditto
#   ──────────────────────────────────────────
#   AUC-ROC                0.8438       0.9790  ←
#   Accuracy               0.7167       0.9500  ←
#   F1-Score               0.7748       0.9552  ←
#   Sensibilidad           0.8357       0.9143  ←
#   Especificidad          0.5500       1.0000  ←
#   Precisión              0.7222       1.0000  ←
#
# =======================================================
#   CENTER_3
# =======================================================
#   Métrica                Global  Local Ditto
#   ──────────────────────────────────────────
#   AUC-ROC                0.1673       0.7634  ←
#   Accuracy               0.3099       0.7251  ←
#   F1-Score               0.4636       0.7773  ←
#   Sensibilidad           0.4766       0.7664  ←
#   Especificidad          0.0312       0.6562  ←
#   Precisión              0.4513       0.7885  ←
#
# =======================================================
#   CENTER_4
# =======================================================
#   Métrica                Global  Local Ditto
#   ──────────────────────────────────────────
#   AUC-ROC                0.2705       0.5148  ←
#   Accuracy               0.4375       0.5125  ←
#   F1-Score               0.5853       0.3097
#   Sensibilidad           0.7341       0.2023
#   Especificidad          0.0884       0.8776  ←
#   Precisión              0.4866       0.6604  ←
#
# =======================================================
#   RESUMEN AUC-ROC
# =======================================================
#   Centro           Global      Local      Mejor
#   ─────────────────────────────────────────────
#   center_1         0.9661     0.9658     Global
#   center_2         0.8438     0.9790      Local
#   center_3         0.1673     0.7634      Local
#   center_4         0.2705     0.5148      Local

# %% [markdown]
# # **Inferencias center_5**

# %%
# Rutas
RUTA_CENTER_5 = Path("../preprocesamiento/output/center_5/preprocesamiento_test")

# Elección del modelo a evaluar
#RUTA_MODELO   = Path("ditto_pesos/center_4_local_ditto_08.pth")
RUTA_MODELO   = Path("ditto_pesos/center_4_local_ditto.pth")

NOMBRE_CSV    = "prob_ditto_c4_center_5.csv"
OUTPUT_DIR    = Path("probabilidades_center_5")
OUTPUT_DIR.mkdir(exist_ok=True)

# %%
# Sin etiquetas, solo probabilidades
class StrokeDatasetInferencia(Dataset):
    def __init__(self, archivos):
        self.archivos = archivos

    def __len__(self):
        return len(self.archivos)

    def __getitem__(self, idx):
        ruta   = self.archivos[idx]
        imagen = np.load(ruta).astype(np.float32)
        imagen = torch.from_numpy(imagen)
        return imagen, ruta.stem    

# Cargar datos
archivos_test = sorted(RUTA_CENTER_5.glob("*.npy"))
print(f"Archivos encontrados: {len(archivos_test)}")

dataset_test  = StrokeDatasetInferencia(archivos_test)
loader_test   = DataLoader(dataset_test, batch_size=BATCH_SIZE, shuffle=False)

# Cargar modelo
modelo_inferencia = crear_modelo().to(DEVICE)
modelo_inferencia.load_state_dict(torch.load(RUTA_MODELO, map_location=DEVICE))
modelo_inferencia.eval()
print(f"Modelo cargado: {RUTA_MODELO.name}")
# Out:
# Archivos encontrados: 257
# Modelo cargado: center_4_local_ditto.pth

# %%
# Inferencia
nombres_archivos = []
probabilidades   = []
predicciones     = []

with torch.no_grad():
    for imagenes, nombres in loader_test:
        imagenes = imagenes.to(DEVICE)
        salida   = modelo_inferencia(imagenes)
        probs    = torch.sigmoid(salida).squeeze(1).cpu().numpy()
        preds    = (probs >= 0.5).astype(int)

        nombres_archivos.extend(nombres)
        probabilidades.extend(probs.tolist())
        predicciones.extend(preds.tolist())

# %%
# Guardar resultados csv
df = pd.DataFrame({
    "archivo"      : nombres_archivos,
    "probabilidad" : probabilidades,
})

ruta_csv = OUTPUT_DIR / NOMBRE_CSV
df.to_csv(ruta_csv, index=False)

print(f"\nCSV guardado: {ruta_csv}")
print(f"Total muestras: {len(df)}")
print(f"\nDistribución predicciones:")
#print(df["clase"].value_counts())
print(f"\nPrimeras filas:")
print(df.head())
# Out:
# CSV guardado: probabilidades_center_5\prob_ditto_c4_center_5.csv
# Total muestras: 257
#
# Distribución predicciones:
#
# Primeras filas:
#        archivo  probabilidad
# 0  P0300_S0007      0.997849
# 1  P0300_S0008      0.997912
# 2  P0300_S0009      0.999563
# 3  P0300_S0010      0.995729
# 4  P0300_S0011      0.995031
